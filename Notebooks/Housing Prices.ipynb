# %% [markdown]
# # Predicting London Housing Prices

# %% [markdown]
# This investigation details the process of building an estimation engine to predict the actual value of properties in London. The study utilises a multi-model ensemble approach, using a mixture of both tree-based and linear models, to analyse various quantitative and descriptive factors that contribute towards predicting property prices. To optimise for predictive accuracy, the estimation engine employed the use of a Ridge meta-learner comprising of Random Forest, Gradient Boost, XGBoost, Elastic Net, K-Nearest Neighbours, and CatBoost models. Using the model, 200 of the most undervalued properties were selected out of 2000 current listings for investment.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.inspection import permutation_importance

# %%
# Read in the data
london_house_prices_2019_training = pd.read_csv("training_data_assignment_with_prices.csv")
london_house_prices_2019_out_of_sample = pd.read_csv("test_data_assignment.csv")

# Fix data types in both data sets
for _df in [london_house_prices_2019_training, london_house_prices_2019_out_of_sample]:
    if "date" in _df.columns:
        _df["date"] = pd.to_datetime(_df["date"], errors="coerce")
    # Convert string columns to categorical
    obj_cols = _df.select_dtypes(include=["object"]).columns
    for c in obj_cols:
        _df[c] = _df[c].astype("category")

# Quick look at the data
print("TRAINING INFO:")
print(london_house_prices_2019_training.info())
print("\nOUT-OF-SAMPLE INFO:")
print(london_house_prices_2019_out_of_sample.info())
# Out:
# TRAINING INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13998 entries, 0 to 13997
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            13998 non-null  int64
#  1   date                          13998 non-null  datetime64[ns]
#  2   postcode                      13998 non-null  category
#  3   property_type                 13998 non-null  category
#  4   whether_old_or_new            13998 non-null  category
#  5   freehold_or_leasehold         13998 non-null  category
#  6   address1                      13998 non-null  category
#  7   address2                      3186 non-null   category
#  8   address3                      13998 non-null  category
#  9   town                          614 non-null    category
#  10  local_aut                     13998 non-null  category
#  11  county                        13998 non-null  category
#  12  postcode_short                13998 non-null  category
#  13  current_energy_rating         13998 non-null  category
#  14  total_floor_area              13998 non-null  float64
#  15  number_habitable_rooms        13998 non-null  int64
#  16  co2_emissions_current         13998 non-null  float64
#  17  co2_emissions_potential       13998 non-null  float64
#  18  energy_consumption_current    13998 non-null  int64
#  19  energy_consumption_potential  13998 non-null  int64
#  20  windows_energy_eff            13998 non-null  category
#  21  tenure                        13998 non-null  category
#  22  latitude                      13998 non-null  float64
#  23  longitude                     13998 non-null  float64
#  24  population                    13929 non-null  float64
#  25  altitude                      13998 non-null  int64
#  26  london_zone                   13998 non-null  int64
#  27  nearest_station               13998 non-null  category
#  28  water_company                 13998 non-null  category
#  29  average_income                13998 non-null  int64
#  30  district                      13998 non-null  category
#  31  price                         13998 non-null  float64
#  32  type_of_closest_station       13998 non-null  category
#  33  num_tube_lines                13998 non-null  int64
#  34  num_rail_lines                13998 non-null  int64
#  35  num_light_rail_lines          13998 non-null  int64
#  36  distance_to_station           13998 non-null  float64
# dtypes: category(18), datetime64[ns](1), float64(8), int64(10)
# memory usage: 3.4 MB
# None
#
# OUT-OF-SAMPLE INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            1999 non-null   int64
#  1   date                          0 non-null      datetime64[ns]
#  2   postcode                      0 non-null      float64
#  3   property_type                 1999 non-null   category
#  4   whether_old_or_new            1999 non-null   category
#  5   freehold_or_leasehold         1999 non-null   category
#  6   address1                      0 non-null      float64
#  7   address2                      0 non-null      float64
#  8   address3                      0 non-null      float64
#  9   town                          83 non-null     category
#  10  local_aut                     0 non-null      float64
#  11  county                        0 non-null      float64
#  12  postcode_short                1999 non-null   category
#  13  current_energy_rating         1999 non-null   category
#  14  total_floor_area              1999 non-null   float64
#  15  number_habitable_rooms        1999 non-null   int64
#  16  co2_emissions_current         1999 non-null   float64
#  17  co2_emissions_potential       1999 non-null   float64
#  18  energy_consumption_current    1999 non-null   int64
#  19  energy_consumption_potential  1999 non-null   int64
#  20  windows_energy_eff            1999 non-null   category
#  21  tenure                        1999 non-null   category
#  22  latitude                      1999 non-null   float64
#  23  longitude                     1999 non-null   float64
#  24  population                    1992 non-null   float64
#  25  altitude                      1999 non-null   int64
#  26  london_zone                   1999 non-null   int64
#  27  nearest_station               1999 non-null   category
#  28  water_company                 1999 non-null   category
#  29  average_income                1999 non-null   int64
#  30  district                      1999 non-null   category
#  31  type_of_closest_station       1999 non-null   category
#  32  num_tube_lines                1999 non-null   int64
#  33  num_rail_lines                1999 non-null   int64
#  34  num_light_rail_lines          1999 non-null   int64
#  35  distance_to_station           1999 non-null   float64
#  36  asking_price                  1999 non-null   float64
# dtypes: category(12), datetime64[ns](1), float64(14), int64(10)
# memory usage: 452.8 KB
# None

# %%
#Creating test train split with 75% training, 25% testing
target = "price"
feature_cols = ['distance_to_station', 'water_company', 'property_type', 'whether_old_or_new', 'freehold_or_leasehold', 'latitude', 'longitude']

df = london_house_prices_2019_training.copy()
X = df[feature_cols]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.75, random_state=42
)
print(f"Train size: {X_train.shape}, Test size: {X_test.shape}")
# Out:
# Train size: (10498, 7), Test size: (3500, 7)

# %% [markdown]
# # Visualize data

# %% [markdown]
# Property prices were plotted against time to check whether there were any relations between time and property prices in 2019. Based on the line chart, there is no underlying seasonality influencing property prices.

# %%
df2= df.copy()

df2['month']=df2['date'].dt.month
df2.head()
df2_grouped=df2.groupby('date')['price'].mean().reset_index()

#Lineplot of date vs. property price in 2019
sns.lineplot(df2,x='date',y='price')
plt.title("Property Sale Price Over Time")
plt.show()

# %%
#Histogram of price (no log transformation)
sns.histplot(df2,x='price')
plt.title("Histogram of Property Prices")
# Out:
# Text(0.5, 1.0, 'Histogram of Property Prices')

# %%
#Histogram of price with log transformation
df2['log_price']=np.log(df2['price'])
sns.histplot(df2,x='log_price')
plt.title("Histogram of Log Prices")
# Out:
# Text(0.5, 1.0, 'Histogram of Log Prices')

# %%
#Building is_house column
#is_house is False when the property type is a flat
df2['is_house']=df2['property_type'].isin(["D","S","T"]).astype(int)

#Histogram of prices by property type
sns.histplot(df2,x='log_price',hue='is_house')
plt.title("Property Price Distribution by House vs. Flat")
# Out:
# Text(0.5, 1.0, 'Property Price Distribution by House vs. Flat')

# %% [markdown]
# Clustering was implemented on specific variables to further subset the dataset, enhancing model predictive power by grouping potentially redundant variables together. K-means clustering was performed on two subsets of variables: clustering using geographical features and clustering using physical property features.

# %%
#Building clusters using K-mean clustering

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

#Scaling the data
scaler=StandardScaler()

#Selecting on geographic features for clustering 
df2_numeric=df2[['latitude','longitude','london_zone','distance_to_station']]

train_scaled= scaler.fit_transform(df2_numeric)

#Determining best number of clusters 
k_count=list(range(2,11))
sse=[]
sc=[]

for i in k_count:
    km=KMeans(n_clusters=i,n_init=50, random_state=1).fit(train_scaled)
    wss=km.inertia_
    sse.append(wss)

    score=silhouette_score(df2_numeric,labels=km.labels_)
    sc.append({'k':i,'Silhouette score':score,'SSE':wss})

#Displaying elbow graph
sns.lineplot(y=sse,x=k_count)
pd.DataFrame(sc)
# Out:
#     k  Silhouette score           SSE
# 0   2          0.463353  42829.771530
# 1   3          0.300524  33170.598647
# 2   4          0.244850  27162.289618
# 3   5          0.125164  23499.690283
# 4   6          0.126288  21181.567805
# 5   7          0.138002  19089.488661
# 6   8          0.135402  17452.694665
# 7   9          0.122649  15990.824153
# 8  10          0.039358  15012.252344

# %%
#Generating clusters for geographical data
km_geography=KMeans(n_clusters=2,n_init=50, random_state=1).fit(train_scaled)

labels_km_geo=(km_geography.labels_)+1

train_scaled_df=pd.DataFrame(train_scaled)
train_scaled_df['cluster_geography']=labels_km_geo.astype('int')

#Displaying clusters using 2 PCAs
pca=PCA(n_components=2,random_state=25)

pca_kmean=pca.fit_transform(train_scaled_df.values)

sns.scatterplot(train_scaled_df,x=pca_kmean[:,0],y=pca_kmean[:,1], hue='cluster_geography')
plt.title('Segmentation of Properties by Geographical Features')
# Out:
# Text(0.5, 1.0, 'Segmentation of Properties by Geographical Features')

# %%
#Clustering for property features 
#Scaling and selecting columns related to energy usage features 
scaler=StandardScaler()

df2_numeric=df2[['total_floor_area','co2_emissions_current','co2_emissions_potential','energy_consumption_potential','energy_consumption_current']]

train_scaled2= scaler.fit_transform(df2_numeric)

#Determining number of clusters 
k_count=list(range(2,11))
sse=[]
sc=[]

for i in k_count:
    km=KMeans(n_clusters=i,n_init=50, random_state=1).fit(train_scaled2)
    wss=km.inertia_
    sse.append(wss)

    score=silhouette_score(df2_numeric,labels=km.labels_)
    sc.append({'k':i,'Silhouette score':score,'SSE':wss})

#Displaying elbow graph
sns.lineplot(y=sse,x=k_count)
pd.DataFrame(sc)
# Out:
#     k  Silhouette score           SSE
# 0   2          0.298397  48642.320937
# 1   3          0.306261  36301.289199
# 2   4          0.191683  29966.457791
# 3   5          0.217887  26393.882715
# 4   6          0.230743  23650.213457
# 5   7          0.206293  21595.641575
# 6   8          0.215318  19782.701975
# 7   9          0.191764  18415.198770
# 8  10          0.205401  17195.078779

# %%
#Generating clusters on data
km_energy=KMeans(n_clusters=3,n_init=50, random_state=1).fit(train_scaled)

labels_km_energy=(km_energy.labels_)+1

train_scaled_df=pd.DataFrame(train_scaled2)
train_scaled_df['cluster_property']=labels_km_energy.astype('int')

#Displaying clusters using PCA=2
pca=PCA(n_components=2,random_state=25)

pca_kmean=pca.fit_transform(train_scaled_df.values)

sns.scatterplot(train_scaled_df,x=pca_kmean[:,0],y=pca_kmean[:,1], hue='cluster_property')
plt.title("Segmentation of Properties by Energy Usage")
# Out:
# Text(0.5, 1.0, 'Segmentation of Properties by Energy Usage')

# %%
# Compute Pearson correlations for numeric columns (drop non-numeric and ID if present)
df_corr = london_house_prices_2019_training.copy()

if "ID" in df_corr.columns:
    df_corr = df_corr.drop(columns=["ID"])

num_cols = df_corr.select_dtypes(include=[np.number]).columns
corr = df_corr[num_cols].corr(method="pearson")

# Heatmap using matplotlib (no seaborn)
plt.figure()
im = plt.imshow(corr.values, interpolation="nearest")
plt.xticks(range(len(num_cols)), num_cols, rotation=90)
plt.yticks(range(len(num_cols)), num_cols)
plt.title("Correlation heatmap (Pearson)")
plt.colorbar(im, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Linear Regression Baseline Model

# %%
# Converted from R chunk: LR model
# We'll build a scikit-learn Pipeline with preprocessing + LinearRegression
numeric_features = ["distance_to_station", "latitude", "longitude"]
categorical_features = ["water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ],
    remainder="drop",
)

lm_pipe = Pipeline(steps=[
    ("preprocess", preprocess),
    ("regressor", LinearRegression())
])

# 5-fold CV (equivalent to caret::trainControl(method='cv', number=5))
cv = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = (-1 * cross_val_score(lm_pipe, X_train, y_train, cv=cv, scoring="neg_root_mean_squared_error")).mean()
cv_r2 = cross_val_score(lm_pipe, X_train, y_train, cv=cv, scoring="r2").mean()
print(f"Linear Regression 5-fold CV -> RMSE: {cv_rmse:.4f}, R^2: {cv_r2:.4f}")

# Fit on full training set to get a final model (caret refits on all training data)
lm_pipe.fit(X_train, y_train)
# Out:
# Linear Regression 5-fold CV -> RMSE: 449332.7874, R^2: 0.1915
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['distance_to_station',
#                                                    'latitude', 'longitude']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['water_company',
#                                                    'property_type',
#                                                    'whether_old_or_new',
#                                                    'freehold_or_leasehold'])])),
#                 ('regressor', LinearRegression())])

# %%
#obtaining permuation importance for linear regression model
r = permutation_importance(lm_pipe, X_test, y_test, n_repeats=10, random_state=42)
# Retrieve feature names after preprocessing
ohe = lm_pipe.named_steps["preprocess"].named_transformers_["cat"]
num_names = ["distance_to_station", "latitude", "longitude"]
cat_names = list(ohe.get_feature_names_out(["water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]))
feature_names = num_names + cat_names

importances = r.importances_mean
# Basic bar plot
plt.figure()
order = np.argsort(importances)
plt.barh(np.array(feature_names)[order], importances[order])
plt.title("Permutation importance (Linear Regression)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Model Prediction

# %%
# Converted from R chunk: predictions for linear model
# Predict on the test split
predictions = lm_pipe.predict(X_test)
rmse = mean_squared_error(y_test, predictions)
rmse=np.sqrt(rmse).astype(float)
r2 = r2_score(y_test, predictions)
lr_results = {"RMSE": rmse, "Rsquare": r2}
print("lr_results:", lr_results)

# Predict on out-of-sample as well
X_oos = london_house_prices_2019_out_of_sample[["distance_to_station","water_company","property_type","whether_old_or_new","freehold_or_leasehold","latitude","longitude"]]
predictions_oos = lm_pipe.predict(X_oos)
# Out:
# lr_results: {'RMSE': np.float64(523465.24487014057), 'Rsquare': 0.15868859526304668}

# %% [markdown]
# # Fit a tree model
#
# Next I fit a tree model using the same subset of features. Again you can (and should) add more variables and tune the parameter of your tree to find a better fit.
#
# Compare the performance of the linear regression model with the tree model; which one performs better? Why do you think that is the case?

# %%
# Converted from R chunk: LR model
# We'll build a scikit-learn Pipeline with preprocessing + LinearRegression
numeric_features = ["distance_to_station", "latitude", "longitude"]
categorical_features = ["water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ],
    remainder="drop",
)

lm_pipe = Pipeline(steps=[
    ("preprocess", preprocess),
    ("regressor", LinearRegression())
])

# 5-fold CV (equivalent to caret::trainControl(method='cv', number=5))
cv = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = (-1 * cross_val_score(lm_pipe, X_train, y_train, cv=cv, scoring="neg_root_mean_squared_error")).mean()
cv_r2 = cross_val_score(lm_pipe, X_train, y_train, cv=cv, scoring="r2").mean()
print(f"Linear Regression 5-fold CV -> RMSE: {cv_rmse:.4f}, R^2: {cv_r2:.4f}")

# Fit on full training set to get a final model (caret refits on all training data)
lm_pipe.fit(X_train, y_train)
# Out:
# Linear Regression 5-fold CV -> RMSE: 449332.7874, R^2: 0.1915
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['distance_to_station',
#                                                    'latitude', 'longitude']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['water_company',
#                                                    'property_type',
#                                                    'whether_old_or_new',
#                                                    'freehold_or_leasehold'])])),
#                 ('regressor', LinearRegression())])

# %% [markdown]
# # Other algorithms

# %%
#Implementing clusters on data set prior to test-train split

energy_features=['total_floor_area','co2_emissions_current','co2_emissions_potential','energy_consumption_potential','energy_consumption_current']
geo_features=['latitude','longitude','london_zone','distance_to_station']

df_scaled_energy=scaler.fit_transform(df[energy_features])
df_scaled_geo=scaler.fit_transform(df[geo_features])

#Getting energy related clusters
km_energy=KMeans(n_clusters=3,n_init=50, random_state=1).fit(df_scaled_energy)
km_energy_labels=(km_energy.labels_+1).astype(int)

df['cluster_energy']=km_energy_labels

#Getting geography related clusters
km_geo=KMeans(n_clusters=2,n_init=50, random_state=1).fit(df_scaled_geo)
km_geo_labels=(km_geo.labels_+1).astype(int)

df['cluster_geo']=km_geo_labels

# %%
#Overall test train split
target = "price"
feature_cols = ['cluster_energy','cluster_geo','co2_emissions_current','co2_emissions_potential','district','average_income','total_floor_area','num_tube_lines','energy_consumption_potential','london_zone','distance_to_station', 'water_company', 'property_type', 'whether_old_or_new', 'freehold_or_leasehold', 'latitude', 'longitude','number_habitable_rooms','current_energy_rating']

X = df[feature_cols]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.75, random_state=42
)

# %%
#Preprocess only pipeline
numeric_features = ['co2_emissions_current','co2_emissions_potential','average_income','number_habitable_rooms','energy_consumption_potential',"num_tube_lines","distance_to_station", "latitude", "longitude","london_zone", "total_floor_area"]
categorical_features = ['cluster_energy','cluster_geo','district','current_energy_rating',"water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

from sklearn.preprocessing import FunctionTransformer,PolynomialFeatures

y_transformer = FunctionTransformer(
    func=np.log1p,       # Natural log: y -> ln(y)
    inverse_func=np.expm1, # Exponential: ln(y) -> y
    check_inverse=True,
    validate=True
)

preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features), #Apply standard scaler to numeric features
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features), #apply one-hot encoding to categoricals 
    ],
    remainder="drop",
)

lm_pipe = Pipeline(steps=[
    ("preprocess", preprocess)
])

# %%
#Custom preprocessor function 
#This custom preprocessor allows for customisation of columns used in the pipeline
#Takes the input of a list of numerical and categorical variables to be used in the model

def create_custom_preprocessor(num_var,cat_var, interact_var=None):
    numeric= [col for col in num_var if col in numeric_features] 
    categorical=[ col for col in cat_var if col in categorical_features]

    transformer=[]
    if numeric:
        transformer.append(("num", StandardScaler(), numeric)) #scale numeric variables
    if categorical:
        transformer.append(("cat", OneHotEncoder(handle_unknown="ignore"), categorical)) #one-hot encoding for categorical
    
    if interact_var: #option for interaction variables 
        for i,group in enumerate(interact_var):
            name=f'interaction group {i}'

            interaction_step = Pipeline([
                ("select", ColumnTransformer([("keep", "passthrough", group)])),
                ("std", StandardScaler()), # Scale before multiplying
                ("poly", PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)) #combine interaction variables
            ])
            transformer.append((name, interaction_step, group))
    
    return ColumnTransformer(
        transformers=transformer,
        remainder="drop"
    )

# %%
#Implementing custom model pipelines
#Each model implemented uses its own set of numerical and categorical variables 

from sklearn.linear_model import Lasso

#Lasso model pipeline
lasso_num=['total_floor_area','london_zone','average_income','co2_emissions_current','co2_emissions_potential']
lasso_cat=[ "property_type", "freehold_or_leasehold",'cluster_geo','cluster_energy']

lasso_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=lasso_num, 
        cat_var=lasso_cat
    )),
    ("regressor", Lasso(alpha=0.01, random_state=1,max_iter=5000))
])


#Elastic Net model pipeline for houses
from sklearn.linear_model import ElasticNet
en_num = ['co2_emissions_current','co2_emissions_potential','average_income','energy_consumption_potential',"num_tube_lines","distance_to_station","london_zone", "total_floor_area"]
en_cat = ['cluster_geo','cluser_energy','current_energy_rating', "property_type", "freehold_or_leasehold"]

en_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=en_num, 
        cat_var=en_cat
    )),
    ("regressor", ElasticNet(alpha=0.001, l1_ratio=0,random_state=101,max_iter=5000))
])

#KNN model pipeline for geographical data
from sklearn.neighbors import KNeighborsRegressor

knn_num=['average_income','longitude','latitude','distance_to_station','london_zone']
knn_cat=['district','property_type','cluster_geo']

knn_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=knn_num, 
        cat_var=knn_cat
    )),
    ("regressor", KNeighborsRegressor(n_neighbors=5,n_jobs=-1))
])

#KNN model pipeline for physical property features

knn_num2=['co2_emissions_current','co2_emissions_potential','number_habitable_rooms',"total_floor_area"]
knn_cat2=['current_energy_rating',"water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

knn_pipe2= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=knn_num2, 
        cat_var=knn_cat2
    )),
    ("regressor", KNeighborsRegressor(n_neighbors=5,n_jobs=-1))
])

#KNN all model
knn_num3=['average_income','number_habitable_rooms',"distance_to_station","london_zone", "total_floor_area"]
knn_cat3=['cluster_energy','cluster_geo','current_energy_rating', "property_type", "whether_old_or_new"]

knn_pipe3= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=knn_num3, 
        cat_var=knn_cat3
    )),
    ("regressor", KNeighborsRegressor(n_neighbors=5,n_jobs=-1))
])

#Random forest model pipeline for overview 
from sklearn.ensemble import RandomForestRegressor

rf_num = ['co2_emissions_current','co2_emissions_potential','average_income','number_habitable_rooms','energy_consumption_potential',"num_tube_lines","distance_to_station", "latitude", "longitude","london_zone", "total_floor_area"]
rf_cat = ['cluster_energy','cluster_geo','district','current_energy_rating',"water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

rf_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=rf_num, 
        cat_var=rf_cat
    )),
    ("regressor", RandomForestRegressor(n_estimators=100, max_depth=3,min_samples_split=2,random_state=1001))
])


#Gradient Boosting model pipeline
from sklearn.ensemble import GradientBoostingRegressor
gbm_num = ['co2_emissions_current','co2_emissions_potential','average_income','number_habitable_rooms','energy_consumption_potential',"num_tube_lines","distance_to_station", "latitude", "longitude","london_zone", "total_floor_area"]
gbm_cat = ['cluster_energy','cluster_geo','district','current_energy_rating',"water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

gbm_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=gbm_num, 
        cat_var=gbm_cat
    )),
    ("regressor", GradientBoostingRegressor(n_estimators=100, learning_rate=0.01,min_samples_split=2,max_depth=3,random_state=10001))
])

#XGBoost pipeline
from xgboost import XGBRegressor

xgb_num = ['co2_emissions_current','co2_emissions_potential','average_income','number_habitable_rooms','energy_consumption_potential',"num_tube_lines","distance_to_station", "latitude", "longitude","london_zone", "total_floor_area"]
xgb_cat = ['cluster_energy','cluster_geo','district','current_energy_rating',"water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

xgb_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=xgb_num, 
        cat_var=xgb_cat
    )),
    ("regressor",XGBRegressor(n_estimators=100, learning_rate=0.01,max_depth=3,tree_method='exact' ,random_state=100001))
])

#Catboost pipeline- take categorical variables only
from catboost import CatBoostRegressor
cat_num=[]
cat_cat=['cluster_energy','cluster_geo','district','current_energy_rating',"water_company", "property_type", "whether_old_or_new", "freehold_or_leasehold"]

cat_pipe= Pipeline(steps=[
    ("preprocess", create_custom_preprocessor(
        num_var=cat_num, 
        cat_var=cat_cat
    )),
    ("regressor",CatBoostRegressor(learning_rate=0.01,depth=3,random_state=1000001))
])

# %%
#Transform y variables using log1p
#fitting and transforming y train
Ytrain2=y_transformer.fit_transform(y_train.values.reshape(-1, 1))

#Transforming y test using the log transformation fitted on y train to avoid data leakage 
Ytest2=y_transformer.transform(y_test.values.reshape(-1,1))

#feature_names = preprocess.get_feature_names_out()

# %%
#Defining a function to print model performance metrics 

def linear_metrics(model,X_test,Y_test):
    #Predict price using model
    pred=model.predict(X_test)

    #Get RMSE
    rmse=mean_squared_error(Y_test,pred)
    rmse=np.sqrt(rmse).astype(float)

    #Get R squared
    r2 = r2_score(Y_test, pred)

    #Gather metrics as a dictionary 
    lr_results = {"RMSE": rmse, "Rsquare": r2}

    #Print dictionary
    print("lr_results:", lr_results)

# %%
#Lasso model 

#Defining lasso parameters to tune
lasso_grid={'regressor__alpha':np.arange(0.01,0.5,0.01)}

#Grid search to tune parameters, scoring on RMSE 
lasso=GridSearchCV(
    lasso_pipe,
    param_grid=lasso_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1
)

#Fitting lasso model 
lasso.fit(X_train, Ytrain2)

#Getting best estimator 
lasso_best=lasso.best_estimator_

lasso_model = lasso_best.named_steps['regressor']

#Getting coefficients 
coef=pd.DataFrame({'Features':lasso_best.named_steps['preprocess'].get_feature_names_out(),'Coefficients':lasso_model.coef_,'Absolute_Coefficient': np.abs(lasso_model.coef_)})

#Get model performance on test set
linear_metrics(lasso_best,X_test,Ytest2)

coef.sort_values(by='Absolute_Coefficient',ascending=False)
# Out:
# lr_results: {'RMSE': np.float64(0.28781996778925606), 'Rsquare': 0.7281380923802536}
#                         Features  Coefficients  Absolute_Coefficient
# 0          num__total_floor_area  3.205005e-01          3.205005e-01
# 1               num__london_zone -1.818402e-01          1.818402e-01
# 2            num__average_income  1.254232e-01          1.254232e-01
# 9   cat__freehold_or_leasehold_F  8.910838e-02          8.910838e-02
# 6           cat__property_type_F -6.476857e-02          6.476857e-02
# 3     num__co2_emissions_current  1.566064e-02          1.566064e-02
# 10  cat__freehold_or_leasehold_L -1.470536e-15          1.470536e-15
# 4   num__co2_emissions_potential  0.000000e+00          0.000000e+00
# 5           cat__property_type_D  0.000000e+00          0.000000e+00
# 7           cat__property_type_S  0.000000e+00          0.000000e+00
# 8           cat__property_type_T  0.000000e+00          0.000000e+00
# 11            cat__cluster_geo_1  0.000000e+00          0.000000e+00
# 12            cat__cluster_geo_2 -0.000000e+00          0.000000e+00
# 13         cat__cluster_energy_1 -0.000000e+00          0.000000e+00
# 14         cat__cluster_energy_2  0.000000e+00          0.000000e+00
# 15         cat__cluster_energy_3  0.000000e+00          0.000000e+00

# %%
#Elastic Net model 
#Determining parameters to tune
param_en={'regressor__alpha':np.arange(0.01,0.5,0.01),
                'regressor__l1_ratio':[0,0.5,1]}

#Grid search on parameters 
en_model=GridSearchCV(
    en_pipe,
    param_grid=param_en,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1
)

#Fitting the model
en_model.fit(X_train, Ytrain2)

#Getting the best model
en_best=en_model.best_estimator_
en_model=en_best.named_steps['regressor']

#Print performance metrics
linear_metrics(en_best,X_test,Ytest2)
# Out:
# python(94844) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94845) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94846) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94847) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94848) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94849) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94850) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(94851) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# lr_results: {'RMSE': np.float64(0.27361038752402245), 'Rsquare': 0.7543189373679291}

# %%
#Feature importance plot for elastic net
r = permutation_importance(en_best, X_test, Ytest2, n_repeats=10, random_state=42)
# Retrieve feature names after preprocessing
feature_names=en_best.named_steps['preprocess'].get_feature_names_out()

importances = r.importances_mean
# Basic bar plot
plt.figure()
order = np.argsort(importances)
plt.barh(np.array(feature_names)[order], importances[order])
plt.title("Permutation Importance (Elastic Net)")
plt.tight_layout()
plt.show()

# %%
#KNN model on geography related features

#Defining parameters to tune
knn_grid={'regressor__n_neighbors':range(5,51,1)}

#Grid search on parameters
knn=GridSearchCV(
    knn_pipe,
    param_grid=knn_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

#Fitting the model 
knn.fit(X_train, Ytrain2)

knn_best=knn.best_estimator_

#Performance metrics
linear_metrics(knn_best,X_test,Ytest2)
# Out:
# KNeighborsRegressor(n_jobs=-1, n_neighbors=10)
# lr_results: {'RMSE': np.float64(0.33155055555263935), 'Rsquare': 0.6392502495084822}

# %%
#KNN model with physical property features
#Parameters to tune
knn_grid2={'regressor__n_neighbors':range(5,51,1)}

knn2=GridSearchCV(
    knn_pipe2,
    param_grid=knn_grid2,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

knn2.fit(X_train, Ytrain2)

knn_best2=knn2.best_estimator_

linear_metrics(knn_best2,X_test,Ytest2)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['co2_emissions_current',
#                                                    'co2_emissions_potential',
#                                                    'number_habitable_rooms',
#                                                    'total_floor_area']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['current_energy_rating',
#                                                    'water_company',
#                                                    'property_type',
#                                                    'whether_old_or_new',
#                                                    'freehold_or_leasehold'])])),
#                 ('regressor', KNeighborsRegressor(n_jobs=-1, n_neighbors=21))])
# lr_results: {'RMSE': np.float64(0.3384505788814215), 'Rsquare': 0.6240786064488556}

# %%
#KNN model with all features
knn_grid3={'regressor__n_neighbors':range(5,51,1)}

knn3=GridSearchCV(
    knn_pipe3,
    param_grid=knn_grid3,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

knn3.fit(X_train, Ytrain2)

knn_best3=knn3.best_estimator_


linear_metrics(knn_best3,X_test,Ytest2)
# Out:
# lr_results: {'RMSE': np.float64(0.27371905555638226), 'Rsquare': 0.7541237475611663}

# %%
#Tree based model

#Getting parameters to tune
param_grid_rf={
    'regressor__n_estimators':[100,200],
    'regressor__max_depth':[10,20],
    'regressor__min_samples_split':[2,5]
}

#Grid search on parameters
rf=GridSearchCV(
    rf_pipe,
    param_grid=param_grid_rf,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1
)

#Fitting the tree model
rf.fit(X_train,Ytrain2)

#Getting the best model
rf_best=rf.best_estimator_
rf_model=rf_best.named_steps['regressor']

#Performance metrics
linear_metrics(rf_best,X_test,Ytest2)

#Extracting feature importance
feature_importance_rf = pd.DataFrame({
    'Feature': rf_best.named_steps['preprocess'].get_feature_names_out(),
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False).reset_index()

feature_importance_rf.head(10)
# Out:
# lr_results: {'RMSE': np.float64(0.21704812672459897), 'Rsquare': 0.8453967556581875}
#    index                            Feature  Importance
# 0     10              num__total_floor_area    0.566660
# 1      9                   num__london_zone    0.153121
# 2      2                num__average_income    0.067577
# 3      8                     num__longitude    0.054882
# 4      7                      num__latitude    0.032671
# 5      3        num__number_habitable_rooms    0.019136
# 6      6           num__distance_to_station    0.015208
# 7      0         num__co2_emissions_current    0.014286
# 8      4  num__energy_consumption_potential    0.011477
# 9      1       num__co2_emissions_potential    0.009043

# %%
#Barplot for feature importance 
sns.barplot(data=feature_importance_rf.head(10),x='Importance',y='Feature')
plt.title('Feature Importance (Random Forest)')
plt.show()

# %%
#Gradient Boosting model

#Parameters to tune, slow learner with lower learning rate 
gbm_grid={'regressor__n_estimators':[100,200,250],
          'regressor__learning_rate':[0.01,0.05],
          'regressor__max_depth':[3,7,15],
          'regressor__min_samples_split':[10,15]
          }

#Grid search on parameters
gbm=GridSearchCV(
    gbm_pipe,
    param_grid=gbm_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

#Fitting model
gbm.fit(X_train,Ytrain2)

#Getting best model
gbm_best=gbm.best_estimator_
gbm_model=gbm_best.named_steps['regressor']

#Performance metrics
linear_metrics(gbm_best,X_test,Ytest2)

#Extracting feature importance
feature_importance_gbm = pd.DataFrame({
    'Feature': gbm_best.named_steps['preprocess'].get_feature_names_out(),
    'Importance': gbm_model.feature_importances_
}).sort_values('Importance', ascending=False).reset_index()

feature_importance_gbm.head(10)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_depth=7, min_samples_split=15,
#                           n_estimators=250, random_state=10001)
# lr_results: {'RMSE': np.float64(0.2094158216473949), 'Rsquare': 0.85607855866617}
#    index                       Feature  Importance
# 0     10         num__total_floor_area    0.584094
# 1      9              num__london_zone    0.157542
# 2      2           num__average_income    0.063281
# 3      8                num__longitude    0.057572
# 4      7                 num__latitude    0.034414
# 5      3   num__number_habitable_rooms    0.016876
# 6      0    num__co2_emissions_current    0.009001
# 7      6      num__distance_to_station    0.008224
# 8     61          cat__property_type_F    0.007696
# 9     66  cat__freehold_or_leasehold_F    0.007110

# %%
#Feature importance bar plot
sns.barplot(data=feature_importance_gbm.head(10),x='Importance',y='Feature')
plt.title('Feature Importance (GBM)')
plt.show()

# %%
#Gradient Boosting model (No log transformation)

gbm2=GridSearchCV(
    gbm_pipe,
    param_grid=gbm_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

gbm2.fit(X_train,y_train)

gbm_best2=gbm2.best_estimator_
gbm_model2=gbm_best2.named_steps['regressor']


linear_metrics(gbm_best2,X_test,y_test)


feature_importance_gbm2 = pd.DataFrame({
    'Feature': gbm_best2.named_steps['preprocess'].get_feature_names_out(),
    'Importance': gbm_model2.feature_importances_
}).sort_values('Importance', ascending=False).reset_index()

feature_importance_gbm2.head(10)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_depth=7, min_samples_split=15,
#                           n_estimators=250, random_state=10001)
# lr_results: {'RMSE': np.float64(234629.48237542706), 'Rsquare': 0.8309768323014265}
#    index                               Feature  Importance
# 0     10                 num__total_floor_area    0.543015
# 1      9                      num__london_zone    0.253079
# 2      8                        num__longitude    0.051266
# 3      2                   num__average_income    0.035770
# 4      7                         num__latitude    0.023078
# 5     35  cat__district_Kensington and Chelsea    0.022619
# 6      6              num__distance_to_station    0.009004
# 7      1          num__co2_emissions_potential    0.008947
# 8      0            num__co2_emissions_current    0.007992
# 9     48             cat__district_Westminster    0.005178

# %%
#Feature importance barplot for GBM on untransformed price
sns.barplot(data=feature_importance_gbm2.head(10),x='Importance',y='Feature')
plt.title('Feature Importance (GBM on Untransformed Price)')
plt.show()

# %%
#XGBoost model
#Tuning parameters
xgb_grid={'regressor__n_estimators':[100,200,250],
          'regressor__learning_rate':[0.01,0.05],
          'regressor__max_depth':[3,7,15],
          }

#Grid search 
xgb=GridSearchCV(
    xgb_pipe,
    param_grid=xgb_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

#Fitting the model
xgb.fit(X_train,Ytrain2)

#getting the best estimator
xgb_best=xgb.best_estimator_
xgb_model=xgb_best.named_steps['regressor']

#performance metrics
linear_metrics(xgb_best,X_test,Ytest2)

#Extracting feature importance
feature_importance_xgb = pd.DataFrame({
    'Feature': xgb_best.named_steps['preprocess'].get_feature_names_out(),
    'Importance': xgb_model.feature_importances_
}).sort_values('Importance', ascending=False).reset_index()

feature_importance_xgb.head(10)
# Out:
# python(89713) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(89714) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# lr_results: {'RMSE': np.float64(0.20839080097675552), 'Rsquare': 0.8574840056331905}
#    index                               Feature  Importance
# 0     10                 num__total_floor_area    0.257261
# 1      9                      num__london_zone    0.224660
# 2     66          cat__freehold_or_leasehold_F    0.044944
# 3     14                    cat__cluster_geo_1    0.032020
# 4     35  cat__district_Kensington and Chelsea    0.029449
# 5      2                   num__average_income    0.023468
# 6     61                  cat__property_type_F    0.023029
# 7     42    cat__district_Richmond upon Thames    0.020788
# 8     59       cat__water_company_Thames Water    0.019166
# 9      3           num__number_habitable_rooms    0.018438

# %%
#Plotting feature importance
sns.barplot(data=feature_importance_xgb.head(10),x='Importance',y='Feature')
plt.title('Feature Importance (XGBoost)')
plt.show()

# %%
#Catboost model
#Parameters to tune
cat_grid={
          'regressor__learning_rate':[0.01,0.05],
          'regressor__depth':[3,7]
          }

#Conduct grid search
cat=GridSearchCV(
    cat_pipe,
    param_grid=cat_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1)

#Fitting the model
cat.fit(X_train,Ytrain2)

#Getting best estimtator
cat_best=cat.best_estimator_
cat_model=cat_best.named_steps['regressor']

#Perofrmance metrics
linear_metrics(cat_best,X_test,Ytest2)

#Extracting feature importance
feature_importance_cat = pd.DataFrame({
    'Feature': cat_best.named_steps['preprocess'].get_feature_names_out(),
    'Importance': cat_model.feature_importances_
}).sort_values('Importance', ascending=False).reset_index()

feature_importance_cat.head(10)
# Out:
# python(89784) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 0:	learn: 0.5429384	total: 71.3ms	remaining: 1m 11s
# 0:	learn: 0.5445082	total: 71.4ms	remaining: 1m 11s
# 0:	learn: 0.5390468	total: 71.4ms	remaining: 1m 11s
# 1:	learn: 0.5420224	total: 72.3ms	remaining: 36.1s
# 1:	learn: 0.5404986	total: 72.5ms	remaining: 36.2s
# 1:	learn: 0.5366185	total: 72.5ms	remaining: 36.2s
# 2:	learn: 0.5380927	total: 73.2ms	remaining: 24.3s
# 2:	learn: 0.5342332	total: 73.5ms	remaining: 24.4s
# 2:	learn: 0.5395813	total: 73.5ms	remaining: 24.4s
# 3:	learn: 0.5357237	total: 74.3ms	remaining: 18.5s
# 3:	learn: 0.5318847	total: 74.4ms	remaining: 18.5s
# 3:	learn: 0.5375315	total: 74.5ms	remaining: 18.5s
# 4:	learn: 0.5295659	total: 75.2ms	remaining: 15s
# 4:	learn: 0.5333939	total: 75.2ms	remaining: 15s
# 4:	learn: 0.5351474	total: 75.5ms	remaining: 15s
# 5:	learn: 0.5272891	total: 76.1ms	remaining: 12.6s
# 5:	learn: 0.5310972	total: 76.1ms	remaining: 12.6s
# 5:	learn: 0.5328071	total: 76.6ms	remaining: 12.7s
# 6:	learn: 0.5250477	total: 76.8ms	remaining: 10.9s
# 6:	learn: 0.5288360	total: 77.1ms	remaining: 10.9s
# 7:	learn: 0.5228345	total: 77.5ms	remaining: 9.61s
# 6:	learn: 0.5305029	total: 77.6ms	remaining: 11s
# 7:	learn: 0.5266101	total: 78.1ms	remaining: 9.69s
# 8:	learn: 0.5209450	total: 78.1ms	remaining: 8.6s
# 7:	learn: 0.5282268	total: 78.4ms	remaining: 9.73s
# 8:	learn: 0.5247187	total: 79ms	remaining: 8.7s
# 9:	learn: 0.5187918	total: 79ms	remaining: 7.82s
# 8:	learn: 0.5263116	total: 79.2ms	remaining: 8.72s
# 10:	learn: 0.5169579	total: 79.6ms	remaining: 7.16s
# 9:	learn: 0.5240962	total: 80.1ms	remaining: 7.92s
# 9:	learn: 0.5225548	total: 80.2ms	remaining: 7.94s
# 11:	learn: 0.5148630	total: 80.3ms	remaining: 6.61s
# 10:	learn: 0.5222373	total: 81ms	remaining: 7.28s
# 10:	learn: 0.5207129	total: 81ms	remaining: 7.29s
# 12:	learn: 0.5128067	total: 81.3ms	remaining: 6.17s
# 11:	learn: 0.5186074	total: 81.8ms	remaining: 6.74s
# 11:	learn: 0.5200810	total: 82.1ms	remaining: 6.76s
# 13:	learn: 0.5107829	total: 82.1ms	remaining: 5.78s
# 14:	learn: 0.5087852	total: 82.8ms	remaining: 5.43s
# 12:	learn: 0.5165325	total: 82.8ms	remaining: 6.29s
# 12:	learn: 0.5179649	total: 83.3ms	remaining: 6.33s
# 13:	learn: 0.5147681	total: 83.5ms	remaining: 5.88s
# 15:	learn: 0.5068193	total: 83.6ms	remaining: 5.14s
# 16:	learn: 0.5048849	total: 84.3ms	remaining: 4.87s
# 14:	learn: 0.5127518	total: 84.4ms	remaining: 5.54s
# 13:	learn: 0.5158822	total: 84.5ms	remaining: 5.95s
# 17:	learn: 0.5031370	total: 85.2ms	remaining: 4.65s
# 15:	learn: 0.5107675	total: 85.2ms	remaining: 5.24s
# 14:	learn: 0.5138253	total: 85.5ms	remaining: 5.61s
# 18:	learn: 0.5012633	total: 85.9ms	remaining: 4.44s
# 16:	learn: 0.5088149	total: 86.1ms	remaining: 4.98s
# 15:	learn: 0.5118011	total: 86.4ms	remaining: 5.32s
# 19:	learn: 0.4995686	total: 86.6ms	remaining: 4.24s
# 17:	learn: 0.5070582	total: 87.1ms	remaining: 4.75s
# 20:	learn: 0.4977447	total: 87.2ms	remaining: 4.07s
# 16:	learn: 0.5098091	total: 87.6ms	remaining: 5.06s
# 21:	learn: 0.4959546	total: 87.9ms	remaining: 3.9s
# 18:	learn: 0.5051587	total: 88.1ms	remaining: 4.55s
# 17:	learn: 0.5080467	total: 88.5ms	remaining: 4.83s
# 22:	learn: 0.4943828	total: 88.7ms	remaining: 3.77s
# 19:	learn: 0.5034552	total: 88.9ms	remaining: 4.36s
# 18:	learn: 0.5061174	total: 89.3ms	remaining: 4.61s
# 23:	learn: 0.4926438	total: 89.4ms	remaining: 3.64s
# 20:	learn: 0.5016137	total: 90ms	remaining: 4.2s
# 24:	learn: 0.4909332	total: 90.1ms	remaining: 3.52s
# 19:	learn: 0.5044087	total: 90.3ms	remaining: 4.42s
# 25:	learn: 0.4894401	total: 90.8ms	remaining: 3.4s
# 20:	learn: 0.5025293	total: 91.2ms	remaining: 4.25s
# 21:	learn: 0.4997984	total: 91.2ms	remaining: 4.05s
# 26:	learn: 0.4879569	total: 91.5ms	remaining: 3.3s
# 22:	learn: 0.4982164	total: 92.1ms	remaining: 3.91s
# 21:	learn: 0.5006853	total: 92.4ms	remaining: 4.11s
# 27:	learn: 0.4863102	total: 92.5ms	remaining: 3.21s
# 23:	learn: 0.4964527	total: 93ms	remaining: 3.78s
# 28:	learn: 0.4846953	total: 93.3ms	remaining: 3.13s
# 22:	learn: 0.4990703	total: 93.4ms	remaining: 3.97s
# 24:	learn: 0.4947177	total: 93.8ms	remaining: 3.66s
# 23:	learn: 0.4972785	total: 94.5ms	remaining: 3.84s
# 29:	learn: 0.4831071	total: 94.4ms	remaining: 3.05s
# 25:	learn: 0.4932263	total: 94.5ms	remaining: 3.54s
# 30:	learn: 0.4816599	total: 95.3ms	remaining: 2.98s
# 26:	learn: 0.4917332	total: 95.3ms	remaining: 3.44s
# 24:	learn: 0.4955158	total: 95.6ms	remaining: 3.73s
# 31:	learn: 0.4802876	total: 96.1ms	remaining: 2.91s
# 27:	learn: 0.4900703	total: 96.5ms	remaining: 3.35s
# 25:	learn: 0.4937757	total: 96.7ms	remaining: 3.62s
# 32:	learn: 0.4787655	total: 96.7ms	remaining: 2.83s
# 26:	learn: 0.4922525	total: 97.9ms	remaining: 3.53s
# 33:	learn: 0.4774218	total: 97.7ms	remaining: 2.78s
# 28:	learn: 0.4884316	total: 98.7ms	remaining: 3.31s
# 27:	learn: 0.4905620	total: 99.1ms	remaining: 3.44s
# 34:	learn: 0.4759440	total: 99.1ms	remaining: 2.73s
# 29:	learn: 0.4868200	total: 99.8ms	remaining: 3.23s
# 35:	learn: 0.4746495	total: 100ms	remaining: 2.68s
# 28:	learn: 0.4889046	total: 101ms	remaining: 3.37s
# 30:	learn: 0.4853580	total: 101ms	remaining: 3.17s
# 29:	learn: 0.4872744	total: 102ms	remaining: 3.3s
# 36:	learn: 0.4733153	total: 102ms	remaining: 2.64s
# 31:	learn: 0.4839871	total: 102ms	remaining: 3.09s
# 37:	learn: 0.4718939	total: 102ms	remaining: 2.59s
# 32:	learn: 0.4824419	total: 103ms	remaining: 3.01s
# 30:	learn: 0.4858553	total: 103ms	remaining: 3.22s
# 38:	learn: 0.4706554	total: 103ms	remaining: 2.53s
# 33:	learn: 0.4810889	total: 104ms	remaining: 2.94s
# 31:	learn: 0.4844583	total: 104ms	remaining: 3.15s
# 39:	learn: 0.4692747	total: 104ms	remaining: 2.49s
# 34:	learn: 0.4795885	total: 105ms	remaining: 2.88s
# 35:	learn: 0.4782896	total: 105ms	remaining: 2.81s
# 32:	learn: 0.4828925	total: 105ms	remaining: 3.09s
# 40:	learn: 0.4680185	total: 105ms	remaining: 2.45s
# 36:	learn: 0.4769466	total: 106ms	remaining: 2.76s
# 33:	learn: 0.4815125	total: 106ms	remaining: 3.02s
# 41:	learn: 0.4668328	total: 106ms	remaining: 2.42s
# 37:	learn: 0.4755102	total: 107ms	remaining: 2.71s
# 34:	learn: 0.4799920	total: 107ms	remaining: 2.95s
# 42:	learn: 0.4656670	total: 107ms	remaining: 2.38s
# 35:	learn: 0.4786734	total: 108ms	remaining: 2.9s
# 38:	learn: 0.4742492	total: 108ms	remaining: 2.67s
# 43:	learn: 0.4645215	total: 108ms	remaining: 2.34s
# 39:	learn: 0.4728548	total: 109ms	remaining: 2.62s
# 44:	learn: 0.4632353	total: 109ms	remaining: 2.31s
# 36:	learn: 0.4773254	total: 109ms	remaining: 2.85s
# 40:	learn: 0.4715879	total: 110ms	remaining: 2.57s
# 45:	learn: 0.4619661	total: 110ms	remaining: 2.28s
# 37:	learn: 0.4758615	total: 111ms	remaining: 2.8s
# 41:	learn: 0.4703991	total: 111ms	remaining: 2.53s
# 42:	learn: 0.4692302	total: 112ms	remaining: 2.49s
# 38:	learn: 0.4745992	total: 112ms	remaining: 2.75s
# 46:	learn: 0.4607186	total: 111ms	remaining: 2.25s
# 39:	learn: 0.4731767	total: 112ms	remaining: 2.7s
# 47:	learn: 0.4596374	total: 112ms	remaining: 2.22s
# 43:	learn: 0.4680763	total: 113ms	remaining: 2.46s
# 40:	learn: 0.4719076	total: 113ms	remaining: 2.65s
# 48:	learn: 0.4585745	total: 113ms	remaining: 2.19s
# 44:	learn: 0.4667694	total: 114ms	remaining: 2.42s
# 41:	learn: 0.4706983	total: 115ms	remaining: 2.61s
# 49:	learn: 0.4574962	total: 114ms	remaining: 2.17s
# 45:	learn: 0.4654871	total: 115ms	remaining: 2.39s
# 42:	learn: 0.4695093	total: 116ms	remaining: 2.57s
# 50:	learn: 0.4563150	total: 115ms	remaining: 2.14s
# 46:	learn: 0.4642267	total: 116ms	remaining: 2.35s
# 43:	learn: 0.4683410	total: 117ms	remaining: 2.54s
# 51:	learn: 0.4552986	total: 116ms	remaining: 2.11s
# 47:	learn: 0.4631426	total: 117ms	remaining: 2.33s
# 44:	learn: 0.4670146	total: 118ms	remaining: 2.5s
# 48:	learn: 0.4620768	total: 118ms	remaining: 2.3s
# 52:	learn: 0.4542680	total: 117ms	remaining: 2.09s
# 45:	learn: 0.4657053	total: 118ms	remaining: 2.46s
# 49:	learn: 0.4609939	total: 119ms	remaining: 2.26s
# 53:	learn: 0.4531361	total: 118ms	remaining: 2.07s
# 46:	learn: 0.4644182	total: 120ms	remaining: 2.42s
# 50:	learn: 0.4598002	total: 120ms	remaining: 2.24s
# 47:	learn: 0.4633145	total: 121ms	remaining: 2.4s
# 54:	learn: 0.4520237	total: 120ms	remaining: 2.06s
# 51:	learn: 0.4587655	total: 122ms	remaining: 2.22s
# 55:	learn: 0.4509307	total: 121ms	remaining: 2.03s
# 48:	learn: 0.4622295	total: 122ms	remaining: 2.37s
# 52:	learn: 0.4577318	total: 123ms	remaining: 2.19s
# 56:	learn: 0.4498567	total: 122ms	remaining: 2.01s
# 49:	learn: 0.4611181	total: 123ms	remaining: 2.34s
# 53:	learn: 0.4565850	total: 124ms	remaining: 2.17s
# 57:	learn: 0.4488014	total: 122ms	remaining: 1.99s
# 50:	learn: 0.4598984	total: 124ms	remaining: 2.31s
# 58:	learn: 0.4478670	total: 123ms	remaining: 1.96s
# 54:	learn: 0.4554580	total: 125ms	remaining: 2.14s
# 59:	learn: 0.4469603	total: 124ms	remaining: 1.94s
# 51:	learn: 0.4588549	total: 125ms	remaining: 2.28s
# 55:	learn: 0.4543506	total: 126ms	remaining: 2.12s
# 60:	learn: 0.4459473	total: 125ms	remaining: 1.92s
# 56:	learn: 0.4532624	total: 127ms	remaining: 2.09s
# 52:	learn: 0.4577937	total: 127ms	remaining: 2.26s
# 61:	learn: 0.4450135	total: 126ms	remaining: 1.9s
# 57:	learn: 0.4521889	total: 128ms	remaining: 2.07s
# 53:	learn: 0.4566217	total: 128ms	remaining: 2.24s
# 62:	learn: 0.4440983	total: 127ms	remaining: 1.89s
# 58:	learn: 0.4511382	total: 129ms	remaining: 2.06s
# 54:	learn: 0.4554698	total: 129ms	remaining: 2.21s
# 63:	learn: 0.4432179	total: 128ms	remaining: 1.87s
# 59:	learn: 0.4502203	total: 130ms	remaining: 2.03s
# 64:	learn: 0.4423702	total: 129ms	remaining: 1.85s
# 55:	learn: 0.4543380	total: 130ms	remaining: 2.19s
# 60:	learn: 0.4492003	total: 131ms	remaining: 2.01s
# 65:	learn: 0.4415393	total: 129ms	remaining: 1.83s
# 61:	learn: 0.4482552	total: 132ms	remaining: 1.99s
# 56:	learn: 0.4532257	total: 132ms	remaining: 2.17s
# 66:	learn: 0.4407099	total: 130ms	remaining: 1.81s
# 62:	learn: 0.4473236	total: 133ms	remaining: 1.97s
# 57:	learn: 0.4521328	total: 133ms	remaining: 2.16s
# 67:	learn: 0.4397866	total: 131ms	remaining: 1.8s
# 63:	learn: 0.4464389	total: 134ms	remaining: 1.96s
# 68:	learn: 0.4389870	total: 132ms	remaining: 1.79s
# 58:	learn: 0.4510588	total: 134ms	remaining: 2.14s
# 69:	learn: 0.4380938	total: 133ms	remaining: 1.77s
# 64:	learn: 0.4455340	total: 135ms	remaining: 1.94s
# 59:	learn: 0.4501279	total: 135ms	remaining: 2.11s
# 65:	learn: 0.4446966	total: 136ms	remaining: 1.92s
# 70:	learn: 0.4372144	total: 134ms	remaining: 1.76s
# 60:	learn: 0.4490851	total: 136ms	remaining: 2.09s
# 66:	learn: 0.4438489	total: 137ms	remaining: 1.91s
# 71:	learn: 0.4364150	total: 135ms	remaining: 1.75s
# 61:	learn: 0.4480606	total: 137ms	remaining: 2.07s
# 67:	learn: 0.4429241	total: 138ms	remaining: 1.89s
# 62:	learn: 0.4471323	total: 138ms	remaining: 2.05s
# 72:	learn: 0.4356640	total: 136ms	remaining: 1.73s
# 68:	learn: 0.4421286	total: 138ms	remaining: 1.87s
# 63:	learn: 0.4462251	total: 139ms	remaining: 2.03s
# 69:	learn: 0.4412276	total: 139ms	remaining: 1.85s
# 73:	learn: 0.4348206	total: 137ms	remaining: 1.72s
# 64:	learn: 0.4452476	total: 140ms	remaining: 2.01s
# 70:	learn: 0.4403467	total: 140ms	remaining: 1.83s
# 74:	learn: 0.4340928	total: 139ms	remaining: 1.71s
# 65:	learn: 0.4443930	total: 141ms	remaining: 1.99s
# 71:	learn: 0.4395321	total: 141ms	remaining: 1.82s
# 75:	learn: 0.4332727	total: 140ms	remaining: 1.7s
# 72:	learn: 0.4387745	total: 142ms	remaining: 1.8s
# 66:	learn: 0.4435260	total: 142ms	remaining: 1.97s
# 76:	learn: 0.4325675	total: 141ms	remaining: 1.68s
# 73:	learn: 0.4380445	total: 143ms	remaining: 1.78s
# 67:	learn: 0.4425869	total: 143ms	remaining: 1.95s
# 77:	learn: 0.4317717	total: 141ms	remaining: 1.67s
# 74:	learn: 0.4373075	total: 143ms	remaining: 1.77s
# 68:	learn: 0.4417835	total: 144ms	remaining: 1.94s
# 75:	learn: 0.4365303	total: 144ms	remaining: 1.75s
# 78:	learn: 0.4310386	total: 142ms	remaining: 1.66s
# 76:	learn: 0.4358160	total: 145ms	remaining: 1.73s
# 69:	learn: 0.4408750	total: 145ms	remaining: 1.92s
# 79:	learn: 0.4303464	total: 143ms	remaining: 1.65s
# 77:	learn: 0.4350093	total: 145ms	remaining: 1.72s
# 78:	learn: 0.4342635	total: 146ms	remaining: 1.7s
# 70:	learn: 0.4400794	total: 146ms	remaining: 1.91s
# 80:	learn: 0.4296826	total: 144ms	remaining: 1.63s
# 79:	learn: 0.4335276	total: 147ms	remaining: 1.69s
# 81:	learn: 0.4289302	total: 145ms	remaining: 1.62s
# 71:	learn: 0.4392613	total: 147ms	remaining: 1.89s
# 80:	learn: 0.4328481	total: 148ms	remaining: 1.67s
# 72:	learn: 0.4384904	total: 148ms	remaining: 1.88s
# 81:	learn: 0.4321351	total: 148ms	remaining: 1.66s
# 82:	learn: 0.4281899	total: 146ms	remaining: 1.61s
# 73:	learn: 0.4376273	total: 149ms	remaining: 1.86s
# 82:	learn: 0.4313764	total: 149ms	remaining: 1.65s
# 83:	learn: 0.4275000	total: 147ms	remaining: 1.6s
# 74:	learn: 0.4368799	total: 149ms	remaining: 1.84s
# 83:	learn: 0.4306830	total: 150ms	remaining: 1.64s
# 84:	learn: 0.4300380	total: 151ms	remaining: 1.62s
# 84:	learn: 0.4268518	total: 148ms	remaining: 1.6s
# 75:	learn: 0.4361057	total: 151ms	remaining: 1.83s
# 85:	learn: 0.4294127	total: 151ms	remaining: 1.61s
# 85:	learn: 0.4262164	total: 149ms	remaining: 1.59s
# 86:	learn: 0.4287491	total: 152ms	remaining: 1.59s
# 76:	learn: 0.4353817	total: 152ms	remaining: 1.82s
# 86:	learn: 0.4255575	total: 150ms	remaining: 1.57s
# 87:	learn: 0.4280299	total: 153ms	remaining: 1.58s
# 87:	learn: 0.4248619	total: 151ms	remaining: 1.57s
# 77:	learn: 0.4345595	total: 153ms	remaining: 1.81s
# 88:	learn: 0.4273282	total: 155ms	remaining: 1.58s
# 78:	learn: 0.4338106	total: 155ms	remaining: 1.8s
# 88:	learn: 0.4242211	total: 153ms	remaining: 1.56s
# 89:	learn: 0.4266800	total: 156ms	remaining: 1.58s
# 89:	learn: 0.4235836	total: 154ms	remaining: 1.55s
# 79:	learn: 0.4330752	total: 156ms	remaining: 1.8s
# 90:	learn: 0.4259961	total: 157ms	remaining: 1.57s
# 90:	learn: 0.4229165	total: 155ms	remaining: 1.55s
# 91:	learn: 0.4254143	total: 158ms	remaining: 1.56s
# 91:	learn: 0.4223330	total: 156ms	remaining: 1.54s
# 80:	learn: 0.4323926	total: 158ms	remaining: 1.79s
# 92:	learn: 0.4247932	total: 159ms	remaining: 1.55s
# 92:	learn: 0.4217215	total: 157ms	remaining: 1.53s
# 93:	learn: 0.4242031	total: 159ms	remaining: 1.53s
# 81:	learn: 0.4316797	total: 159ms	remaining: 1.78s
# 93:	learn: 0.4211441	total: 158ms	remaining: 1.52s
# 94:	learn: 0.4236269	total: 160ms	remaining: 1.53s
# 82:	learn: 0.4309071	total: 161ms	remaining: 1.77s
# 94:	learn: 0.4205763	total: 159ms	remaining: 1.51s
# 95:	learn: 0.4230338	total: 161ms	remaining: 1.52s
# 83:	learn: 0.4302139	total: 162ms	remaining: 1.76s
# 95:	learn: 0.4199926	total: 160ms	remaining: 1.51s
# 96:	learn: 0.4224015	total: 163ms	remaining: 1.51s
# 84:	learn: 0.4295498	total: 163ms	remaining: 1.76s
# 96:	learn: 0.4193707	total: 161ms	remaining: 1.5s
# 97:	learn: 0.4218614	total: 164ms	remaining: 1.51s
# 85:	learn: 0.4289028	total: 164ms	remaining: 1.75s
# 97:	learn: 0.4188290	total: 162ms	remaining: 1.49s
# 98:	learn: 0.4213165	total: 165ms	remaining: 1.5s
# 86:	learn: 0.4282408	total: 165ms	remaining: 1.73s
# 87:	learn: 0.4275145	total: 166ms	remaining: 1.72s
# 98:	learn: 0.4182973	total: 163ms	remaining: 1.49s
# 99:	learn: 0.4207519	total: 166ms	remaining: 1.49s
# 99:	learn: 0.4177392	total: 164ms	remaining: 1.48s
# 88:	learn: 0.4267998	total: 167ms	remaining: 1.71s
# 100:	learn: 0.4201490	total: 167ms	remaining: 1.49s
# 100:	learn: 0.4171537	total: 165ms	remaining: 1.47s
# 89:	learn: 0.4261481	total: 168ms	remaining: 1.7s
# 101:	learn: 0.4195572	total: 168ms	remaining: 1.48s
# 90:	learn: 0.4254574	total: 169ms	remaining: 1.69s
# 101:	learn: 0.4165789	total: 166ms	remaining: 1.46s
# 102:	learn: 0.4190382	total: 169ms	remaining: 1.47s
# 91:	learn: 0.4248642	total: 170ms	remaining: 1.67s
# 102:	learn: 0.4160685	total: 168ms	remaining: 1.46s
# 103:	learn: 0.4184646	total: 170ms	remaining: 1.47s
# 92:	learn: 0.4242448	total: 171ms	remaining: 1.67s
# 103:	learn: 0.4155103	total: 168ms	remaining: 1.45s
# 93:	learn: 0.4236490	total: 172ms	remaining: 1.66s
# 104:	learn: 0.4179371	total: 172ms	remaining: 1.46s
# 104:	learn: 0.4149918	total: 169ms	remaining: 1.44s
# 105:	learn: 0.4144526	total: 170ms	remaining: 1.43s
# 94:	learn: 0.4230700	total: 173ms	remaining: 1.65s
# 105:	learn: 0.4173818	total: 173ms	remaining: 1.46s
# 106:	learn: 0.4139320	total: 171ms	remaining: 1.42s
# 106:	learn: 0.4168551	total: 174ms	remaining: 1.45s
# 95:	learn: 0.4224788	total: 174ms	remaining: 1.64s
# 107:	learn: 0.4134074	total: 172ms	remaining: 1.42s
# 96:	learn: 0.4218344	total: 175ms	remaining: 1.63s
# 107:	learn: 0.4163147	total: 175ms	remaining: 1.45s
# 108:	learn: 0.4129445	total: 173ms	remaining: 1.41s
# 108:	learn: 0.4158465	total: 176ms	remaining: 1.44s
# 97:	learn: 0.4212834	total: 177ms	remaining: 1.63s
# 109:	learn: 0.4124348	total: 174ms	remaining: 1.4s
# 109:	learn: 0.4153262	total: 177ms	remaining: 1.43s
# 98:	learn: 0.4207359	total: 178ms	remaining: 1.62s
# 110:	learn: 0.4119359	total: 175ms	remaining: 1.4s
# 110:	learn: 0.4148121	total: 178ms	remaining: 1.43s
# 99:	learn: 0.4201176	total: 179ms	remaining: 1.61s
# 111:	learn: 0.4114924	total: 176ms	remaining: 1.4s
# 112:	learn: 0.4110387	total: 177ms	remaining: 1.39s
# 100:	learn: 0.4195117	total: 180ms	remaining: 1.6s
# 111:	learn: 0.4143636	total: 179ms	remaining: 1.42s
# 113:	learn: 0.4105576	total: 177ms	remaining: 1.38s
# 101:	learn: 0.4189170	total: 181ms	remaining: 1.59s
# 112:	learn: 0.4139058	total: 180ms	remaining: 1.42s
# 114:	learn: 0.4101220	total: 178ms	remaining: 1.37s
# 102:	learn: 0.4183318	total: 182ms	remaining: 1.58s
# 113:	learn: 0.4134187	total: 181ms	remaining: 1.41s
# 103:	learn: 0.4177574	total: 182ms	remaining: 1.57s
# 115:	learn: 0.4096501	total: 179ms	remaining: 1.37s
# 114:	learn: 0.4129794	total: 182ms	remaining: 1.4s
# 116:	learn: 0.4092216	total: 180ms	remaining: 1.36s
# 104:	learn: 0.4172281	total: 184ms	remaining: 1.56s
# 117:	learn: 0.4087656	total: 181ms	remaining: 1.35s
# 115:	learn: 0.4124973	total: 183ms	remaining: 1.4s
# 116:	learn: 0.4120637	total: 184ms	remaining: 1.39s
# 118:	learn: 0.4083178	total: 181ms	remaining: 1.34s
# 105:	learn: 0.4166732	total: 185ms	remaining: 1.56s
# 117:	learn: 0.4116019	total: 185ms	remaining: 1.38s
# 106:	learn: 0.4161462	total: 186ms	remaining: 1.55s
# 119:	learn: 0.4078781	total: 182ms	remaining: 1.34s
# 118:	learn: 0.4111484	total: 186ms	remaining: 1.37s
# 120:	learn: 0.4074309	total: 184ms	remaining: 1.33s
# 119:	learn: 0.4107031	total: 187ms	remaining: 1.37s
# 107:	learn: 0.4156063	total: 188ms	remaining: 1.55s
# 120:	learn: 0.4102455	total: 188ms	remaining: 1.37s
# 121:	learn: 0.4070138	total: 185ms	remaining: 1.33s
# 108:	learn: 0.4151344	total: 189ms	remaining: 1.55s
# 121:	learn: 0.4098178	total: 189ms	remaining: 1.36s
# 109:	learn: 0.4146098	total: 190ms	remaining: 1.54s
# 122:	learn: 0.4093749	total: 191ms	remaining: 1.36s
# 110:	learn: 0.4140949	total: 192ms	remaining: 1.54s
# 122:	learn: 0.4065810	total: 188ms	remaining: 1.34s
# 123:	learn: 0.4089368	total: 192ms	remaining: 1.36s
# 111:	learn: 0.4136480	total: 193ms	remaining: 1.53s
# 123:	learn: 0.4061573	total: 190ms	remaining: 1.34s
# 124:	learn: 0.4085102	total: 193ms	remaining: 1.35s
# 112:	learn: 0.4131832	total: 194ms	remaining: 1.52s
# 124:	learn: 0.4057396	total: 191ms	remaining: 1.33s
# 125:	learn: 0.4081248	total: 194ms	remaining: 1.34s
# 125:	learn: 0.4053294	total: 191ms	remaining: 1.33s
# 113:	learn: 0.4126883	total: 195ms	remaining: 1.52s
# 126:	learn: 0.4077102	total: 195ms	remaining: 1.34s
# 126:	learn: 0.4049192	total: 192ms	remaining: 1.32s
# 114:	learn: 0.4122498	total: 196ms	remaining: 1.51s
# 127:	learn: 0.4072993	total: 196ms	remaining: 1.33s
# 127:	learn: 0.4045198	total: 193ms	remaining: 1.32s
# 115:	learn: 0.4117689	total: 197ms	remaining: 1.5s
# 128:	learn: 0.4068922	total: 197ms	remaining: 1.33s
# 116:	learn: 0.4113267	total: 198ms	remaining: 1.5s
# 129:	learn: 0.4064919	total: 197ms	remaining: 1.32s
# 128:	learn: 0.4041215	total: 195ms	remaining: 1.31s
# 130:	learn: 0.4060989	total: 198ms	remaining: 1.31s
# 117:	learn: 0.4108603	total: 199ms	remaining: 1.49s
# 129:	learn: 0.4037325	total: 196ms	remaining: 1.31s
# 118:	learn: 0.4104023	total: 200ms	remaining: 1.48s
# 131:	learn: 0.4057130	total: 199ms	remaining: 1.31s
# 130:	learn: 0.4033505	total: 197ms	remaining: 1.31s
# 119:	learn: 0.4099526	total: 201ms	remaining: 1.47s
# 132:	learn: 0.4053576	total: 200ms	remaining: 1.3s
# 120:	learn: 0.4095426	total: 201ms	remaining: 1.46s
# 131:	learn: 0.4029755	total: 198ms	remaining: 1.3s
# 133:	learn: 0.4049351	total: 201ms	remaining: 1.3s
# 121:	learn: 0.4091143	total: 202ms	remaining: 1.46s
# 132:	learn: 0.4025686	total: 199ms	remaining: 1.3s
# 134:	learn: 0.4046008	total: 202ms	remaining: 1.29s
# 122:	learn: 0.4086699	total: 203ms	remaining: 1.45s
# 133:	learn: 0.4021545	total: 200ms	remaining: 1.29s
# 134:	learn: 0.4017918	total: 200ms	remaining: 1.28s
# 135:	learn: 0.4042330	total: 203ms	remaining: 1.29s
# 123:	learn: 0.4082817	total: 204ms	remaining: 1.44s
# 135:	learn: 0.4013981	total: 201ms	remaining: 1.28s
# 136:	learn: 0.4039019	total: 204ms	remaining: 1.28s
# 124:	learn: 0.4078504	total: 205ms	remaining: 1.44s
# 136:	learn: 0.4010663	total: 203ms	remaining: 1.27s
# 137:	learn: 0.4035667	total: 205ms	remaining: 1.28s
# 125:	learn: 0.4074305	total: 207ms	remaining: 1.43s
# 138:	learn: 0.4032348	total: 206ms	remaining: 1.28s
# 137:	learn: 0.4007326	total: 204ms	remaining: 1.27s
# 139:	learn: 0.4028860	total: 207ms	remaining: 1.27s
# 126:	learn: 0.4070106	total: 209ms	remaining: 1.43s
# 138:	learn: 0.4004040	total: 206ms	remaining: 1.27s
# 127:	learn: 0.4066016	total: 210ms	remaining: 1.43s
# 140:	learn: 0.4025415	total: 209ms	remaining: 1.27s
# 139:	learn: 0.4000788	total: 207ms	remaining: 1.27s
# 141:	learn: 0.4021456	total: 210ms	remaining: 1.27s
# 140:	learn: 0.3997428	total: 208ms	remaining: 1.27s
# 128:	learn: 0.4061932	total: 212ms	remaining: 1.43s
# 129:	learn: 0.4057948	total: 213ms	remaining: 1.42s
# 141:	learn: 0.3993698	total: 209ms	remaining: 1.26s
# 142:	learn: 0.4017498	total: 212ms	remaining: 1.27s
# 130:	learn: 0.4054037	total: 213ms	remaining: 1.42s
# 143:	learn: 0.4014171	total: 212ms	remaining: 1.26s
# 131:	learn: 0.4049633	total: 214ms	remaining: 1.41s
# 142:	learn: 0.3990248	total: 211ms	remaining: 1.26s
# 144:	learn: 0.4011088	total: 214ms	remaining: 1.26s
# 132:	learn: 0.4045387	total: 215ms	remaining: 1.4s
# 145:	learn: 0.4007469	total: 214ms	remaining: 1.25s
# 143:	learn: 0.3986975	total: 213ms	remaining: 1.26s
# 133:	learn: 0.4041247	total: 217ms	remaining: 1.4s
# 146:	learn: 0.4004250	total: 215ms	remaining: 1.25s
# 144:	learn: 0.3983920	total: 214ms	remaining: 1.26s
# 134:	learn: 0.4037562	total: 218ms	remaining: 1.4s
# 147:	learn: 0.4001361	total: 216ms	remaining: 1.25s
# 145:	learn: 0.3980401	total: 214ms	remaining: 1.25s
# 148:	learn: 0.3997608	total: 217ms	remaining: 1.24s
# 135:	learn: 0.4033860	total: 219ms	remaining: 1.39s
# 146:	learn: 0.3977235	total: 215ms	remaining: 1.25s
# 136:	learn: 0.4030480	total: 220ms	remaining: 1.39s
# 147:	learn: 0.3974354	total: 216ms	remaining: 1.25s
# 149:	learn: 0.3993900	total: 218ms	remaining: 1.24s
# 148:	learn: 0.3971419	total: 217ms	remaining: 1.24s
# 150:	learn: 0.3991122	total: 219ms	remaining: 1.23s
# 137:	learn: 0.4027079	total: 221ms	remaining: 1.38s
# 138:	learn: 0.4023570	total: 222ms	remaining: 1.37s
# 149:	learn: 0.3968225	total: 218ms	remaining: 1.24s
# 151:	learn: 0.3988244	total: 220ms	remaining: 1.23s
# 139:	learn: 0.4020250	total: 223ms	remaining: 1.37s
# 150:	learn: 0.3965208	total: 219ms	remaining: 1.23s
# 152:	learn: 0.3984807	total: 221ms	remaining: 1.22s
# 140:	learn: 0.4016848	total: 223ms	remaining: 1.36s
# 151:	learn: 0.3962246	total: 220ms	remaining: 1.23s
# 153:	learn: 0.3981844	total: 222ms	remaining: 1.22s
# 141:	learn: 0.4013622	total: 224ms	remaining: 1.35s
# 154:	learn: 0.3978348	total: 223ms	remaining: 1.21s
# 152:	learn: 0.3958750	total: 221ms	remaining: 1.22s
# 142:	learn: 0.4009668	total: 225ms	remaining: 1.35s
# 155:	learn: 0.3975565	total: 224ms	remaining: 1.21s
# 153:	learn: 0.3955831	total: 222ms	remaining: 1.22s
# 156:	learn: 0.3972087	total: 224ms	remaining: 1.2s
# 154:	learn: 0.3952995	total: 222ms	remaining: 1.21s
# 143:	learn: 0.4006296	total: 226ms	remaining: 1.34s
# 155:	learn: 0.3949838	total: 223ms	remaining: 1.21s
# 157:	learn: 0.3968899	total: 225ms	remaining: 1.2s
# 144:	learn: 0.4003185	total: 227ms	remaining: 1.34s
# 158:	learn: 0.3966074	total: 226ms	remaining: 1.19s
# 156:	learn: 0.3947017	total: 224ms	remaining: 1.2s
# 145:	learn: 0.3999475	total: 228ms	remaining: 1.33s
# 159:	learn: 0.3963158	total: 226ms	remaining: 1.19s
# 157:	learn: 0.3943907	total: 225ms	remaining: 1.2s
# 160:	learn: 0.3959993	total: 227ms	remaining: 1.18s
# 146:	learn: 0.3996216	total: 229ms	remaining: 1.33s
# 158:	learn: 0.3941177	total: 226ms	remaining: 1.19s
# 161:	learn: 0.3956726	total: 228ms	remaining: 1.18s
# 147:	learn: 0.3993300	total: 230ms	remaining: 1.32s
# 159:	learn: 0.3938315	total: 226ms	remaining: 1.19s
# 162:	learn: 0.3954090	total: 229ms	remaining: 1.18s
# 148:	learn: 0.3990000	total: 231ms	remaining: 1.32s
# 160:	learn: 0.3935760	total: 227ms	remaining: 1.18s
# 163:	learn: 0.3950979	total: 230ms	remaining: 1.17s
# 161:	learn: 0.3932753	total: 228ms	remaining: 1.18s
# 149:	learn: 0.3986763	total: 232ms	remaining: 1.32s
# 162:	learn: 0.3930201	total: 229ms	remaining: 1.18s
# 164:	learn: 0.3947784	total: 231ms	remaining: 1.17s
# 150:	learn: 0.3984015	total: 233ms	remaining: 1.31s
# 163:	learn: 0.3927289	total: 230ms	remaining: 1.17s
# 164:	learn: 0.3924719	total: 231ms	remaining: 1.17s
# 165:	learn: 0.3944860	total: 233ms	remaining: 1.17s
# 151:	learn: 0.3980939	total: 235ms	remaining: 1.31s
# 152:	learn: 0.3977451	total: 235ms	remaining: 1.3s
# 165:	learn: 0.3921680	total: 232ms	remaining: 1.17s
# 166:	learn: 0.3942173	total: 234ms	remaining: 1.17s
# 153:	learn: 0.3974526	total: 236ms	remaining: 1.3s
# 166:	learn: 0.3918603	total: 233ms	remaining: 1.16s
# 167:	learn: 0.3939542	total: 235ms	remaining: 1.16s
# 154:	learn: 0.3971431	total: 237ms	remaining: 1.29s
# 167:	learn: 0.3916002	total: 234ms	remaining: 1.16s
# 168:	learn: 0.3937176	total: 236ms	remaining: 1.16s
# 155:	learn: 0.3968663	total: 238ms	remaining: 1.29s
# 168:	learn: 0.3913665	total: 235ms	remaining: 1.15s
# 169:	learn: 0.3934271	total: 237ms	remaining: 1.15s
# 156:	learn: 0.3965165	total: 239ms	remaining: 1.28s
# 170:	learn: 0.3931246	total: 238ms	remaining: 1.15s
# 157:	learn: 0.3961903	total: 240ms	remaining: 1.28s
# 169:	learn: 0.3910763	total: 237ms	remaining: 1.16s
# 158:	learn: 0.3959106	total: 242ms	remaining: 1.28s
# 171:	learn: 0.3928555	total: 240ms	remaining: 1.15s
# 172:	learn: 0.3926121	total: 241ms	remaining: 1.15s
# 173:	learn: 0.3923439	total: 242ms	remaining: 1.15s
# 174:	learn: 0.3920463	total: 242ms	remaining: 1.14s
# 175:	learn: 0.3917995	total: 243ms	remaining: 1.14s
# 170:	learn: 0.3908280	total: 243ms	remaining: 1.18s
# 159:	learn: 0.3956218	total: 247ms	remaining: 1.29s
# 176:	learn: 0.3915612	total: 244ms	remaining: 1.13s
# 171:	learn: 0.3905441	total: 244ms	remaining: 1.17s
# 160:	learn: 0.3953363	total: 248ms	remaining: 1.29s
# 172:	learn: 0.3902992	total: 246ms	remaining: 1.17s
# 161:	learn: 0.3950553	total: 250ms	remaining: 1.29s
# 173:	learn: 0.3900441	total: 247ms	remaining: 1.17s
# 177:	learn: 0.3913274	total: 248ms	remaining: 1.14s
# 162:	learn: 0.3947988	total: 251ms	remaining: 1.29s
# 174:	learn: 0.3897683	total: 247ms	remaining: 1.17s
# 175:	learn: 0.3895236	total: 248ms	remaining: 1.16s
# 178:	learn: 0.3910895	total: 249ms	remaining: 1.14s
# 163:	learn: 0.3944902	total: 252ms	remaining: 1.29s
# 176:	learn: 0.3892643	total: 249ms	remaining: 1.16s
# 179:	learn: 0.3908560	total: 250ms	remaining: 1.14s
# 164:	learn: 0.3941714	total: 253ms	remaining: 1.28s
# 177:	learn: 0.3890419	total: 250ms	remaining: 1.15s
# 165:	learn: 0.3938667	total: 254ms	remaining: 1.27s
# 180:	learn: 0.3906090	total: 251ms	remaining: 1.14s
# 181:	learn: 0.3903902	total: 252ms	remaining: 1.13s
# 178:	learn: 0.3888035	total: 251ms	remaining: 1.15s
# 166:	learn: 0.3935480	total: 255ms	remaining: 1.27s
# 182:	learn: 0.3901233	total: 253ms	remaining: 1.13s
# 179:	learn: 0.3885827	total: 252ms	remaining: 1.15s
# 167:	learn: 0.3932888	total: 256ms	remaining: 1.27s
# 180:	learn: 0.3883368	total: 253ms	remaining: 1.14s
# 183:	learn: 0.3898637	total: 253ms	remaining: 1.12s
# 168:	learn: 0.3929999	total: 257ms	remaining: 1.26s
# 184:	learn: 0.3896006	total: 254ms	remaining: 1.12s
# 181:	learn: 0.3881240	total: 254ms	remaining: 1.14s
# 185:	learn: 0.3893551	total: 255ms	remaining: 1.11s
# 186:	learn: 0.3890902	total: 255ms	remaining: 1.11s
# 169:	learn: 0.3927087	total: 259ms	remaining: 1.26s
# 182:	learn: 0.3878687	total: 255ms	remaining: 1.14s
# 187:	learn: 0.3888339	total: 256ms	remaining: 1.1s
# 183:	learn: 0.3876151	total: 255ms	remaining: 1.13s
# 170:	learn: 0.3924118	total: 260ms	remaining: 1.26s
# 188:	learn: 0.3886128	total: 257ms	remaining: 1.1s
# 184:	learn: 0.3874075	total: 256ms	remaining: 1.13s
# 189:	learn: 0.3883601	total: 257ms	remaining: 1.1s
# 185:	learn: 0.3871585	total: 257ms	remaining: 1.12s
# 171:	learn: 0.3921281	total: 261ms	remaining: 1.25s
# 186:	learn: 0.3869106	total: 257ms	remaining: 1.12s
# 190:	learn: 0.3881299	total: 258ms	remaining: 1.09s
# 172:	learn: 0.3918662	total: 261ms	remaining: 1.25s
# 187:	learn: 0.3866784	total: 258ms	remaining: 1.11s
# 173:	learn: 0.3915975	total: 262ms	remaining: 1.24s
# 191:	learn: 0.3878764	total: 259ms	remaining: 1.09s
# 188:	learn: 0.3864709	total: 259ms	remaining: 1.11s
# 174:	learn: 0.3913015	total: 263ms	remaining: 1.24s
# 192:	learn: 0.3876542	total: 260ms	remaining: 1.09s
# 175:	learn: 0.3910408	total: 263ms	remaining: 1.23s
# 189:	learn: 0.3862199	total: 260ms	remaining: 1.11s
# 176:	learn: 0.3907983	total: 264ms	remaining: 1.23s
# 193:	learn: 0.3873986	total: 261ms	remaining: 1.08s
# 190:	learn: 0.3860022	total: 261ms	remaining: 1.1s
# 194:	learn: 0.3871549	total: 262ms	remaining: 1.08s
# 177:	learn: 0.3905665	total: 265ms	remaining: 1.22s
# 191:	learn: 0.3857513	total: 261ms	remaining: 1.1s
# 192:	learn: 0.3855383	total: 262ms	remaining: 1.09s
# 178:	learn: 0.3903205	total: 266ms	remaining: 1.22s
# 195:	learn: 0.3869294	total: 263ms	remaining: 1.08s
# 179:	learn: 0.3901019	total: 267ms	remaining: 1.22s
# 193:	learn: 0.3852932	total: 264ms	remaining: 1.1s
# 180:	learn: 0.3898550	total: 268ms	remaining: 1.21s
# 194:	learn: 0.3850446	total: 265ms	remaining: 1.09s
# 181:	learn: 0.3896367	total: 269ms	remaining: 1.21s
# 196:	learn: 0.3866958	total: 266ms	remaining: 1.08s
# 197:	learn: 0.3864662	total: 267ms	remaining: 1.08s
# 182:	learn: 0.3893772	total: 271ms	remaining: 1.21s
# 195:	learn: 0.3848175	total: 268ms	remaining: 1.1s
# 196:	learn: 0.3845929	total: 268ms	remaining: 1.09s
# 183:	learn: 0.3891204	total: 272ms	remaining: 1.21s
# 197:	learn: 0.3843678	total: 269ms	remaining: 1.09s
# 184:	learn: 0.3888547	total: 273ms	remaining: 1.2s
# 198:	learn: 0.3862563	total: 270ms	remaining: 1.09s
# 185:	learn: 0.3885978	total: 274ms	remaining: 1.2s
# 198:	learn: 0.3841575	total: 270ms	remaining: 1.09s
# 199:	learn: 0.3860207	total: 271ms	remaining: 1.08s
# 186:	learn: 0.3883388	total: 275ms	remaining: 1.19s
# 200:	learn: 0.3858159	total: 271ms	remaining: 1.08s
# 199:	learn: 0.3839355	total: 271ms	remaining: 1.08s
# 187:	learn: 0.3880873	total: 276ms	remaining: 1.19s
# 201:	learn: 0.3856118	total: 272ms	remaining: 1.07s
# 200:	learn: 0.3837321	total: 272ms	remaining: 1.08s
# 202:	learn: 0.3853903	total: 273ms	remaining: 1.07s
# 188:	learn: 0.3878744	total: 277ms	remaining: 1.19s
# 203:	learn: 0.3851881	total: 274ms	remaining: 1.07s
# 201:	learn: 0.3835133	total: 275ms	remaining: 1.08s
# 204:	learn: 0.3849920	total: 275ms	remaining: 1.06s
# 189:	learn: 0.3876303	total: 279ms	remaining: 1.19s
# 202:	learn: 0.3833194	total: 276ms	remaining: 1.08s
# 190:	learn: 0.3874017	total: 280ms	remaining: 1.19s
# 205:	learn: 0.3847855	total: 277ms	remaining: 1.07s
# 203:	learn: 0.3831236	total: 277ms	remaining: 1.08s
# 191:	learn: 0.3871504	total: 281ms	remaining: 1.18s
# 206:	learn: 0.3846062	total: 278ms	remaining: 1.06s
# 204:	learn: 0.3829263	total: 278ms	remaining: 1.08s
# 192:	learn: 0.3869279	total: 282ms	remaining: 1.18s
# 205:	learn: 0.3827515	total: 279ms	remaining: 1.07s
# 207:	learn: 0.3844002	total: 279ms	remaining: 1.06s
# 193:	learn: 0.3866797	total: 283ms	remaining: 1.18s
# 206:	learn: 0.3825746	total: 280ms	remaining: 1.07s
# 208:	learn: 0.3841820	total: 280ms	remaining: 1.06s
# 194:	learn: 0.3864397	total: 285ms	remaining: 1.18s
# 207:	learn: 0.3823451	total: 282ms	remaining: 1.07s
# 209:	learn: 0.3839568	total: 282ms	remaining: 1.06s
# 195:	learn: 0.3862088	total: 285ms	remaining: 1.17s
# 196:	learn: 0.3859773	total: 286ms	remaining: 1.17s
# 210:	learn: 0.3837377	total: 282ms	remaining: 1.06s
# 208:	learn: 0.3821351	total: 283ms	remaining: 1.07s
# 197:	learn: 0.3857389	total: 287ms	remaining: 1.16s
# 211:	learn: 0.3835049	total: 284ms	remaining: 1.05s
# 198:	learn: 0.3855255	total: 288ms	remaining: 1.16s
# 209:	learn: 0.3819212	total: 284ms	remaining: 1.07s
# 199:	learn: 0.3853142	total: 288ms	remaining: 1.15s
# 212:	learn: 0.3832921	total: 285ms	remaining: 1.05s
# 210:	learn: 0.3817324	total: 285ms	remaining: 1.07s
# 213:	learn: 0.3830688	total: 285ms	remaining: 1.05s
# 200:	learn: 0.3851013	total: 290ms	remaining: 1.15s
# 211:	learn: 0.3815198	total: 286ms	remaining: 1.06s
# 214:	learn: 0.3828614	total: 287ms	remaining: 1.05s
# 201:	learn: 0.3848947	total: 291ms	remaining: 1.15s
# 212:	learn: 0.3813111	total: 287ms	remaining: 1.06s
# 215:	learn: 0.3826685	total: 288ms	remaining: 1.04s
# 213:	learn: 0.3811014	total: 288ms	remaining: 1.06s
# 202:	learn: 0.3846713	total: 292ms	remaining: 1.15s
# 216:	learn: 0.3824848	total: 288ms	remaining: 1.04s
# 214:	learn: 0.3809146	total: 289ms	remaining: 1.05s
# 217:	learn: 0.3822903	total: 289ms	remaining: 1.04s
# 203:	learn: 0.3844705	total: 293ms	remaining: 1.14s
# 215:	learn: 0.3807275	total: 290ms	remaining: 1.05s
# 218:	learn: 0.3821114	total: 290ms	remaining: 1.03s
# 216:	learn: 0.3805598	total: 290ms	remaining: 1.05s
# 204:	learn: 0.3842675	total: 294ms	remaining: 1.14s
# 219:	learn: 0.3818909	total: 290ms	remaining: 1.03s
# 217:	learn: 0.3803441	total: 291ms	remaining: 1.04s
# 220:	learn: 0.3816750	total: 291ms	remaining: 1.02s
# 205:	learn: 0.3840637	total: 295ms	remaining: 1.14s
# 218:	learn: 0.3801339	total: 292ms	remaining: 1.04s
# 221:	learn: 0.3814687	total: 292ms	remaining: 1.02s
# 206:	learn: 0.3838714	total: 296ms	remaining: 1.13s
# 219:	learn: 0.3799246	total: 294ms	remaining: 1.04s
# 207:	learn: 0.3836342	total: 298ms	remaining: 1.13s
# 222:	learn: 0.3812648	total: 294ms	remaining: 1.02s
# 220:	learn: 0.3797156	total: 295ms	remaining: 1.04s
# 208:	learn: 0.3834369	total: 300ms	remaining: 1.13s
# 221:	learn: 0.3795205	total: 297ms	remaining: 1.04s
# 223:	learn: 0.3810878	total: 296ms	remaining: 1.03s
# 209:	learn: 0.3832177	total: 302ms	remaining: 1.14s
# 222:	learn: 0.3793271	total: 298ms	remaining: 1.04s
# 224:	learn: 0.3809058	total: 297ms	remaining: 1.02s
# 223:	learn: 0.3791493	total: 299ms	remaining: 1.03s
# 210:	learn: 0.3830018	total: 303ms	remaining: 1.13s
# 224:	learn: 0.3789659	total: 300ms	remaining: 1.03s
# 225:	learn: 0.3807146	total: 299ms	remaining: 1.02s
# 211:	learn: 0.3827971	total: 304ms	remaining: 1.13s
# 225:	learn: 0.3787790	total: 331ms	remaining: 1.13s
# 212:	learn: 0.3825809	total: 335ms	remaining: 1.24s
# 213:	learn: 0.3823526	total: 338ms	remaining: 1.24s
# 226:	learn: 0.3805109	total: 336ms	remaining: 1.14s
# 226:	learn: 0.3785883	total: 338ms	remaining: 1.15s
# 214:	learn: 0.3821386	total: 341ms	remaining: 1.24s
# 227:	learn: 0.3803176	total: 338ms	remaining: 1.14s
# 227:	learn: 0.3784197	total: 341ms	remaining: 1.15s
# 228:	learn: 0.3801114	total: 340ms	remaining: 1.14s
# 215:	learn: 0.3819560	total: 343ms	remaining: 1.25s
# 216:	learn: 0.3817783	total: 345ms	remaining: 1.24s
# 229:	learn: 0.3799172	total: 343ms	remaining: 1.15s
# 217:	learn: 0.3815524	total: 348ms	remaining: 1.25s
# 228:	learn: 0.3782161	total: 343ms	remaining: 1.15s
# 230:	learn: 0.3797093	total: 346ms	remaining: 1.15s
# 218:	learn: 0.3813734	total: 350ms	remaining: 1.25s
# 229:	learn: 0.3780163	total: 344ms	remaining: 1.15s
# 231:	learn: 0.3795177	total: 348ms	remaining: 1.15s
# 219:	learn: 0.3811500	total: 351ms	remaining: 1.24s
# 230:	learn: 0.3778168	total: 346ms	remaining: 1.15s
# 220:	learn: 0.3809298	total: 352ms	remaining: 1.24s
# 232:	learn: 0.3793104	total: 350ms	remaining: 1.15s
# 231:	learn: 0.3776488	total: 347ms	remaining: 1.15s
# 233:	learn: 0.3791316	total: 351ms	remaining: 1.15s
# 221:	learn: 0.3807147	total: 354ms	remaining: 1.24s
# 234:	learn: 0.3789253	total: 353ms	remaining: 1.15s
# 222:	learn: 0.3804960	total: 358ms	remaining: 1.25s
# 232:	learn: 0.3774477	total: 352ms	remaining: 1.16s
# 223:	learn: 0.3803164	total: 360ms	remaining: 1.25s
# 233:	learn: 0.3772756	total: 354ms	remaining: 1.16s
# 235:	learn: 0.3787394	total: 355ms	remaining: 1.15s
# 224:	learn: 0.3801406	total: 361ms	remaining: 1.24s
# 234:	learn: 0.3770805	total: 355ms	remaining: 1.16s
# 236:	learn: 0.3785453	total: 356ms	remaining: 1.15s
# 225:	learn: 0.3799452	total: 361ms	remaining: 1.24s
# 235:	learn: 0.3768913	total: 355ms	remaining: 1.15s
# 226:	learn: 0.3797546	total: 362ms	remaining: 1.23s
# 237:	learn: 0.3783437	total: 357ms	remaining: 1.14s
# 236:	learn: 0.3767039	total: 356ms	remaining: 1.15s
# 227:	learn: 0.3795777	total: 363ms	remaining: 1.23s
# 238:	learn: 0.3781758	total: 358ms	remaining: 1.14s
# 228:	learn: 0.3793700	total: 363ms	remaining: 1.22s
# 237:	learn: 0.3765063	total: 358ms	remaining: 1.15s
# 229:	learn: 0.3791801	total: 364ms	remaining: 1.22s
# 230:	learn: 0.3789694	total: 365ms	remaining: 1.22s
# 239:	learn: 0.3779794	total: 360ms	remaining: 1.14s
# 238:	learn: 0.3763307	total: 359ms	remaining: 1.14s
# 231:	learn: 0.3787939	total: 366ms	remaining: 1.21s
# 239:	learn: 0.3761631	total: 360ms	remaining: 1.14s
# 240:	learn: 0.3777844	total: 361ms	remaining: 1.14s
# 232:	learn: 0.3786067	total: 367ms	remaining: 1.21s
# 240:	learn: 0.3760008	total: 361ms	remaining: 1.14s
# 241:	learn: 0.3776010	total: 363ms	remaining: 1.14s
# 241:	learn: 0.3758286	total: 363ms	remaining: 1.14s
# 233:	learn: 0.3784225	total: 369ms	remaining: 1.21s
# 242:	learn: 0.3756966	total: 364ms	remaining: 1.13s
# 242:	learn: 0.3774619	total: 365ms	remaining: 1.14s
# 243:	learn: 0.3755074	total: 365ms	remaining: 1.13s
# 234:	learn: 0.3782197	total: 371ms	remaining: 1.21s
# 243:	learn: 0.3772994	total: 366ms	remaining: 1.13s
# 235:	learn: 0.3780295	total: 372ms	remaining: 1.2s
# 244:	learn: 0.3753262	total: 366ms	remaining: 1.13s
# 244:	learn: 0.3771121	total: 367ms	remaining: 1.13s
# 236:	learn: 0.3778393	total: 373ms	remaining: 1.2s
# 245:	learn: 0.3751614	total: 367ms	remaining: 1.12s
# 245:	learn: 0.3769398	total: 368ms	remaining: 1.13s
# 237:	learn: 0.3776504	total: 374ms	remaining: 1.2s
# 246:	learn: 0.3749770	total: 368ms	remaining: 1.12s
# 238:	learn: 0.3774813	total: 375ms	remaining: 1.19s
# 246:	learn: 0.3767538	total: 370ms	remaining: 1.13s
# 247:	learn: 0.3748291	total: 370ms	remaining: 1.12s
# 239:	learn: 0.3773042	total: 377ms	remaining: 1.19s
# 248:	learn: 0.3746428	total: 371ms	remaining: 1.12s
# 240:	learn: 0.3771375	total: 378ms	remaining: 1.19s
# 249:	learn: 0.3744930	total: 371ms	remaining: 1.11s
# 247:	learn: 0.3766068	total: 373ms	remaining: 1.13s
# 250:	learn: 0.3743335	total: 373ms	remaining: 1.11s
# 248:	learn: 0.3764193	total: 374ms	remaining: 1.13s
# 251:	learn: 0.3741667	total: 374ms	remaining: 1.11s
# 249:	learn: 0.3762302	total: 375ms	remaining: 1.12s
# 241:	learn: 0.3769427	total: 381ms	remaining: 1.19s
# 250:	learn: 0.3760303	total: 376ms	remaining: 1.12s
# 252:	learn: 0.3739948	total: 375ms	remaining: 1.11s
# 242:	learn: 0.3768060	total: 382ms	remaining: 1.19s
# 253:	learn: 0.3738283	total: 375ms	remaining: 1.1s
# 254:	learn: 0.3736821	total: 376ms	remaining: 1.1s
# 251:	learn: 0.3758556	total: 377ms	remaining: 1.12s
# 243:	learn: 0.3766309	total: 383ms	remaining: 1.19s
# 255:	learn: 0.3734934	total: 377ms	remaining: 1.09s
# 252:	learn: 0.3756805	total: 378ms	remaining: 1.12s
# 244:	learn: 0.3764524	total: 384ms	remaining: 1.18s
# 256:	learn: 0.3733588	total: 378ms	remaining: 1.09s
# 253:	learn: 0.3755121	total: 379ms	remaining: 1.11s
# 257:	learn: 0.3731948	total: 378ms	remaining: 1.09s
# 245:	learn: 0.3762773	total: 385ms	remaining: 1.18s
# 254:	learn: 0.3753579	total: 380ms	remaining: 1.11s
# 258:	learn: 0.3730359	total: 379ms	remaining: 1.08s
# 246:	learn: 0.3761055	total: 386ms	remaining: 1.18s
# 259:	learn: 0.3728828	total: 380ms	remaining: 1.08s
# 247:	learn: 0.3759575	total: 387ms	remaining: 1.17s
# 255:	learn: 0.3752157	total: 382ms	remaining: 1.11s
# 260:	learn: 0.3727390	total: 381ms	remaining: 1.08s
# 261:	learn: 0.3725766	total: 382ms	remaining: 1.07s
# 256:	learn: 0.3750668	total: 383ms	remaining: 1.11s
# 248:	learn: 0.3757652	total: 389ms	remaining: 1.17s
# 262:	learn: 0.3723934	total: 383ms	remaining: 1.07s
# 257:	learn: 0.3748981	total: 384ms	remaining: 1.1s
# 263:	learn: 0.3722249	total: 384ms	remaining: 1.07s
# 258:	learn: 0.3747363	total: 386ms	remaining: 1.1s
# 249:	learn: 0.3755891	total: 391ms	remaining: 1.17s
# 264:	learn: 0.3720842	total: 385ms	remaining: 1.07s
# 259:	learn: 0.3745793	total: 387ms	remaining: 1.1s
# 250:	learn: 0.3754290	total: 392ms	remaining: 1.17s
# 260:	learn: 0.3743997	total: 387ms	remaining: 1.1s
# 265:	learn: 0.3719402	total: 386ms	remaining: 1.06s
# 251:	learn: 0.3752507	total: 393ms	remaining: 1.17s
# 261:	learn: 0.3742373	total: 388ms	remaining: 1.09s
# 266:	learn: 0.3717691	total: 387ms	remaining: 1.06s
# 252:	learn: 0.3750761	total: 394ms	remaining: 1.16s
# 267:	learn: 0.3716072	total: 388ms	remaining: 1.06s
# 262:	learn: 0.3740928	total: 390ms	remaining: 1.09s
# 268:	learn: 0.3714557	total: 389ms	remaining: 1.06s
# 263:	learn: 0.3739173	total: 391ms	remaining: 1.09s
# 253:	learn: 0.3749035	total: 396ms	remaining: 1.16s
# 269:	learn: 0.3713103	total: 390ms	remaining: 1.05s
# 254:	learn: 0.3747471	total: 397ms	remaining: 1.16s
# 264:	learn: 0.3737683	total: 392ms	remaining: 1.09s
# 270:	learn: 0.3711420	total: 391ms	remaining: 1.05s
# 255:	learn: 0.3745601	total: 399ms	remaining: 1.16s
# 265:	learn: 0.3735945	total: 393ms	remaining: 1.08s
# 271:	learn: 0.3709875	total: 392ms	remaining: 1.05s
# 256:	learn: 0.3744093	total: 400ms	remaining: 1.16s
# 266:	learn: 0.3734127	total: 394ms	remaining: 1.08s
# 272:	learn: 0.3708411	total: 393ms	remaining: 1.05s
# 257:	learn: 0.3742420	total: 400ms	remaining: 1.15s
# 267:	learn: 0.3732510	total: 396ms	remaining: 1.08s
# 258:	learn: 0.3740805	total: 402ms	remaining: 1.15s
# 273:	learn: 0.3706866	total: 395ms	remaining: 1.05s
# 268:	learn: 0.3731039	total: 397ms	remaining: 1.08s
# 259:	learn: 0.3739248	total: 403ms	remaining: 1.15s
# 274:	learn: 0.3705279	total: 396ms	remaining: 1.04s
# 269:	learn: 0.3729581	total: 398ms	remaining: 1.08s
# 260:	learn: 0.3737878	total: 404ms	remaining: 1.14s
# 275:	learn: 0.3703777	total: 397ms	remaining: 1.04s
# 270:	learn: 0.3728041	total: 399ms	remaining: 1.07s
# 271:	learn: 0.3726430	total: 400ms	remaining: 1.07s
# 261:	learn: 0.3736250	total: 405ms	remaining: 1.14s
# 276:	learn: 0.3702233	total: 398ms	remaining: 1.04s
# 272:	learn: 0.3724947	total: 401ms	remaining: 1.07s
# 262:	learn: 0.3734375	total: 407ms	remaining: 1.14s
# 277:	learn: 0.3700776	total: 400ms	remaining: 1.04s
# 273:	learn: 0.3723211	total: 402ms	remaining: 1.07s
# 263:	learn: 0.3732630	total: 408ms	remaining: 1.14s
# 278:	learn: 0.3699067	total: 401ms	remaining: 1.04s
# 274:	learn: 0.3721586	total: 403ms	remaining: 1.06s
# 264:	learn: 0.3730858	total: 409ms	remaining: 1.14s
# 279:	learn: 0.3697806	total: 402ms	remaining: 1.03s
# 275:	learn: 0.3720089	total: 404ms	remaining: 1.06s
# 265:	learn: 0.3729342	total: 410ms	remaining: 1.13s
# 280:	learn: 0.3696258	total: 403ms	remaining: 1.03s
# 276:	learn: 0.3718521	total: 405ms	remaining: 1.06s
# 266:	learn: 0.3727758	total: 411ms	remaining: 1.13s
# 277:	learn: 0.3716819	total: 406ms	remaining: 1.05s
# 281:	learn: 0.3694688	total: 404ms	remaining: 1.03s
# 278:	learn: 0.3715127	total: 407ms	remaining: 1.05s
# 267:	learn: 0.3726021	total: 413ms	remaining: 1.13s
# 282:	learn: 0.3693204	total: 405ms	remaining: 1.03s
# 279:	learn: 0.3713798	total: 408ms	remaining: 1.05s
# 268:	learn: 0.3724486	total: 414ms	remaining: 1.13s
# 283:	learn: 0.3691686	total: 407ms	remaining: 1.02s
# 284:	learn: 0.3690356	total: 407ms	remaining: 1.02s
# 280:	learn: 0.3712436	total: 409ms	remaining: 1.05s
# 269:	learn: 0.3722683	total: 415ms	remaining: 1.12s
# 285:	learn: 0.3688942	total: 408ms	remaining: 1.02s
# 270:	learn: 0.3721130	total: 416ms	remaining: 1.12s
# 286:	learn: 0.3687515	total: 409ms	remaining: 1.01s
# 281:	learn: 0.3710861	total: 411ms	remaining: 1.04s
# 271:	learn: 0.3719476	total: 417ms	remaining: 1.12s
# 287:	learn: 0.3686356	total: 410ms	remaining: 1.01s
# 282:	learn: 0.3709361	total: 412ms	remaining: 1.04s
# 288:	learn: 0.3684589	total: 411ms	remaining: 1.01s
# 272:	learn: 0.3717999	total: 418ms	remaining: 1.11s
# 283:	learn: 0.3707823	total: 413ms	remaining: 1.04s
# 289:	learn: 0.3683143	total: 412ms	remaining: 1.01s
# 273:	learn: 0.3716344	total: 420ms	remaining: 1.11s
# 284:	learn: 0.3706689	total: 414ms	remaining: 1.04s
# 285:	learn: 0.3705252	total: 414ms	remaining: 1.03s
# 290:	learn: 0.3681489	total: 413ms	remaining: 1s
# 274:	learn: 0.3714720	total: 421ms	remaining: 1.11s
# 275:	learn: 0.3713238	total: 422ms	remaining: 1.11s
# 291:	learn: 0.3680102	total: 414ms	remaining: 1s
# 286:	learn: 0.3703835	total: 416ms	remaining: 1.03s
# 276:	learn: 0.3711535	total: 423ms	remaining: 1.1s
# 287:	learn: 0.3702416	total: 417ms	remaining: 1.03s
# 292:	learn: 0.3678652	total: 415ms	remaining: 1s
# 293:	learn: 0.3677199	total: 416ms	remaining: 999ms
# 277:	learn: 0.3709818	total: 424ms	remaining: 1.1s
# 288:	learn: 0.3700895	total: 419ms	remaining: 1.03s
# 294:	learn: 0.3675758	total: 417ms	remaining: 996ms
# 295:	learn: 0.3674181	total: 418ms	remaining: 994ms
# 296:	learn: 0.3672638	total: 419ms	remaining: 991ms
# 278:	learn: 0.3708152	total: 427ms	remaining: 1.1s
# 289:	learn: 0.3699301	total: 422ms	remaining: 1.03s
# 279:	learn: 0.3706812	total: 428ms	remaining: 1.1s
# 297:	learn: 0.3671629	total: 420ms	remaining: 989ms
# 290:	learn: 0.3697780	total: 423ms	remaining: 1.03s
# 298:	learn: 0.3670354	total: 421ms	remaining: 988ms
# 280:	learn: 0.3705282	total: 429ms	remaining: 1.1s
# 291:	learn: 0.3696343	total: 424ms	remaining: 1.03s
# 299:	learn: 0.3668776	total: 423ms	remaining: 986ms
# 281:	learn: 0.3703686	total: 431ms	remaining: 1.1s
# 292:	learn: 0.3694979	total: 425ms	remaining: 1.03s
# 300:	learn: 0.3667362	total: 424ms	remaining: 984ms
# 293:	learn: 0.3693500	total: 427ms	remaining: 1.02s
# 282:	learn: 0.3702149	total: 432ms	remaining: 1.09s
# 283:	learn: 0.3700609	total: 432ms	remaining: 1.09s
# 301:	learn: 0.3665901	total: 425ms	remaining: 982ms
# 284:	learn: 0.3699426	total: 433ms	remaining: 1.09s
# 294:	learn: 0.3691796	total: 429ms	remaining: 1.02s
# 302:	learn: 0.3664562	total: 426ms	remaining: 981ms
# 285:	learn: 0.3697922	total: 434ms	remaining: 1.08s
# 295:	learn: 0.3690225	total: 430ms	remaining: 1.02s
# 286:	learn: 0.3696051	total: 435ms	remaining: 1.08s
# 296:	learn: 0.3688663	total: 430ms	remaining: 1.02s
# 303:	learn: 0.3663244	total: 428ms	remaining: 979ms
# 297:	learn: 0.3687148	total: 431ms	remaining: 1.01s
# 304:	learn: 0.3661811	total: 428ms	remaining: 976ms
# 287:	learn: 0.3694734	total: 437ms	remaining: 1.08s
# 298:	learn: 0.3685866	total: 432ms	remaining: 1.01s
# 305:	learn: 0.3660423	total: 429ms	remaining: 973ms
# 299:	learn: 0.3684325	total: 433ms	remaining: 1.01s
# 288:	learn: 0.3692938	total: 438ms	remaining: 1.08s
# 300:	learn: 0.3682858	total: 433ms	remaining: 1s
# 306:	learn: 0.3659077	total: 430ms	remaining: 971ms
# 301:	learn: 0.3681370	total: 434ms	remaining: 1s
# 289:	learn: 0.3691449	total: 439ms	remaining: 1.07s
# 302:	learn: 0.3680078	total: 435ms	remaining: 1s
# 290:	learn: 0.3689926	total: 440ms	remaining: 1.07s
# 291:	learn: 0.3688490	total: 441ms	remaining: 1.07s
# 292:	learn: 0.3687149	total: 442ms	remaining: 1.07s
# 303:	learn: 0.3678794	total: 438ms	remaining: 1s
# 307:	learn: 0.3657669	total: 435ms	remaining: 978ms
# 293:	learn: 0.3685890	total: 443ms	remaining: 1.06s
# 294:	learn: 0.3684166	total: 444ms	remaining: 1.06s
# 304:	learn: 0.3677430	total: 439ms	remaining: 1s
# 308:	learn: 0.3656453	total: 436ms	remaining: 976ms
# 309:	learn: 0.3654877	total: 437ms	remaining: 973ms
# 305:	learn: 0.3676056	total: 440ms	remaining: 998ms
# 295:	learn: 0.3682593	total: 445ms	remaining: 1.06s
# 310:	learn: 0.3653645	total: 438ms	remaining: 970ms
# 306:	learn: 0.3674801	total: 441ms	remaining: 995ms
# 296:	learn: 0.3681025	total: 446ms	remaining: 1.05s
# 311:	learn: 0.3652080	total: 438ms	remaining: 967ms
# 307:	learn: 0.3673414	total: 442ms	remaining: 992ms
# 297:	learn: 0.3679648	total: 447ms	remaining: 1.05s
# 312:	learn: 0.3650824	total: 440ms	remaining: 966ms
# 308:	learn: 0.3672206	total: 443ms	remaining: 991ms
# 298:	learn: 0.3678298	total: 448ms	remaining: 1.05s
# 313:	learn: 0.3649450	total: 441ms	remaining: 964ms
# 309:	learn: 0.3670651	total: 444ms	remaining: 989ms
# 299:	learn: 0.3676550	total: 449ms	remaining: 1.05s
# 314:	learn: 0.3648321	total: 443ms	remaining: 962ms
# 310:	learn: 0.3669401	total: 446ms	remaining: 988ms
# 300:	learn: 0.3675127	total: 450ms	remaining: 1.04s
# ...
# 707:	learn: 0.3059196	total: 1.03s	remaining: 426ms
# 708:	learn: 0.3059174	total: 1.03s	remaining: 425ms
# 709:	learn: 0.3059016	total: 1.04s	remaining: 423ms
# 710:	learn: 0.3058880	total: 1.04s	remaining: 422ms
# 711:	learn: 0.3058767	total: 1.04s	remaining: 420ms
# 712:	learn: 0.3058550	total: 1.04s	remaining: 419ms
# 713:	learn: 0.3058346	total: 1.04s	remaining: 417ms
# 714:	learn: 0.3058321	total: 1.04s	remaining: 416ms
# 715:	learn: 0.3058176	total: 1.04s	remaining: 414ms
# 716:	learn: 0.3058015	total: 1.04s	remaining: 413ms
# 717:	learn: 0.3057920	total: 1.05s	remaining: 411ms
# 718:	learn: 0.3057888	total: 1.05s	remaining: 409ms
# 719:	learn: 0.3057758	total: 1.05s	remaining: 408ms
# 720:	learn: 0.3057674	total: 1.05s	remaining: 406ms
# 721:	learn: 0.3057513	total: 1.05s	remaining: 405ms
# 722:	learn: 0.3057289	total: 1.05s	remaining: 403ms
# 723:	learn: 0.3057185	total: 1.05s	remaining: 402ms
# 724:	learn: 0.3057008	total: 1.05s	remaining: 400ms
# 725:	learn: 0.3056855	total: 1.06s	remaining: 399ms
# 726:	learn: 0.3056799	total: 1.06s	remaining: 397ms
# 727:	learn: 0.3056619	total: 1.06s	remaining: 396ms
# 728:	learn: 0.3056443	total: 1.06s	remaining: 394ms
# 729:	learn: 0.3056308	total: 1.06s	remaining: 393ms
# 730:	learn: 0.3056169	total: 1.06s	remaining: 391ms
# 731:	learn: 0.3056077	total: 1.06s	remaining: 390ms
# 732:	learn: 0.3055897	total: 1.06s	remaining: 388ms
# 733:	learn: 0.3055698	total: 1.07s	remaining: 387ms
# 734:	learn: 0.3055461	total: 1.07s	remaining: 385ms
# 735:	learn: 0.3055259	total: 1.07s	remaining: 384ms
# 736:	learn: 0.3055128	total: 1.07s	remaining: 382ms
# 737:	learn: 0.3054968	total: 1.07s	remaining: 381ms
# 738:	learn: 0.3054842	total: 1.07s	remaining: 379ms
# 739:	learn: 0.3054666	total: 1.07s	remaining: 378ms
# 740:	learn: 0.3054490	total: 1.08s	remaining: 376ms
# 741:	learn: 0.3054372	total: 1.08s	remaining: 375ms
# 742:	learn: 0.3054227	total: 1.08s	remaining: 373ms
# 743:	learn: 0.3054005	total: 1.08s	remaining: 372ms
# 744:	learn: 0.3053860	total: 1.08s	remaining: 370ms
# 745:	learn: 0.3053739	total: 1.08s	remaining: 369ms
# 746:	learn: 0.3053564	total: 1.08s	remaining: 367ms
# 747:	learn: 0.3053465	total: 1.08s	remaining: 366ms
# 748:	learn: 0.3053393	total: 1.09s	remaining: 364ms
# 749:	learn: 0.3053307	total: 1.09s	remaining: 363ms
# 750:	learn: 0.3053206	total: 1.09s	remaining: 361ms
# 751:	learn: 0.3052972	total: 1.09s	remaining: 359ms
# 752:	learn: 0.3052786	total: 1.09s	remaining: 358ms
# 753:	learn: 0.3052660	total: 1.09s	remaining: 356ms
# 754:	learn: 0.3052523	total: 1.09s	remaining: 355ms
# 755:	learn: 0.3052313	total: 1.09s	remaining: 353ms
# 756:	learn: 0.3052245	total: 1.09s	remaining: 352ms
# 757:	learn: 0.3052158	total: 1.1s	remaining: 350ms
# 758:	learn: 0.3052129	total: 1.1s	remaining: 349ms
# 759:	learn: 0.3052008	total: 1.1s	remaining: 347ms
# 760:	learn: 0.3051883	total: 1.1s	remaining: 346ms
# 761:	learn: 0.3051808	total: 1.1s	remaining: 344ms
# 762:	learn: 0.3051647	total: 1.1s	remaining: 343ms
# 763:	learn: 0.3051488	total: 1.1s	remaining: 341ms
# 764:	learn: 0.3051314	total: 1.1s	remaining: 340ms
# 765:	learn: 0.3051227	total: 1.11s	remaining: 338ms
# 766:	learn: 0.3051181	total: 1.11s	remaining: 337ms
# 767:	learn: 0.3051042	total: 1.11s	remaining: 335ms
# 768:	learn: 0.3050883	total: 1.11s	remaining: 334ms
# 769:	learn: 0.3050739	total: 1.11s	remaining: 332ms
# 770:	learn: 0.3050596	total: 1.11s	remaining: 331ms
# 771:	learn: 0.3050391	total: 1.11s	remaining: 329ms
# 772:	learn: 0.3050281	total: 1.12s	remaining: 328ms
# 773:	learn: 0.3050152	total: 1.12s	remaining: 326ms
# 774:	learn: 0.3050072	total: 1.12s	remaining: 325ms
# 775:	learn: 0.3049961	total: 1.12s	remaining: 323ms
# 776:	learn: 0.3049845	total: 1.12s	remaining: 322ms
# 777:	learn: 0.3049772	total: 1.12s	remaining: 320ms
# 778:	learn: 0.3049610	total: 1.12s	remaining: 319ms
# 779:	learn: 0.3049479	total: 1.13s	remaining: 318ms
# 780:	learn: 0.3049298	total: 1.13s	remaining: 316ms
# 781:	learn: 0.3049154	total: 1.13s	remaining: 315ms
# 782:	learn: 0.3048977	total: 1.13s	remaining: 313ms
# 783:	learn: 0.3048850	total: 1.13s	remaining: 312ms
# 784:	learn: 0.3048765	total: 1.13s	remaining: 310ms
# 785:	learn: 0.3048610	total: 1.13s	remaining: 309ms
# 786:	learn: 0.3048462	total: 1.14s	remaining: 307ms
# 787:	learn: 0.3048378	total: 1.14s	remaining: 306ms
# 788:	learn: 0.3048279	total: 1.14s	remaining: 304ms
# 789:	learn: 0.3048118	total: 1.14s	remaining: 303ms
# 790:	learn: 0.3048007	total: 1.14s	remaining: 301ms
# 791:	learn: 0.3047861	total: 1.14s	remaining: 300ms
# 792:	learn: 0.3047755	total: 1.14s	remaining: 298ms
# 793:	learn: 0.3047702	total: 1.14s	remaining: 297ms
# 794:	learn: 0.3047555	total: 1.15s	remaining: 296ms
# 795:	learn: 0.3047349	total: 1.15s	remaining: 294ms
# 796:	learn: 0.3047259	total: 1.15s	remaining: 293ms
# 797:	learn: 0.3047097	total: 1.15s	remaining: 291ms
# 798:	learn: 0.3046995	total: 1.15s	remaining: 290ms
# 799:	learn: 0.3046838	total: 1.15s	remaining: 288ms
# 800:	learn: 0.3046736	total: 1.15s	remaining: 287ms
# 801:	learn: 0.3046595	total: 1.16s	remaining: 285ms
# 802:	learn: 0.3046456	total: 1.16s	remaining: 284ms
# 803:	learn: 0.3046297	total: 1.16s	remaining: 283ms
# 804:	learn: 0.3046138	total: 1.16s	remaining: 281ms
# 805:	learn: 0.3046069	total: 1.16s	remaining: 280ms
# 806:	learn: 0.3045834	total: 1.16s	remaining: 278ms
# 807:	learn: 0.3045698	total: 1.16s	remaining: 277ms
# 808:	learn: 0.3045603	total: 1.17s	remaining: 275ms
# 809:	learn: 0.3045499	total: 1.17s	remaining: 274ms
# 810:	learn: 0.3045352	total: 1.17s	remaining: 273ms
# 811:	learn: 0.3045289	total: 1.17s	remaining: 271ms
# 812:	learn: 0.3045143	total: 1.17s	remaining: 270ms
# 813:	learn: 0.3045072	total: 1.17s	remaining: 268ms
# 814:	learn: 0.3044971	total: 1.17s	remaining: 267ms
# 815:	learn: 0.3044815	total: 1.18s	remaining: 265ms
# 816:	learn: 0.3044723	total: 1.18s	remaining: 264ms
# 817:	learn: 0.3044604	total: 1.18s	remaining: 262ms
# 818:	learn: 0.3044455	total: 1.18s	remaining: 261ms
# 819:	learn: 0.3044264	total: 1.18s	remaining: 260ms
# 820:	learn: 0.3044188	total: 1.18s	remaining: 258ms
# 821:	learn: 0.3044043	total: 1.19s	remaining: 257ms
# 822:	learn: 0.3044001	total: 1.19s	remaining: 255ms
# 823:	learn: 0.3043907	total: 1.19s	remaining: 254ms
# 824:	learn: 0.3043787	total: 1.19s	remaining: 252ms
# 825:	learn: 0.3043676	total: 1.19s	remaining: 251ms
# 826:	learn: 0.3043635	total: 1.19s	remaining: 250ms
# 827:	learn: 0.3043516	total: 1.19s	remaining: 248ms
# 828:	learn: 0.3043454	total: 1.2s	remaining: 247ms
# 829:	learn: 0.3043280	total: 1.2s	remaining: 245ms
# 830:	learn: 0.3043167	total: 1.2s	remaining: 244ms
# 831:	learn: 0.3043101	total: 1.2s	remaining: 243ms
# 832:	learn: 0.3042951	total: 1.2s	remaining: 241ms
# 833:	learn: 0.3042871	total: 1.2s	remaining: 240ms
# 834:	learn: 0.3042667	total: 1.21s	remaining: 238ms
# 835:	learn: 0.3042575	total: 1.21s	remaining: 237ms
# 836:	learn: 0.3042407	total: 1.21s	remaining: 235ms
# 837:	learn: 0.3042309	total: 1.21s	remaining: 234ms
# 838:	learn: 0.3042204	total: 1.21s	remaining: 233ms
# 839:	learn: 0.3042056	total: 1.21s	remaining: 231ms
# 840:	learn: 0.3041853	total: 1.22s	remaining: 230ms
# 841:	learn: 0.3041695	total: 1.22s	remaining: 228ms
# 842:	learn: 0.3041596	total: 1.22s	remaining: 227ms
# 843:	learn: 0.3041437	total: 1.22s	remaining: 226ms
# 844:	learn: 0.3041294	total: 1.22s	remaining: 224ms
# 845:	learn: 0.3041234	total: 1.22s	remaining: 223ms
# 846:	learn: 0.3041104	total: 1.22s	remaining: 221ms
# 847:	learn: 0.3040926	total: 1.23s	remaining: 220ms
# 848:	learn: 0.3040742	total: 1.23s	remaining: 218ms
# 849:	learn: 0.3040654	total: 1.23s	remaining: 217ms
# 850:	learn: 0.3040593	total: 1.23s	remaining: 215ms
# 851:	learn: 0.3040518	total: 1.23s	remaining: 214ms
# 852:	learn: 0.3040428	total: 1.23s	remaining: 213ms
# 853:	learn: 0.3040330	total: 1.23s	remaining: 211ms
# 854:	learn: 0.3040175	total: 1.24s	remaining: 210ms
# 855:	learn: 0.3040055	total: 1.24s	remaining: 208ms
# 856:	learn: 0.3039940	total: 1.24s	remaining: 207ms
# 857:	learn: 0.3039824	total: 1.24s	remaining: 206ms
# 858:	learn: 0.3039652	total: 1.24s	remaining: 204ms
# 859:	learn: 0.3039544	total: 1.24s	remaining: 203ms
# 860:	learn: 0.3039445	total: 1.25s	remaining: 201ms
# 861:	learn: 0.3039255	total: 1.25s	remaining: 200ms
# 862:	learn: 0.3039216	total: 1.25s	remaining: 198ms
# 863:	learn: 0.3039125	total: 1.25s	remaining: 197ms
# 864:	learn: 0.3038992	total: 1.25s	remaining: 195ms
# 865:	learn: 0.3038945	total: 1.25s	remaining: 194ms
# 866:	learn: 0.3038859	total: 1.25s	remaining: 192ms
# 867:	learn: 0.3038785	total: 1.25s	remaining: 191ms
# 868:	learn: 0.3038668	total: 1.25s	remaining: 189ms
# 869:	learn: 0.3038651	total: 1.26s	remaining: 188ms
# 870:	learn: 0.3038541	total: 1.26s	remaining: 186ms
# 871:	learn: 0.3038425	total: 1.26s	remaining: 185ms
# 872:	learn: 0.3038295	total: 1.26s	remaining: 183ms
# 873:	learn: 0.3038150	total: 1.26s	remaining: 182ms
# 874:	learn: 0.3038015	total: 1.26s	remaining: 181ms
# 875:	learn: 0.3037951	total: 1.26s	remaining: 179ms
# 876:	learn: 0.3037930	total: 1.27s	remaining: 178ms
# 877:	learn: 0.3037846	total: 1.27s	remaining: 176ms
# 878:	learn: 0.3037756	total: 1.27s	remaining: 175ms
# 879:	learn: 0.3037691	total: 1.27s	remaining: 173ms
# 880:	learn: 0.3037649	total: 1.27s	remaining: 172ms
# 881:	learn: 0.3037561	total: 1.27s	remaining: 170ms
# 882:	learn: 0.3037477	total: 1.27s	remaining: 169ms
# 883:	learn: 0.3037377	total: 1.28s	remaining: 167ms
# 884:	learn: 0.3037246	total: 1.28s	remaining: 166ms
# 885:	learn: 0.3037066	total: 1.28s	remaining: 165ms
# 886:	learn: 0.3036981	total: 1.28s	remaining: 163ms
# 887:	learn: 0.3036899	total: 1.28s	remaining: 162ms
# 888:	learn: 0.3036800	total: 1.28s	remaining: 160ms
# 889:	learn: 0.3036726	total: 1.28s	remaining: 159ms
# 890:	learn: 0.3036658	total: 1.28s	remaining: 157ms
# 891:	learn: 0.3036530	total: 1.29s	remaining: 156ms
# 892:	learn: 0.3036423	total: 1.29s	remaining: 154ms
# 893:	learn: 0.3036305	total: 1.29s	remaining: 153ms
# 894:	learn: 0.3036193	total: 1.29s	remaining: 151ms
# 895:	learn: 0.3036099	total: 1.29s	remaining: 150ms
# 896:	learn: 0.3035963	total: 1.29s	remaining: 148ms
# 897:	learn: 0.3035833	total: 1.29s	remaining: 147ms
# 898:	learn: 0.3035778	total: 1.3s	remaining: 146ms
# 899:	learn: 0.3035634	total: 1.3s	remaining: 144ms
# 900:	learn: 0.3035448	total: 1.3s	remaining: 143ms
# 901:	learn: 0.3035358	total: 1.3s	remaining: 141ms
# 902:	learn: 0.3035290	total: 1.3s	remaining: 140ms
# 903:	learn: 0.3035215	total: 1.3s	remaining: 138ms
# 904:	learn: 0.3035093	total: 1.3s	remaining: 137ms
# 905:	learn: 0.3034932	total: 1.3s	remaining: 135ms
# 906:	learn: 0.3034912	total: 1.31s	remaining: 134ms
# 907:	learn: 0.3034872	total: 1.31s	remaining: 132ms
# 908:	learn: 0.3034776	total: 1.31s	remaining: 131ms
# 909:	learn: 0.3034688	total: 1.31s	remaining: 130ms
# 910:	learn: 0.3034591	total: 1.31s	remaining: 128ms
# 911:	learn: 0.3034481	total: 1.31s	remaining: 127ms
# 912:	learn: 0.3034333	total: 1.31s	remaining: 125ms
# 913:	learn: 0.3034235	total: 1.32s	remaining: 124ms
# 914:	learn: 0.3034106	total: 1.32s	remaining: 122ms
# 915:	learn: 0.3034008	total: 1.32s	remaining: 121ms
# 916:	learn: 0.3033909	total: 1.32s	remaining: 120ms
# 917:	learn: 0.3033783	total: 1.32s	remaining: 118ms
# 918:	learn: 0.3033692	total: 1.32s	remaining: 117ms
# 919:	learn: 0.3033537	total: 1.32s	remaining: 115ms
# 920:	learn: 0.3033405	total: 1.32s	remaining: 114ms
# 921:	learn: 0.3033273	total: 1.33s	remaining: 112ms
# 922:	learn: 0.3033191	total: 1.33s	remaining: 111ms
# 923:	learn: 0.3033070	total: 1.33s	remaining: 109ms
# 924:	learn: 0.3032950	total: 1.33s	remaining: 108ms
# 925:	learn: 0.3032880	total: 1.33s	remaining: 106ms
# 926:	learn: 0.3032762	total: 1.33s	remaining: 105ms
# 927:	learn: 0.3032678	total: 1.33s	remaining: 104ms
# 928:	learn: 0.3032663	total: 1.34s	remaining: 102ms
# 929:	learn: 0.3032558	total: 1.34s	remaining: 101ms
# 930:	learn: 0.3032494	total: 1.34s	remaining: 99.3ms
# 931:	learn: 0.3032347	total: 1.34s	remaining: 97.9ms
# 932:	learn: 0.3032268	total: 1.34s	remaining: 96.4ms
# 933:	learn: 0.3032197	total: 1.34s	remaining: 95ms
# 934:	learn: 0.3032122	total: 1.34s	remaining: 93.5ms
# 935:	learn: 0.3032061	total: 1.35s	remaining: 92ms
# 936:	learn: 0.3032043	total: 1.35s	remaining: 90.6ms
# 937:	learn: 0.3031875	total: 1.35s	remaining: 89.1ms
# 938:	learn: 0.3031816	total: 1.35s	remaining: 87.7ms
# 939:	learn: 0.3031680	total: 1.35s	remaining: 86.2ms
# 940:	learn: 0.3031586	total: 1.35s	remaining: 84.8ms
# 941:	learn: 0.3031514	total: 1.35s	remaining: 83.3ms
# 942:	learn: 0.3031423	total: 1.35s	remaining: 81.9ms
# 943:	learn: 0.3031313	total: 1.35s	remaining: 80.4ms
# 944:	learn: 0.3031195	total: 1.36s	remaining: 79ms
# 945:	learn: 0.3031136	total: 1.36s	remaining: 77.5ms
# 946:	learn: 0.3031070	total: 1.36s	remaining: 76.1ms
# 947:	learn: 0.3031010	total: 1.36s	remaining: 74.7ms
# 948:	learn: 0.3030901	total: 1.36s	remaining: 73.2ms
# 949:	learn: 0.3030838	total: 1.36s	remaining: 71.8ms
# 950:	learn: 0.3030737	total: 1.36s	remaining: 70.3ms
# 951:	learn: 0.3030677	total: 1.36s	remaining: 68.9ms
# 952:	learn: 0.3030536	total: 1.37s	remaining: 67.4ms
# 953:	learn: 0.3030435	total: 1.37s	remaining: 66ms
# 954:	learn: 0.3030335	total: 1.37s	remaining: 64.6ms
# 955:	learn: 0.3030217	total: 1.37s	remaining: 63.1ms
# 956:	learn: 0.3030130	total: 1.37s	remaining: 61.7ms
# 957:	learn: 0.3030020	total: 1.37s	remaining: 60.2ms
# 958:	learn: 0.3029938	total: 1.38s	remaining: 58.8ms
# 959:	learn: 0.3029869	total: 1.38s	remaining: 57.4ms
# 960:	learn: 0.3029781	total: 1.38s	remaining: 55.9ms
# 961:	learn: 0.3029742	total: 1.38s	remaining: 54.5ms
# 962:	learn: 0.3029647	total: 1.38s	remaining: 53.1ms
# 963:	learn: 0.3029494	total: 1.38s	remaining: 51.6ms
# 964:	learn: 0.3029383	total: 1.38s	remaining: 50.2ms
# 965:	learn: 0.3029262	total: 1.38s	remaining: 48.7ms
# 966:	learn: 0.3029139	total: 1.39s	remaining: 47.3ms
# 967:	learn: 0.3029041	total: 1.39s	remaining: 45.9ms
# 968:	learn: 0.3028965	total: 1.39s	remaining: 44.4ms
# 969:	learn: 0.3028884	total: 1.39s	remaining: 43ms
# 970:	learn: 0.3028847	total: 1.39s	remaining: 41.5ms
# 971:	learn: 0.3028775	total: 1.39s	remaining: 40.1ms
# 972:	learn: 0.3028719	total: 1.39s	remaining: 38.7ms
# 973:	learn: 0.3028582	total: 1.39s	remaining: 37.2ms
# 974:	learn: 0.3028547	total: 1.4s	remaining: 35.8ms
# 975:	learn: 0.3028458	total: 1.4s	remaining: 34.4ms
# 976:	learn: 0.3028346	total: 1.4s	remaining: 32.9ms
# 977:	learn: 0.3028282	total: 1.4s	remaining: 31.5ms
# 978:	learn: 0.3028203	total: 1.4s	remaining: 30ms
# 979:	learn: 0.3028169	total: 1.4s	remaining: 28.6ms
# 980:	learn: 0.3028094	total: 1.4s	remaining: 27.2ms
# 981:	learn: 0.3028015	total: 1.4s	remaining: 25.7ms
# 982:	learn: 0.3027947	total: 1.41s	remaining: 24.3ms
# 983:	learn: 0.3027842	total: 1.41s	remaining: 22.9ms
# 984:	learn: 0.3027763	total: 1.41s	remaining: 21.5ms
# 985:	learn: 0.3027676	total: 1.41s	remaining: 20ms
# 986:	learn: 0.3027621	total: 1.41s	remaining: 18.6ms
# 987:	learn: 0.3027470	total: 1.41s	remaining: 17.2ms
# 988:	learn: 0.3027367	total: 1.41s	remaining: 15.7ms
# 989:	learn: 0.3027292	total: 1.42s	remaining: 14.3ms
# 990:	learn: 0.3027182	total: 1.42s	remaining: 12.9ms
# 991:	learn: 0.3027095	total: 1.42s	remaining: 11.4ms
# 992:	learn: 0.3026993	total: 1.42s	remaining: 10ms
# 993:	learn: 0.3026915	total: 1.42s	remaining: 8.58ms
# 994:	learn: 0.3026821	total: 1.42s	remaining: 7.15ms
# 995:	learn: 0.3026788	total: 1.42s	remaining: 5.72ms
# 996:	learn: 0.3026667	total: 1.42s	remaining: 4.29ms
# 997:	learn: 0.3026573	total: 1.43s	remaining: 2.86ms
# 998:	learn: 0.3026540	total: 1.43s	remaining: 1.43ms
# 999:	learn: 0.3026508	total: 1.43s	remaining: 0us
# lr_results: {'RMSE': np.float64(0.3160139096495144), 'Rsquare': 0.6722679479203877}
#    index                               Feature  Importance
# 0      2                 cat__cluster_energy_3   29.668526
# 1      4                    cat__cluster_geo_2    8.530121
# 2      3                    cat__cluster_geo_1    7.064250
# 3     24  cat__district_Kensington and Chelsea    6.421359
# 4     50                  cat__property_type_F    5.721395
# 5     55          cat__freehold_or_leasehold_F    5.451963
# 6     56          cat__freehold_or_leasehold_L    5.047913
# 7     37             cat__district_Westminster    3.859409
# 8     48       cat__water_company_Thames Water    3.708731
# 9     49                  cat__property_type_D    2.133339

# %%
#Plotting feature importance for cat boost
sns.barplot(data=feature_importance_cat.head(10),x='Importance',y='Feature')
plt.title('Feature Importance (CatBoost)')
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error

#Defining a function to calculate performance metrics on untransformed price 
#Ie. performance metrics on actual price data 
#Includes R squared, RMSE, MAPE, Average profit

def scores(model,Xtest, Ytest):
    #Predicting the model
    pred=model.predict(Xtest)

    #Reduce prediction array dimension if necessary
    if hasattr(pred, "ndim") and pred.ndim > 1:
        pred = pred.ravel()

    #Undoing log transformation by taking e^y_hat -1
    pred_real=np.exp(pred)-1

    #Calculating RMSE
    rmse=mean_squared_error(Ytest,pred_real)
    rmse=np.sqrt(rmse)
    rmse=round(rmse,2)

    #Calculating R squared
    r2 = r2_score(Ytest, pred_real)
    r2=round(r2,2)

    #Calculating R squared on transformed Y
    r2_log=r2_score(np.log(Ytest),pred)
    r2_log=round(r2_log,2)

    #calculating MAPE
    mape=mean_absolute_percentage_error(Ytest,pred_real)
    mape=100*round(mape,2)

    #Calculating Average profit 
    average_profit=round(np.mean((pred_real-Ytest)/Ytest),4)*100
    return (rmse, r2_log,r2,mape, average_profit)

# %%
#Displaying performance metrics 

models=[lasso_best,en_best,rf_best,knn_best,knn_best2,knn_best3,gbm_best,xgb_best, cat_best]
model_names=['Lasso','Elastic Net','Random Forest','KNN (Geography)','KNN (Property features)','KNN All','GBM', 'XGB','CatBoost']

#Applying scores function on list of models
score=list(map(lambda l: scores(l,Xtest=X_test,Ytest=y_test),models))

#Transforming score tuple into a dataframe for visualisation
score_df= pd.DataFrame(score,columns=['RMSE (£)','R Squared (log Price)','R Squared (Actual)','MAPE (Actual)','Average Profit (%)'],index=model_names)
score_df
# Out:
#                           RMSE (£)  R Squared (log Price)  R Squared (Actual)  MAPE (Actual)  Average Profit (%)
# Lasso                    383632.99                   0.73                0.55           22.0                4.23
# Elastic Net              338445.25                   0.71                0.65           25.0               12.05
# Random Forest            245554.27                   0.85                0.81           16.0                2.37
# KNN (Geography)          399811.87                   0.64                0.51           25.0                5.29
# KNN (Property features)  407861.77                   0.62                0.49           25.0                4.86
# KNN All                  349881.64                   0.75                0.62           20.0                2.50
# GBM                      230136.43                   0.86                0.84           15.0                2.25
# XGB                      239208.81                   0.86                0.82           15.0                2.35
# CatBoost                 359654.95                   0.67                0.60           24.0                5.42

# %% [markdown]
# # Stacking
#
# Stacking was implemented to combine the predictions of multiple models by using base model predictions as features. Doing so allowed the stacked model to leverage the strengths of different models and enhance model predictive power. To achieve this, the similarities and dissimilarities of the base models were compared through seeing how strongly correlated each base model was to the others. The greater the correlation, the more similar two models are.

# %%
from sklearn.model_selection import cross_val_predict

#Using cross_val_predict to get CV predictions from previous models to build Stacking model
lasso_pred=cross_val_predict(lasso_best,X_train,Ytrain2, cv=5, method='predict')


en_pred=cross_val_predict(en_best,X_train,Ytrain2, cv=5,method='predict')


knn_pred=cross_val_predict(knn_best,X_train,Ytrain2, cv=5, method='predict')
knn_pred=[knn_pred[i][0] for i in range(len(knn_pred))]

knn_pred2=cross_val_predict(knn_best2,X_train,Ytrain2, cv=5, method='predict')
knn_pred2=[knn_pred2[i][0] for i in range(len(knn_pred2))]

knn_pred3=cross_val_predict(knn_best3,X_train,Ytrain2, cv=5, method='predict')
knn_pred3=[knn_pred3[i][0] for i in range(len(knn_pred3))]

rf_pred=cross_val_predict(rf_best,X_train,Ytrain2, cv=5, method='predict')

gbm_pred=cross_val_predict(gbm_best,X_train,Ytrain2, cv=5, method='predict')

gbm_pred2=cross_val_predict(gbm_best2,X_train,y_train, cv=5, method='predict')

xgb_pred=cross_val_predict(xgb_best,X_train,Ytrain2, cv=5, method='predict')

cat_pred=cross_val_predict(cat_best,X_train,Ytrain2, cv=5, method='predict')
# Out:
# 0:	learn: 0.5345490	total: 9.01ms	remaining: 9s
# 1:	learn: 0.5230177	total: 11.9ms	remaining: 5.91s
# 2:	learn: 0.5123946	total: 13.5ms	remaining: 4.49s
# 3:	learn: 0.5037966	total: 14.6ms	remaining: 3.63s
# 4:	learn: 0.4945477	total: 16.3ms	remaining: 3.25s
# 5:	learn: 0.4860634	total: 17ms	remaining: 2.82s
# 6:	learn: 0.4782709	total: 20ms	remaining: 2.83s
# 7:	learn: 0.4710879	total: 20.6ms	remaining: 2.55s
# 8:	learn: 0.4650720	total: 21.1ms	remaining: 2.33s
# 9:	learn: 0.4595547	total: 21.7ms	remaining: 2.15s
# 10:	learn: 0.4544981	total: 22.4ms	remaining: 2.01s
# 11:	learn: 0.4490165	total: 23ms	remaining: 1.89s
# 12:	learn: 0.4440212	total: 23.6ms	remaining: 1.79s
# 13:	learn: 0.4397505	total: 24.2ms	remaining: 1.71s
# 14:	learn: 0.4354254	total: 24.8ms	remaining: 1.63s
# 15:	learn: 0.4314819	total: 25.6ms	remaining: 1.57s
# 16:	learn: 0.4278889	total: 26.1ms	remaining: 1.51s
# 17:	learn: 0.4244629	total: 26.8ms	remaining: 1.46s
# 18:	learn: 0.4213355	total: 27.4ms	remaining: 1.41s
# 19:	learn: 0.4184315	total: 27.9ms	remaining: 1.37s
# 20:	learn: 0.4160273	total: 28.5ms	remaining: 1.33s
# 21:	learn: 0.4135265	total: 29ms	remaining: 1.29s
# 22:	learn: 0.4112463	total: 29.6ms	remaining: 1.26s
# 23:	learn: 0.4089345	total: 30.1ms	remaining: 1.23s
# 24:	learn: 0.4069635	total: 30.7ms	remaining: 1.2s
# 25:	learn: 0.4051934	total: 31.3ms	remaining: 1.17s
# 26:	learn: 0.4030492	total: 31.9ms	remaining: 1.15s
# 27:	learn: 0.4012025	total: 32.4ms	remaining: 1.13s
# 28:	learn: 0.3996521	total: 33.1ms	remaining: 1.11s
# 29:	learn: 0.3982048	total: 33.8ms	remaining: 1.09s
# 30:	learn: 0.3966931	total: 34.3ms	remaining: 1.07s
# 31:	learn: 0.3952857	total: 34.9ms	remaining: 1.05s
# 32:	learn: 0.3937619	total: 35.5ms	remaining: 1.04s
# 33:	learn: 0.3921903	total: 36.1ms	remaining: 1.02s
# 34:	learn: 0.3909316	total: 36.7ms	remaining: 1.01s
# 35:	learn: 0.3898027	total: 37.2ms	remaining: 997ms
# 36:	learn: 0.3885179	total: 37.8ms	remaining: 984ms
# 37:	learn: 0.3872320	total: 38.3ms	remaining: 971ms
# 38:	learn: 0.3859170	total: 38.9ms	remaining: 960ms
# 39:	learn: 0.3847412	total: 39.5ms	remaining: 948ms
# 40:	learn: 0.3836417	total: 40.1ms	remaining: 938ms
# 41:	learn: 0.3825853	total: 40.7ms	remaining: 928ms
# 42:	learn: 0.3815522	total: 41.3ms	remaining: 918ms
# 43:	learn: 0.3804727	total: 41.8ms	remaining: 909ms
# 44:	learn: 0.3794819	total: 42.4ms	remaining: 900ms
# 45:	learn: 0.3784838	total: 43ms	remaining: 891ms
# 46:	learn: 0.3774983	total: 43.5ms	remaining: 883ms
# 47:	learn: 0.3765751	total: 44.1ms	remaining: 875ms
# 48:	learn: 0.3756961	total: 44.6ms	remaining: 867ms
# 49:	learn: 0.3749023	total: 45.2ms	remaining: 858ms
# 50:	learn: 0.3739675	total: 45.7ms	remaining: 850ms
# 51:	learn: 0.3731802	total: 46.2ms	remaining: 842ms
# 52:	learn: 0.3723175	total: 46.8ms	remaining: 835ms
# 53:	learn: 0.3715957	total: 47.3ms	remaining: 828ms
# 54:	learn: 0.3708152	total: 47.8ms	remaining: 821ms
# 55:	learn: 0.3700138	total: 48.3ms	remaining: 815ms
# 56:	learn: 0.3692866	total: 49.2ms	remaining: 813ms
# 57:	learn: 0.3685997	total: 49.7ms	remaining: 807ms
# 58:	learn: 0.3677549	total: 50.2ms	remaining: 801ms
# 59:	learn: 0.3671265	total: 50.8ms	remaining: 796ms
# 60:	learn: 0.3664892	total: 51.4ms	remaining: 791ms
# 61:	learn: 0.3659141	total: 51.9ms	remaining: 785ms
# 62:	learn: 0.3652386	total: 52.4ms	remaining: 779ms
# 63:	learn: 0.3646585	total: 52.9ms	remaining: 774ms
# 64:	learn: 0.3640880	total: 53.5ms	remaining: 770ms
# 65:	learn: 0.3634592	total: 54.1ms	remaining: 765ms
# 66:	learn: 0.3628684	total: 54.7ms	remaining: 762ms
# 67:	learn: 0.3621752	total: 55.3ms	remaining: 758ms
# 68:	learn: 0.3615541	total: 56ms	remaining: 755ms
# 69:	learn: 0.3609707	total: 56.7ms	remaining: 753ms
# 70:	learn: 0.3605163	total: 57.2ms	remaining: 749ms
# 71:	learn: 0.3598729	total: 57.8ms	remaining: 745ms
# 72:	learn: 0.3591851	total: 58.5ms	remaining: 742ms
# 73:	learn: 0.3585917	total: 59.1ms	remaining: 739ms
# 74:	learn: 0.3580294	total: 59.6ms	remaining: 735ms
# 75:	learn: 0.3574823	total: 60.2ms	remaining: 732ms
# 76:	learn: 0.3569661	total: 60.9ms	remaining: 730ms
# 77:	learn: 0.3564681	total: 61.5ms	remaining: 727ms
# 78:	learn: 0.3559458	total: 62.3ms	remaining: 726ms
# 79:	learn: 0.3555101	total: 62.9ms	remaining: 723ms
# 80:	learn: 0.3550414	total: 63.5ms	remaining: 720ms
# 81:	learn: 0.3544420	total: 64.2ms	remaining: 718ms
# 82:	learn: 0.3539288	total: 65ms	remaining: 718ms
# 83:	learn: 0.3534594	total: 65.7ms	remaining: 716ms
# 84:	learn: 0.3529989	total: 66.2ms	remaining: 713ms
# 85:	learn: 0.3525495	total: 66.8ms	remaining: 710ms
# 86:	learn: 0.3521655	total: 67.4ms	remaining: 707ms
# 87:	learn: 0.3518221	total: 67.9ms	remaining: 704ms
# 88:	learn: 0.3514210	total: 68.5ms	remaining: 701ms
# 89:	learn: 0.3510519	total: 69.1ms	remaining: 698ms
# 90:	learn: 0.3506628	total: 69.7ms	remaining: 696ms
# 91:	learn: 0.3502042	total: 70.3ms	remaining: 694ms
# 92:	learn: 0.3497579	total: 70.8ms	remaining: 691ms
# 93:	learn: 0.3494286	total: 71.4ms	remaining: 688ms
# 94:	learn: 0.3489927	total: 72.1ms	remaining: 687ms
# 95:	learn: 0.3487372	total: 72.7ms	remaining: 684ms
# 96:	learn: 0.3484325	total: 73.3ms	remaining: 682ms
# 97:	learn: 0.3480538	total: 73.9ms	remaining: 680ms
# 98:	learn: 0.3476461	total: 74.4ms	remaining: 677ms
# 99:	learn: 0.3473382	total: 75ms	remaining: 675ms
# 100:	learn: 0.3470293	total: 75.4ms	remaining: 672ms
# 101:	learn: 0.3466966	total: 76ms	remaining: 669ms
# 102:	learn: 0.3463373	total: 76.6ms	remaining: 667ms
# 103:	learn: 0.3460178	total: 77.2ms	remaining: 665ms
# 104:	learn: 0.3457442	total: 77.7ms	remaining: 663ms
# 105:	learn: 0.3455103	total: 78.3ms	remaining: 660ms
# 106:	learn: 0.3451567	total: 78.8ms	remaining: 658ms
# 107:	learn: 0.3447800	total: 79.4ms	remaining: 656ms
# 108:	learn: 0.3445415	total: 80ms	remaining: 654ms
# 109:	learn: 0.3441921	total: 80.6ms	remaining: 652ms
# 110:	learn: 0.3439190	total: 81.5ms	remaining: 652ms
# 111:	learn: 0.3436187	total: 82.1ms	remaining: 651ms
# 112:	learn: 0.3433693	total: 82.6ms	remaining: 649ms
# 113:	learn: 0.3431308	total: 83.2ms	remaining: 647ms
# 114:	learn: 0.3428405	total: 83.8ms	remaining: 645ms
# 115:	learn: 0.3424623	total: 84.8ms	remaining: 646ms
# 116:	learn: 0.3422430	total: 85.4ms	remaining: 644ms
# 117:	learn: 0.3419801	total: 86.2ms	remaining: 644ms
# 118:	learn: 0.3417202	total: 87.1ms	remaining: 645ms
# 119:	learn: 0.3414106	total: 87.7ms	remaining: 643ms
# 120:	learn: 0.3412175	total: 88.3ms	remaining: 642ms
# 121:	learn: 0.3409974	total: 89ms	remaining: 641ms
# 122:	learn: 0.3407369	total: 89.6ms	remaining: 639ms
# 123:	learn: 0.3404728	total: 90.2ms	remaining: 637ms
# 124:	learn: 0.3401731	total: 90.8ms	remaining: 636ms
# 125:	learn: 0.3398325	total: 91.6ms	remaining: 635ms
# 126:	learn: 0.3395663	total: 92.3ms	remaining: 635ms
# 127:	learn: 0.3393146	total: 92.9ms	remaining: 633ms
# 128:	learn: 0.3391092	total: 93.5ms	remaining: 632ms
# 129:	learn: 0.3388154	total: 94.2ms	remaining: 630ms
# 130:	learn: 0.3385776	total: 95.4ms	remaining: 633ms
# 131:	learn: 0.3383468	total: 96.2ms	remaining: 633ms
# 132:	learn: 0.3380636	total: 96.9ms	remaining: 632ms
# 133:	learn: 0.3378551	total: 97.6ms	remaining: 631ms
# 134:	learn: 0.3376368	total: 98.3ms	remaining: 630ms
# 135:	learn: 0.3374167	total: 98.9ms	remaining: 629ms
# 136:	learn: 0.3371894	total: 99.5ms	remaining: 627ms
# 137:	learn: 0.3369726	total: 100ms	remaining: 626ms
# 138:	learn: 0.3367592	total: 101ms	remaining: 624ms
# 139:	learn: 0.3365280	total: 102ms	remaining: 625ms
# 140:	learn: 0.3363055	total: 102ms	remaining: 624ms
# 141:	learn: 0.3361081	total: 103ms	remaining: 622ms
# 142:	learn: 0.3358088	total: 104ms	remaining: 621ms
# 143:	learn: 0.3355767	total: 104ms	remaining: 619ms
# 144:	learn: 0.3354382	total: 105ms	remaining: 618ms
# 145:	learn: 0.3352476	total: 105ms	remaining: 617ms
# 146:	learn: 0.3350766	total: 106ms	remaining: 615ms
# 147:	learn: 0.3348889	total: 107ms	remaining: 614ms
# 148:	learn: 0.3347024	total: 107ms	remaining: 613ms
# 149:	learn: 0.3345565	total: 109ms	remaining: 616ms
# 150:	learn: 0.3343473	total: 110ms	remaining: 616ms
# 151:	learn: 0.3341588	total: 110ms	remaining: 616ms
# 152:	learn: 0.3340000	total: 112ms	remaining: 617ms
# 153:	learn: 0.3338526	total: 112ms	remaining: 617ms
# 154:	learn: 0.3337049	total: 113ms	remaining: 617ms
# 155:	learn: 0.3335447	total: 114ms	remaining: 615ms
# 156:	learn: 0.3334105	total: 114ms	remaining: 614ms
# 157:	learn: 0.3331492	total: 115ms	remaining: 613ms
# 158:	learn: 0.3329822	total: 116ms	remaining: 612ms
# 159:	learn: 0.3328079	total: 116ms	remaining: 610ms
# 160:	learn: 0.3326340	total: 117ms	remaining: 609ms
# 161:	learn: 0.3324753	total: 117ms	remaining: 608ms
# 162:	learn: 0.3322839	total: 118ms	remaining: 606ms
# 163:	learn: 0.3321243	total: 119ms	remaining: 605ms
# 164:	learn: 0.3319917	total: 119ms	remaining: 604ms
# 165:	learn: 0.3318049	total: 120ms	remaining: 603ms
# 166:	learn: 0.3316013	total: 121ms	remaining: 603ms
# 167:	learn: 0.3314486	total: 121ms	remaining: 601ms
# 168:	learn: 0.3313024	total: 122ms	remaining: 600ms
# 169:	learn: 0.3311580	total: 123ms	remaining: 599ms
# 170:	learn: 0.3309930	total: 123ms	remaining: 597ms
# 171:	learn: 0.3308437	total: 124ms	remaining: 596ms
# 172:	learn: 0.3306903	total: 124ms	remaining: 595ms
# 173:	learn: 0.3305550	total: 125ms	remaining: 595ms
# 174:	learn: 0.3304216	total: 126ms	remaining: 594ms
# 175:	learn: 0.3302774	total: 127ms	remaining: 593ms
# 176:	learn: 0.3301384	total: 127ms	remaining: 592ms
# 177:	learn: 0.3299815	total: 128ms	remaining: 591ms
# 178:	learn: 0.3298395	total: 129ms	remaining: 591ms
# 179:	learn: 0.3296542	total: 129ms	remaining: 590ms
# 180:	learn: 0.3295209	total: 130ms	remaining: 588ms
# 181:	learn: 0.3293767	total: 131ms	remaining: 587ms
# 182:	learn: 0.3292493	total: 131ms	remaining: 586ms
# 183:	learn: 0.3291157	total: 132ms	remaining: 585ms
# 184:	learn: 0.3289918	total: 132ms	remaining: 583ms
# 185:	learn: 0.3288576	total: 133ms	remaining: 582ms
# 186:	learn: 0.3287404	total: 134ms	remaining: 580ms
# 187:	learn: 0.3286206	total: 134ms	remaining: 579ms
# 188:	learn: 0.3284865	total: 135ms	remaining: 578ms
# 189:	learn: 0.3283141	total: 135ms	remaining: 576ms
# 190:	learn: 0.3281963	total: 136ms	remaining: 575ms
# 191:	learn: 0.3280662	total: 136ms	remaining: 573ms
# 192:	learn: 0.3279440	total: 137ms	remaining: 572ms
# 193:	learn: 0.3278123	total: 137ms	remaining: 570ms
# 194:	learn: 0.3276927	total: 138ms	remaining: 569ms
# 195:	learn: 0.3275342	total: 138ms	remaining: 568ms
# 196:	learn: 0.3273621	total: 139ms	remaining: 566ms
# 197:	learn: 0.3272406	total: 140ms	remaining: 565ms
# 198:	learn: 0.3271324	total: 140ms	remaining: 565ms
# 199:	learn: 0.3270228	total: 141ms	remaining: 565ms
# 200:	learn: 0.3269197	total: 142ms	remaining: 564ms
# 201:	learn: 0.3268070	total: 143ms	remaining: 564ms
# 202:	learn: 0.3267058	total: 144ms	remaining: 564ms
# 203:	learn: 0.3266062	total: 145ms	remaining: 566ms
# 204:	learn: 0.3264921	total: 146ms	remaining: 566ms
# 205:	learn: 0.3263867	total: 147ms	remaining: 566ms
# 206:	learn: 0.3262402	total: 147ms	remaining: 565ms
# 207:	learn: 0.3261078	total: 148ms	remaining: 565ms
# 208:	learn: 0.3260030	total: 149ms	remaining: 564ms
# 209:	learn: 0.3259035	total: 150ms	remaining: 563ms
# 210:	learn: 0.3258097	total: 151ms	remaining: 563ms
# 211:	learn: 0.3256951	total: 151ms	remaining: 563ms
# 212:	learn: 0.3255957	total: 152ms	remaining: 562ms
# 213:	learn: 0.3255059	total: 153ms	remaining: 561ms
# 214:	learn: 0.3254034	total: 154ms	remaining: 562ms
# 215:	learn: 0.3253045	total: 155ms	remaining: 562ms
# 216:	learn: 0.3251215	total: 156ms	remaining: 564ms
# 217:	learn: 0.3250194	total: 157ms	remaining: 563ms
# 218:	learn: 0.3249225	total: 158ms	remaining: 564ms
# 219:	learn: 0.3248247	total: 160ms	remaining: 566ms
# 220:	learn: 0.3246692	total: 161ms	remaining: 566ms
# 221:	learn: 0.3245559	total: 162ms	remaining: 567ms
# 222:	learn: 0.3244540	total: 162ms	remaining: 566ms
# 223:	learn: 0.3243592	total: 163ms	remaining: 565ms
# 224:	learn: 0.3242701	total: 164ms	remaining: 564ms
# 225:	learn: 0.3241592	total: 164ms	remaining: 563ms
# 226:	learn: 0.3240672	total: 165ms	remaining: 562ms
# 227:	learn: 0.3239828	total: 166ms	remaining: 561ms
# 228:	learn: 0.3238446	total: 166ms	remaining: 560ms
# 229:	learn: 0.3237485	total: 167ms	remaining: 558ms
# 230:	learn: 0.3236622	total: 167ms	remaining: 557ms
# 231:	learn: 0.3235382	total: 168ms	remaining: 556ms
# 232:	learn: 0.3234577	total: 168ms	remaining: 555ms
# 233:	learn: 0.3233642	total: 169ms	remaining: 553ms
# 234:	learn: 0.3232724	total: 170ms	remaining: 552ms
# 235:	learn: 0.3231193	total: 170ms	remaining: 551ms
# 236:	learn: 0.3230203	total: 171ms	remaining: 550ms
# 237:	learn: 0.3229346	total: 173ms	remaining: 553ms
# 238:	learn: 0.3228532	total: 173ms	remaining: 552ms
# 239:	learn: 0.3227468	total: 174ms	remaining: 551ms
# 240:	learn: 0.3226618	total: 175ms	remaining: 550ms
# 241:	learn: 0.3225791	total: 175ms	remaining: 549ms
# 242:	learn: 0.3224972	total: 176ms	remaining: 549ms
# 243:	learn: 0.3224152	total: 177ms	remaining: 548ms
# 244:	learn: 0.3223377	total: 177ms	remaining: 547ms
# 245:	learn: 0.3222560	total: 178ms	remaining: 546ms
# 246:	learn: 0.3221745	total: 179ms	remaining: 545ms
# 247:	learn: 0.3220889	total: 179ms	remaining: 544ms
# 248:	learn: 0.3220136	total: 180ms	remaining: 543ms
# 249:	learn: 0.3219244	total: 181ms	remaining: 542ms
# 250:	learn: 0.3218437	total: 181ms	remaining: 541ms
# 251:	learn: 0.3217762	total: 182ms	remaining: 539ms
# 252:	learn: 0.3217015	total: 182ms	remaining: 538ms
# 253:	learn: 0.3216282	total: 183ms	remaining: 538ms
# 254:	learn: 0.3215688	total: 184ms	remaining: 538ms
# 255:	learn: 0.3214540	total: 185ms	remaining: 537ms
# 256:	learn: 0.3213854	total: 186ms	remaining: 537ms
# 257:	learn: 0.3213083	total: 187ms	remaining: 537ms
# 258:	learn: 0.3212379	total: 188ms	remaining: 537ms
# 259:	learn: 0.3211520	total: 188ms	remaining: 536ms
# 260:	learn: 0.3210338	total: 189ms	remaining: 535ms
# 261:	learn: 0.3209604	total: 201ms	remaining: 567ms
# 262:	learn: 0.3208361	total: 202ms	remaining: 566ms
# 263:	learn: 0.3207478	total: 203ms	remaining: 565ms
# 264:	learn: 0.3206742	total: 204ms	remaining: 565ms
# 265:	learn: 0.3205706	total: 205ms	remaining: 566ms
# 266:	learn: 0.3205005	total: 206ms	remaining: 564ms
# 267:	learn: 0.3203874	total: 206ms	remaining: 564ms
# 268:	learn: 0.3203246	total: 207ms	remaining: 563ms
# 269:	learn: 0.3202049	total: 208ms	remaining: 562ms
# 270:	learn: 0.3201423	total: 208ms	remaining: 560ms
# 271:	learn: 0.3200747	total: 209ms	remaining: 559ms
# 272:	learn: 0.3199618	total: 209ms	remaining: 558ms
# 273:	learn: 0.3198868	total: 210ms	remaining: 557ms
# 274:	learn: 0.3197954	total: 211ms	remaining: 556ms
# 275:	learn: 0.3197259	total: 211ms	remaining: 554ms
# 276:	learn: 0.3196516	total: 212ms	remaining: 554ms
# 277:	learn: 0.3195558	total: 213ms	remaining: 553ms
# 278:	learn: 0.3194634	total: 213ms	remaining: 552ms
# 279:	learn: 0.3193947	total: 214ms	remaining: 550ms
# 280:	learn: 0.3192883	total: 215ms	remaining: 550ms
# 281:	learn: 0.3192383	total: 216ms	remaining: 549ms
# 282:	learn: 0.3191755	total: 216ms	remaining: 548ms
# 283:	learn: 0.3190702	total: 217ms	remaining: 547ms
# 284:	learn: 0.3190078	total: 217ms	remaining: 545ms
# 285:	learn: 0.3189493	total: 218ms	remaining: 544ms
# 286:	learn: 0.3188654	total: 219ms	remaining: 544ms
# 287:	learn: 0.3187861	total: 220ms	remaining: 543ms
# 288:	learn: 0.3186890	total: 220ms	remaining: 542ms
# 289:	learn: 0.3186385	total: 221ms	remaining: 541ms
# 290:	learn: 0.3185787	total: 222ms	remaining: 541ms
# 291:	learn: 0.3185196	total: 223ms	remaining: 540ms
# 292:	learn: 0.3184463	total: 223ms	remaining: 539ms
# 293:	learn: 0.3183934	total: 224ms	remaining: 538ms
# 294:	learn: 0.3183186	total: 225ms	remaining: 538ms
# 295:	learn: 0.3182286	total: 226ms	remaining: 538ms
# 296:	learn: 0.3181390	total: 227ms	remaining: 538ms
# 297:	learn: 0.3180693	total: 228ms	remaining: 537ms
# 298:	learn: 0.3180000	total: 229ms	remaining: 536ms
# 299:	learn: 0.3179298	total: 230ms	remaining: 536ms
# 300:	learn: 0.3178785	total: 230ms	remaining: 535ms
# 301:	learn: 0.3178154	total: 231ms	remaining: 534ms
# 302:	learn: 0.3177706	total: 232ms	remaining: 534ms
# 303:	learn: 0.3177078	total: 234ms	remaining: 536ms
# 304:	learn: 0.3176530	total: 236ms	remaining: 537ms
# 305:	learn: 0.3175918	total: 237ms	remaining: 537ms
# 306:	learn: 0.3174757	total: 238ms	remaining: 536ms
# 307:	learn: 0.3174195	total: 238ms	remaining: 536ms
# 308:	learn: 0.3173499	total: 239ms	remaining: 535ms
# 309:	learn: 0.3172613	total: 240ms	remaining: 535ms
# 310:	learn: 0.3172057	total: 241ms	remaining: 534ms
# 311:	learn: 0.3171479	total: 242ms	remaining: 533ms
# 312:	learn: 0.3170907	total: 243ms	remaining: 533ms
# 313:	learn: 0.3170124	total: 244ms	remaining: 532ms
# 314:	learn: 0.3169715	total: 244ms	remaining: 531ms
# 315:	learn: 0.3169112	total: 248ms	remaining: 536ms
# 316:	learn: 0.3168246	total: 250ms	remaining: 538ms
# 317:	learn: 0.3167633	total: 251ms	remaining: 537ms
# 318:	learn: 0.3167153	total: 251ms	remaining: 536ms
# 319:	learn: 0.3166331	total: 252ms	remaining: 535ms
# 320:	learn: 0.3165831	total: 252ms	remaining: 534ms
# 321:	learn: 0.3165333	total: 253ms	remaining: 533ms
# 322:	learn: 0.3164937	total: 253ms	remaining: 531ms
# 323:	learn: 0.3164381	total: 254ms	remaining: 530ms
# 324:	learn: 0.3163799	total: 255ms	remaining: 529ms
# 325:	learn: 0.3163323	total: 255ms	remaining: 528ms
# 326:	learn: 0.3162834	total: 256ms	remaining: 527ms
# 327:	learn: 0.3162370	total: 257ms	remaining: 526ms
# 328:	learn: 0.3161627	total: 257ms	remaining: 525ms
# 329:	learn: 0.3160744	total: 259ms	remaining: 525ms
# 330:	learn: 0.3160199	total: 260ms	remaining: 525ms
# 331:	learn: 0.3159580	total: 261ms	remaining: 525ms
# 332:	learn: 0.3158822	total: 264ms	remaining: 528ms
# 333:	learn: 0.3158165	total: 265ms	remaining: 528ms
# 334:	learn: 0.3157443	total: 266ms	remaining: 528ms
# 335:	learn: 0.3157017	total: 267ms	remaining: 527ms
# 336:	learn: 0.3156615	total: 269ms	remaining: 529ms
# 337:	learn: 0.3155942	total: 271ms	remaining: 531ms
# 338:	learn: 0.3155506	total: 274ms	remaining: 534ms
# 339:	learn: 0.3155027	total: 284ms	remaining: 551ms
# 340:	learn: 0.3154463	total: 288ms	remaining: 557ms
# 341:	learn: 0.3154019	total: 291ms	remaining: 560ms
# 342:	learn: 0.3153335	total: 294ms	remaining: 563ms
# 343:	learn: 0.3152897	total: 295ms	remaining: 563ms
# 344:	learn: 0.3152463	total: 297ms	remaining: 563ms
# 345:	learn: 0.3151961	total: 297ms	remaining: 562ms
# 346:	learn: 0.3151598	total: 300ms	remaining: 564ms
# 347:	learn: 0.3151173	total: 302ms	remaining: 565ms
# 348:	learn: 0.3150845	total: 304ms	remaining: 566ms
# 349:	learn: 0.3150231	total: 305ms	remaining: 566ms
# 350:	learn: 0.3149605	total: 306ms	remaining: 566ms
# 351:	learn: 0.3149275	total: 308ms	remaining: 566ms
# 352:	learn: 0.3148849	total: 309ms	remaining: 566ms
# 353:	learn: 0.3148203	total: 310ms	remaining: 566ms
# 354:	learn: 0.3147733	total: 311ms	remaining: 565ms
# 355:	learn: 0.3147426	total: 312ms	remaining: 564ms
# 356:	learn: 0.3147007	total: 313ms	remaining: 564ms
# 357:	learn: 0.3146400	total: 315ms	remaining: 564ms
# 358:	learn: 0.3145733	total: 318ms	remaining: 568ms
# 359:	learn: 0.3145449	total: 319ms	remaining: 568ms
# 360:	learn: 0.3145036	total: 320ms	remaining: 567ms
# 361:	learn: 0.3144392	total: 321ms	remaining: 567ms
# 362:	learn: 0.3143783	total: 322ms	remaining: 565ms
# 363:	learn: 0.3143160	total: 323ms	remaining: 565ms
# 364:	learn: 0.3142763	total: 325ms	remaining: 565ms
# 365:	learn: 0.3142236	total: 326ms	remaining: 565ms
# 366:	learn: 0.3141949	total: 327ms	remaining: 564ms
# 367:	learn: 0.3141322	total: 329ms	remaining: 565ms
# 368:	learn: 0.3140496	total: 331ms	remaining: 566ms
# 369:	learn: 0.3140091	total: 334ms	remaining: 568ms
# 370:	learn: 0.3139731	total: 336ms	remaining: 569ms
# 371:	learn: 0.3139282	total: 337ms	remaining: 569ms
# 372:	learn: 0.3138531	total: 339ms	remaining: 570ms
# 373:	learn: 0.3138160	total: 341ms	remaining: 570ms
# 374:	learn: 0.3137882	total: 346ms	remaining: 577ms
# 375:	learn: 0.3137315	total: 348ms	remaining: 578ms
# 376:	learn: 0.3136919	total: 351ms	remaining: 581ms
# 377:	learn: 0.3136513	total: 354ms	remaining: 583ms
# 378:	learn: 0.3136253	total: 356ms	remaining: 584ms
# 379:	learn: 0.3135908	total: 367ms	remaining: 599ms
# 380:	learn: 0.3135465	total: 368ms	remaining: 598ms
# 381:	learn: 0.3135190	total: 369ms	remaining: 597ms
# 382:	learn: 0.3134483	total: 371ms	remaining: 597ms
# 383:	learn: 0.3134059	total: 376ms	remaining: 603ms
# 384:	learn: 0.3133700	total: 377ms	remaining: 602ms
# 385:	learn: 0.3133327	total: 378ms	remaining: 601ms
# 386:	learn: 0.3132770	total: 386ms	remaining: 611ms
# 387:	learn: 0.3132405	total: 391ms	remaining: 616ms
# 388:	learn: 0.3131948	total: 402ms	remaining: 631ms
# 389:	learn: 0.3131703	total: 415ms	remaining: 649ms
# 390:	learn: 0.3131187	total: 417ms	remaining: 649ms
# 391:	learn: 0.3130691	total: 423ms	remaining: 656ms
# 392:	learn: 0.3130343	total: 425ms	remaining: 656ms
# 393:	learn: 0.3129790	total: 427ms	remaining: 657ms
# 394:	learn: 0.3129221	total: 431ms	remaining: 661ms
# 395:	learn: 0.3128768	total: 435ms	remaining: 664ms
# 396:	learn: 0.3128421	total: 438ms	remaining: 665ms
# 397:	learn: 0.3127735	total: 439ms	remaining: 664ms
# 398:	learn: 0.3127410	total: 441ms	remaining: 664ms
# 399:	learn: 0.3126964	total: 443ms	remaining: 664ms
# 400:	learn: 0.3126404	total: 451ms	remaining: 674ms
# 401:	learn: 0.3125989	total: 453ms	remaining: 674ms
# 402:	learn: 0.3125850	total: 454ms	remaining: 673ms
# 403:	learn: 0.3125487	total: 456ms	remaining: 672ms
# 404:	learn: 0.3125084	total: 471ms	remaining: 691ms
# 405:	learn: 0.3124826	total: 478ms	remaining: 700ms
# 406:	learn: 0.3124502	total: 483ms	remaining: 704ms
# 407:	learn: 0.3123858	total: 484ms	remaining: 703ms
# 408:	learn: 0.3123527	total: 490ms	remaining: 708ms
# 409:	learn: 0.3123068	total: 497ms	remaining: 715ms
# 410:	learn: 0.3122720	total: 505ms	remaining: 724ms
# 411:	learn: 0.3122500	total: 508ms	remaining: 724ms
# 412:	learn: 0.3122159	total: 511ms	remaining: 727ms
# 413:	learn: 0.3121840	total: 513ms	remaining: 726ms
# 414:	learn: 0.3121616	total: 516ms	remaining: 727ms
# 415:	learn: 0.3121384	total: 518ms	remaining: 728ms
# 416:	learn: 0.3121084	total: 525ms	remaining: 734ms
# 417:	learn: 0.3120771	total: 530ms	remaining: 738ms
# 418:	learn: 0.3120330	total: 533ms	remaining: 739ms
# 419:	learn: 0.3120211	total: 538ms	remaining: 743ms
# 420:	learn: 0.3119857	total: 540ms	remaining: 742ms
# 421:	learn: 0.3119536	total: 541ms	remaining: 741ms
# 422:	learn: 0.3119208	total: 543ms	remaining: 741ms
# 423:	learn: 0.3119000	total: 544ms	remaining: 740ms
# 424:	learn: 0.3118637	total: 545ms	remaining: 738ms
# 425:	learn: 0.3118182	total: 546ms	remaining: 736ms
# 426:	learn: 0.3117993	total: 554ms	remaining: 743ms
# 427:	learn: 0.3117702	total: 563ms	remaining: 752ms
# 428:	learn: 0.3117145	total: 566ms	remaining: 754ms
# 429:	learn: 0.3116681	total: 569ms	remaining: 754ms
# 430:	learn: 0.3116255	total: 570ms	remaining: 753ms
# 431:	learn: 0.3115677	total: 572ms	remaining: 752ms
# 432:	learn: 0.3115403	total: 573ms	remaining: 751ms
# 433:	learn: 0.3115048	total: 574ms	remaining: 749ms
# 434:	learn: 0.3114765	total: 576ms	remaining: 748ms
# 435:	learn: 0.3114439	total: 580ms	remaining: 750ms
# 436:	learn: 0.3114169	total: 581ms	remaining: 749ms
# 437:	learn: 0.3113884	total: 582ms	remaining: 747ms
# 438:	learn: 0.3113508	total: 584ms	remaining: 746ms
# 439:	learn: 0.3113222	total: 586ms	remaining: 746ms
# 440:	learn: 0.3112927	total: 589ms	remaining: 746ms
# 441:	learn: 0.3112603	total: 591ms	remaining: 746ms
# 442:	learn: 0.3112495	total: 596ms	remaining: 750ms
# 443:	learn: 0.3112200	total: 599ms	remaining: 750ms
# 444:	learn: 0.3111915	total: 601ms	remaining: 750ms
# 445:	learn: 0.3111463	total: 603ms	remaining: 748ms
# 446:	learn: 0.3110931	total: 604ms	remaining: 748ms
# 447:	learn: 0.3110375	total: 605ms	remaining: 745ms
# 448:	learn: 0.3110091	total: 606ms	remaining: 743ms
# 449:	learn: 0.3109623	total: 607ms	remaining: 742ms
# 450:	learn: 0.3109363	total: 613ms	remaining: 747ms
# 451:	learn: 0.3108745	total: 614ms	remaining: 745ms
# 452:	learn: 0.3108307	total: 616ms	remaining: 744ms
# 453:	learn: 0.3107904	total: 618ms	remaining: 743ms
# 454:	learn: 0.3107731	total: 619ms	remaining: 741ms
# 455:	learn: 0.3107525	total: 620ms	remaining: 740ms
# 456:	learn: 0.3107334	total: 624ms	remaining: 742ms
# 457:	learn: 0.3107022	total: 626ms	remaining: 741ms
# 458:	learn: 0.3106925	total: 626ms	remaining: 738ms
# 459:	learn: 0.3106594	total: 627ms	remaining: 737ms
# 460:	learn: 0.3106314	total: 628ms	remaining: 734ms
# 461:	learn: 0.3106138	total: 629ms	remaining: 733ms
# 462:	learn: 0.3105895	total: 631ms	remaining: 732ms
# 463:	learn: 0.3105455	total: 634ms	remaining: 732ms
# 464:	learn: 0.3105144	total: 637ms	remaining: 733ms
# 465:	learn: 0.3104892	total: 641ms	remaining: 735ms
# 466:	learn: 0.3104587	total: 642ms	remaining: 733ms
# 467:	learn: 0.3104131	total: 643ms	remaining: 731ms
# 468:	learn: 0.3103886	total: 644ms	remaining: 729ms
# 469:	learn: 0.3103631	total: 645ms	remaining: 728ms
# 470:	learn: 0.3103250	total: 647ms	remaining: 727ms
# 471:	learn: 0.3103157	total: 649ms	remaining: 727ms
# 472:	learn: 0.3102860	total: 650ms	remaining: 725ms
# 473:	learn: 0.3102306	total: 651ms	remaining: 723ms
# 474:	learn: 0.3101806	total: 655ms	remaining: 724ms
# 475:	learn: 0.3101541	total: 656ms	remaining: 722ms
# 476:	learn: 0.3101273	total: 657ms	remaining: 720ms
# 477:	learn: 0.3100918	total: 682ms	remaining: 745ms
# 478:	learn: 0.3100634	total: 687ms	remaining: 747ms
# 479:	learn: 0.3100367	total: 689ms	remaining: 746ms
# 480:	learn: 0.3100085	total: 690ms	remaining: 744ms
# 481:	learn: 0.3099915	total: 690ms	remaining: 742ms
# 482:	learn: 0.3099694	total: 692ms	remaining: 741ms
# 483:	learn: 0.3099326	total: 694ms	remaining: 740ms
# 484:	learn: 0.3098904	total: 695ms	remaining: 738ms
# 485:	learn: 0.3098524	total: 696ms	remaining: 736ms
# 486:	learn: 0.3098279	total: 696ms	remaining: 734ms
# 487:	learn: 0.3097998	total: 699ms	remaining: 734ms
# 488:	learn: 0.3097763	total: 704ms	remaining: 736ms
# 489:	learn: 0.3097487	total: 706ms	remaining: 735ms
# 490:	learn: 0.3097112	total: 707ms	remaining: 733ms
# 491:	learn: 0.3097023	total: 710ms	remaining: 733ms
# 492:	learn: 0.3096727	total: 711ms	remaining: 731ms
# 493:	learn: 0.3096429	total: 712ms	remaining: 729ms
# 494:	learn: 0.3096344	total: 713ms	remaining: 727ms
# 495:	learn: 0.3096128	total: 713ms	remaining: 725ms
# 496:	learn: 0.3095993	total: 716ms	remaining: 724ms
# 497:	learn: 0.3095757	total: 717ms	remaining: 723ms
# 498:	learn: 0.3095312	total: 718ms	remaining: 721ms
# 499:	learn: 0.3094997	total: 719ms	remaining: 719ms
# 500:	learn: 0.3094750	total: 720ms	remaining: 717ms
# 501:	learn: 0.3094363	total: 722ms	remaining: 716ms
# 502:	learn: 0.3094196	total: 724ms	remaining: 716ms
# 503:	learn: 0.3093957	total: 726ms	remaining: 715ms
# 504:	learn: 0.3093721	total: 727ms	remaining: 713ms
# 505:	learn: 0.3093388	total: 731ms	remaining: 714ms
# 506:	learn: 0.3092905	total: 733ms	remaining: 712ms
# 507:	learn: 0.3092680	total: 734ms	remaining: 711ms
# 508:	learn: 0.3092547	total: 736ms	remaining: 710ms
# 509:	learn: 0.3092396	total: 737ms	remaining: 708ms
# 510:	learn: 0.3092172	total: 738ms	remaining: 706ms
# 511:	learn: 0.3092005	total: 740ms	remaining: 705ms
# 512:	learn: 0.3091645	total: 741ms	remaining: 704ms
# 513:	learn: 0.3091519	total: 743ms	remaining: 702ms
# 514:	learn: 0.3091404	total: 744ms	remaining: 701ms
# 515:	learn: 0.3090967	total: 745ms	remaining: 699ms
# 516:	learn: 0.3090571	total: 746ms	remaining: 697ms
# 517:	learn: 0.3090224	total: 748ms	remaining: 696ms
# 518:	learn: 0.3090112	total: 749ms	remaining: 694ms
# 519:	learn: 0.3089851	total: 750ms	remaining: 692ms
# 520:	learn: 0.3089643	total: 752ms	remaining: 691ms
# 521:	learn: 0.3089317	total: 753ms	remaining: 690ms
# 522:	learn: 0.3088890	total: 756ms	remaining: 689ms
# 523:	learn: 0.3088411	total: 759ms	remaining: 690ms
# 524:	learn: 0.3088043	total: 761ms	remaining: 688ms
# 525:	learn: 0.3087931	total: 761ms	remaining: 686ms
# 526:	learn: 0.3087593	total: 763ms	remaining: 684ms
# 527:	learn: 0.3087270	total: 765ms	remaining: 684ms
# 528:	learn: 0.3087163	total: 766ms	remaining: 682ms
# 529:	learn: 0.3087062	total: 767ms	remaining: 680ms
# 530:	learn: 0.3086963	total: 767ms	remaining: 678ms
# 531:	learn: 0.3086757	total: 768ms	remaining: 676ms
# 532:	learn: 0.3086659	total: 769ms	remaining: 674ms
# 533:	learn: 0.3086434	total: 771ms	remaining: 673ms
# 534:	learn: 0.3086114	total: 772ms	remaining: 671ms
# 535:	learn: 0.3086018	total: 772ms	remaining: 669ms
# 536:	learn: 0.3085924	total: 773ms	remaining: 666ms
# 537:	learn: 0.3085828	total: 774ms	remaining: 664ms
# 538:	learn: 0.3085487	total: 775ms	remaining: 663ms
# 539:	learn: 0.3085407	total: 776ms	remaining: 661ms
# 540:	learn: 0.3085207	total: 777ms	remaining: 660ms
# 541:	learn: 0.3085124	total: 779ms	remaining: 658ms
# 542:	learn: 0.3084894	total: 779ms	remaining: 656ms
# 543:	learn: 0.3084557	total: 780ms	remaining: 654ms
# 544:	learn: 0.3084472	total: 780ms	remaining: 651ms
# 545:	learn: 0.3084221	total: 781ms	remaining: 650ms
# 546:	learn: 0.3083992	total: 782ms	remaining: 648ms
# 547:	learn: 0.3083628	total: 784ms	remaining: 647ms
# 548:	learn: 0.3083601	total: 785ms	remaining: 645ms
# 549:	learn: 0.3083525	total: 786ms	remaining: 643ms
# 550:	learn: 0.3083338	total: 787ms	remaining: 641ms
# 551:	learn: 0.3082906	total: 788ms	remaining: 640ms
# 552:	learn: 0.3082882	total: 789ms	remaining: 638ms
# 553:	learn: 0.3082677	total: 790ms	remaining: 636ms
# 554:	learn: 0.3082338	total: 791ms	remaining: 634ms
# 555:	learn: 0.3082024	total: 793ms	remaining: 633ms
# 556:	learn: 0.3081713	total: 794ms	remaining: 632ms
# 557:	learn: 0.3081525	total: 796ms	remaining: 631ms
# 558:	learn: 0.3081319	total: 799ms	remaining: 630ms
# 559:	learn: 0.3080927	total: 800ms	remaining: 628ms
# 560:	learn: 0.3080759	total: 801ms	remaining: 627ms
# 561:	learn: 0.3080390	total: 802ms	remaining: 625ms
# 562:	learn: 0.3080366	total: 803ms	remaining: 624ms
# 563:	learn: 0.3080082	total: 804ms	remaining: 622ms
# 564:	learn: 0.3079793	total: 805ms	remaining: 620ms
# 565:	learn: 0.3079464	total: 806ms	remaining: 618ms
# 566:	learn: 0.3079226	total: 808ms	remaining: 617ms
# 567:	learn: 0.3078954	total: 809ms	remaining: 615ms
# 568:	learn: 0.3078645	total: 825ms	remaining: 625ms
# 569:	learn: 0.3078362	total: 827ms	remaining: 624ms
# 570:	learn: 0.3078006	total: 828ms	remaining: 622ms
# 571:	learn: 0.3077804	total: 829ms	remaining: 621ms
# 572:	learn: 0.3077577	total: 831ms	remaining: 619ms
# 573:	learn: 0.3077130	total: 832ms	remaining: 618ms
# 574:	learn: 0.3076829	total: 834ms	remaining: 616ms
# 575:	learn: 0.3076640	total: 853ms	remaining: 628ms
# 576:	learn: 0.3076470	total: 856ms	remaining: 627ms
# 577:	learn: 0.3076120	total: 857ms	remaining: 626ms
# 578:	learn: 0.3076047	total: 860ms	remaining: 625ms
# 579:	learn: 0.3075638	total: 861ms	remaining: 623ms
# 580:	learn: 0.3075406	total: 863ms	remaining: 622ms
# 581:	learn: 0.3075192	total: 863ms	remaining: 620ms
# 582:	learn: 0.3074943	total: 864ms	remaining: 618ms
# 583:	learn: 0.3074669	total: 865ms	remaining: 616ms
# 584:	learn: 0.3074366	total: 866ms	remaining: 614ms
# 585:	learn: 0.3074049	total: 876ms	remaining: 619ms
# 586:	learn: 0.3073877	total: 881ms	remaining: 620ms
# 587:	learn: 0.3073707	total: 882ms	remaining: 618ms
# 588:	learn: 0.3073521	total: 883ms	remaining: 616ms
# 589:	learn: 0.3073194	total: 884ms	remaining: 614ms
# 590:	learn: 0.3073008	total: 885ms	remaining: 613ms
# 591:	learn: 0.3072664	total: 886ms	remaining: 610ms
# 592:	learn: 0.3072491	total: 886ms	remaining: 608ms
# 593:	learn: 0.3072319	total: 887ms	remaining: 606ms
# 594:	learn: 0.3072001	total: 888ms	remaining: 604ms
# 595:	learn: 0.3071746	total: 888ms	remaining: 602ms
# 596:	learn: 0.3071501	total: 891ms	remaining: 601ms
# 597:	learn: 0.3071323	total: 893ms	remaining: 600ms
# 598:	learn: 0.3070963	total: 893ms	remaining: 598ms
# 599:	learn: 0.3070730	total: 894ms	remaining: 596ms
# 600:	learn: 0.3070543	total: 895ms	remaining: 594ms
# 601:	learn: 0.3070521	total: 896ms	remaining: 592ms
# 602:	learn: 0.3070254	total: 897ms	remaining: 590ms
# 603:	learn: 0.3070232	total: 898ms	remaining: 589ms
# 604:	learn: 0.3070031	total: 898ms	remaining: 587ms
# 605:	learn: 0.3069827	total: 900ms	remaining: 585ms
# 606:	learn: 0.3069458	total: 900ms	remaining: 583ms
# 607:	learn: 0.3069201	total: 901ms	remaining: 581ms
# 608:	learn: 0.3069028	total: 902ms	remaining: 579ms
# 609:	learn: 0.3068741	total: 903ms	remaining: 577ms
# 610:	learn: 0.3068582	total: 904ms	remaining: 575ms
# 611:	learn: 0.3068302	total: 909ms	remaining: 576ms
# 612:	learn: 0.3068021	total: 910ms	remaining: 575ms
# 613:	learn: 0.3067836	total: 911ms	remaining: 573ms
# 614:	learn: 0.3067675	total: 912ms	remaining: 571ms
# 615:	learn: 0.3067436	total: 913ms	remaining: 569ms
# 616:	learn: 0.3067261	total: 913ms	remaining: 567ms
# 617:	learn: 0.3066945	total: 914ms	remaining: 565ms
# 618:	learn: 0.3066784	total: 915ms	remaining: 563ms
# 619:	learn: 0.3066629	total: 920ms	remaining: 564ms
# 620:	learn: 0.3066402	total: 923ms	remaining: 563ms
# 621:	learn: 0.3066239	total: 924ms	remaining: 562ms
# 622:	learn: 0.3066183	total: 925ms	remaining: 560ms
# 623:	learn: 0.3065852	total: 926ms	remaining: 558ms
# 624:	learn: 0.3065669	total: 928ms	remaining: 557ms
# 625:	learn: 0.3065395	total: 929ms	remaining: 555ms
# 626:	learn: 0.3065225	total: 930ms	remaining: 553ms
# 627:	learn: 0.3064903	total: 931ms	remaining: 552ms
# 628:	learn: 0.3064596	total: 933ms	remaining: 551ms
# 629:	learn: 0.3064353	total: 934ms	remaining: 549ms
# 630:	learn: 0.3064201	total: 936ms	remaining: 547ms
# 631:	learn: 0.3063920	total: 937ms	remaining: 546ms
# 632:	learn: 0.3063686	total: 938ms	remaining: 544ms
# 633:	learn: 0.3063667	total: 941ms	remaining: 543ms
# 634:	learn: 0.3063551	total: 943ms	remaining: 542ms
# 635:	learn: 0.3063315	total: 948ms	remaining: 543ms
# 636:	learn: 0.3063101	total: 951ms	remaining: 542ms
# 637:	learn: 0.3062888	total: 952ms	remaining: 540ms
# 638:	learn: 0.3062588	total: 953ms	remaining: 538ms
# 639:	learn: 0.3062369	total: 955ms	remaining: 537ms
# 640:	learn: 0.3062120	total: 958ms	remaining: 536ms
# 641:	learn: 0.3061858	total: 959ms	remaining: 535ms
# 642:	learn: 0.3061665	total: 960ms	remaining: 533ms
# 643:	learn: 0.3061392	total: 961ms	remaining: 531ms
# 644:	learn: 0.3061130	total: 962ms	remaining: 530ms
# 645:	learn: 0.3060929	total: 963ms	remaining: 528ms
# 646:	learn: 0.3060695	total: 964ms	remaining: 526ms
# 647:	learn: 0.3060474	total: 965ms	remaining: 524ms
# 648:	learn: 0.3060302	total: 967ms	remaining: 523ms
# 649:	learn: 0.3060166	total: 968ms	remaining: 521ms
# 650:	learn: 0.3059932	total: 969ms	remaining: 519ms
# 651:	learn: 0.3059747	total: 970ms	remaining: 518ms
# 652:	learn: 0.3059562	total: 971ms	remaining: 516ms
# 653:	learn: 0.3059413	total: 972ms	remaining: 514ms
# 654:	learn: 0.3059277	total: 973ms	remaining: 512ms
# 655:	learn: 0.3059122	total: 974ms	remaining: 511ms
# 656:	learn: 0.3058859	total: 975ms	remaining: 509ms
# 657:	learn: 0.3058640	total: 976ms	remaining: 507ms
# 658:	learn: 0.3058401	total: 977ms	remaining: 505ms
# 659:	learn: 0.3058244	total: 978ms	remaining: 504ms
# 660:	learn: 0.3058111	total: 978ms	remaining: 502ms
# 661:	learn: 0.3057946	total: 979ms	remaining: 500ms
# 662:	learn: 0.3057926	total: 980ms	remaining: 498ms
# 663:	learn: 0.3057665	total: 983ms	remaining: 497ms
# 664:	learn: 0.3057423	total: 984ms	remaining: 496ms
# 665:	learn: 0.3057052	total: 989ms	remaining: 496ms
# 666:	learn: 0.3056864	total: 990ms	remaining: 494ms
# 667:	learn: 0.3056774	total: 991ms	remaining: 492ms
# 668:	learn: 0.3056517	total: 992ms	remaining: 491ms
# 669:	learn: 0.3056232	total: 993ms	remaining: 489ms
# 670:	learn: 0.3056064	total: 994ms	remaining: 488ms
# 671:	learn: 0.3055838	total: 996ms	remaining: 486ms
# 672:	learn: 0.3055674	total: 997ms	remaining: 484ms
# 673:	learn: 0.3055510	total: 998ms	remaining: 483ms
# 674:	learn: 0.3055320	total: 999ms	remaining: 481ms
# 675:	learn: 0.3055130	total: 999ms	remaining: 479ms
# 676:	learn: 0.3054820	total: 1s	remaining: 478ms
# 677:	learn: 0.3054696	total: 1s	remaining: 476ms
# 678:	learn: 0.3054566	total: 1s	remaining: 475ms
# 679:	learn: 0.3054385	total: 1s	remaining: 473ms
# 680:	learn: 0.3054121	total: 1.01s	remaining: 471ms
# 681:	learn: 0.3053917	total: 1.01s	remaining: 470ms
# 682:	learn: 0.3053679	total: 1.01s	remaining: 469ms
# 683:	learn: 0.3053515	total: 1.01s	remaining: 467ms
# 684:	learn: 0.3053377	total: 1.01s	remaining: 465ms
# 685:	learn: 0.3053127	total: 1.01s	remaining: 464ms
# 686:	learn: 0.3052985	total: 1.01s	remaining: 462ms
# 687:	learn: 0.3052881	total: 1.01s	remaining: 460ms
# 688:	learn: 0.3052669	total: 1.01s	remaining: 458ms
# 689:	learn: 0.3052523	total: 1.02s	remaining: 457ms
# 690:	learn: 0.3052217	total: 1.02s	remaining: 455ms
# 691:	learn: 0.3051981	total: 1.02s	remaining: 453ms
# 692:	learn: 0.3051824	total: 1.02s	remaining: 452ms
# 693:	learn: 0.3051637	total: 1.02s	remaining: 450ms
# 694:	learn: 0.3051527	total: 1.02s	remaining: 449ms
# 695:	learn: 0.3051329	total: 1.02s	remaining: 447ms
# 696:	learn: 0.3051127	total: 1.02s	remaining: 446ms
# 697:	learn: 0.3050984	total: 1.02s	remaining: 444ms
# 698:	learn: 0.3050766	total: 1.03s	remaining: 442ms
# 699:	learn: 0.3050648	total: 1.03s	remaining: 440ms
# 700:	learn: 0.3050524	total: 1.03s	remaining: 438ms
# 701:	learn: 0.3050396	total: 1.03s	remaining: 437ms
# 702:	learn: 0.3050201	total: 1.03s	remaining: 435ms
# 703:	learn: 0.3050049	total: 1.03s	remaining: 433ms
# 704:	learn: 0.3049919	total: 1.03s	remaining: 432ms
# 705:	learn: 0.3049758	total: 1.03s	remaining: 430ms
# 706:	learn: 0.3049559	total: 1.03s	remaining: 428ms
# 707:	learn: 0.3049448	total: 1.03s	remaining: 426ms
# 708:	learn: 0.3049250	total: 1.03s	remaining: 425ms
# 709:	learn: 0.3049204	total: 1.03s	remaining: 423ms
# 710:	learn: 0.3049101	total: 1.04s	remaining: 421ms
# 711:	learn: 0.3048860	total: 1.04s	remaining: 420ms
# 712:	learn: 0.3048739	total: 1.04s	remaining: 418ms
# 713:	learn: 0.3048718	total: 1.04s	remaining: 416ms
# 714:	learn: 0.3048511	total: 1.04s	remaining: 415ms
# 715:	learn: 0.3048378	total: 1.04s	remaining: 413ms
# 716:	learn: 0.3048187	total: 1.04s	remaining: 412ms
# 717:	learn: 0.3047914	total: 1.04s	remaining: 411ms
# 718:	learn: 0.3047708	total: 1.05s	remaining: 409ms
# 719:	learn: 0.3047578	total: 1.05s	remaining: 407ms
# 720:	learn: 0.3047366	total: 1.05s	remaining: 406ms
# 721:	learn: 0.3047161	total: 1.05s	remaining: 404ms
# 722:	learn: 0.3047146	total: 1.05s	remaining: 402ms
# 723:	learn: 0.3046951	total: 1.05s	remaining: 401ms
# 724:	learn: 0.3046766	total: 1.05s	remaining: 399ms
# 725:	learn: 0.3046585	total: 1.05s	remaining: 398ms
# 726:	learn: 0.3046320	total: 1.05s	remaining: 396ms
# 727:	learn: 0.3046160	total: 1.05s	remaining: 394ms
# 728:	learn: 0.3045931	total: 1.05s	remaining: 393ms
# 729:	learn: 0.3045765	total: 1.06s	remaining: 391ms
# 730:	learn: 0.3045517	total: 1.06s	remaining: 389ms
# 731:	learn: 0.3045402	total: 1.06s	remaining: 388ms
# 732:	learn: 0.3045214	total: 1.06s	remaining: 386ms
# 733:	learn: 0.3044992	total: 1.06s	remaining: 385ms
# 734:	learn: 0.3044868	total: 1.06s	remaining: 383ms
# 735:	learn: 0.3044683	total: 1.06s	remaining: 381ms
# 736:	learn: 0.3044506	total: 1.06s	remaining: 380ms
# 737:	learn: 0.3044400	total: 1.06s	remaining: 378ms
# 738:	learn: 0.3044275	total: 1.06s	remaining: 376ms
# 739:	learn: 0.3044166	total: 1.07s	remaining: 375ms
# 740:	learn: 0.3043976	total: 1.07s	remaining: 373ms
# 741:	learn: 0.3043799	total: 1.07s	remaining: 372ms
# 742:	learn: 0.3043628	total: 1.07s	remaining: 370ms
# 743:	learn: 0.3043429	total: 1.07s	remaining: 369ms
# 744:	learn: 0.3043232	total: 1.07s	remaining: 367ms
# 745:	learn: 0.3043080	total: 1.07s	remaining: 365ms
# 746:	learn: 0.3042878	total: 1.07s	remaining: 364ms
# 747:	learn: 0.3042768	total: 1.07s	remaining: 362ms
# 748:	learn: 0.3042653	total: 1.08s	remaining: 361ms
# 749:	learn: 0.3042531	total: 1.08s	remaining: 359ms
# 750:	learn: 0.3042511	total: 1.08s	remaining: 358ms
# 751:	learn: 0.3042433	total: 1.08s	remaining: 356ms
# 752:	learn: 0.3042205	total: 1.08s	remaining: 355ms
# 753:	learn: 0.3042038	total: 1.08s	remaining: 353ms
# 754:	learn: 0.3041879	total: 1.08s	remaining: 351ms
# 755:	learn: 0.3041708	total: 1.08s	remaining: 350ms
# 756:	learn: 0.3041519	total: 1.08s	remaining: 348ms
# 757:	learn: 0.3041273	total: 1.08s	remaining: 346ms
# 758:	learn: 0.3041102	total: 1.09s	remaining: 345ms
# 759:	learn: 0.3040968	total: 1.09s	remaining: 343ms
# 760:	learn: 0.3040775	total: 1.09s	remaining: 342ms
# 761:	learn: 0.3040555	total: 1.09s	remaining: 340ms
# 762:	learn: 0.3040394	total: 1.09s	remaining: 339ms
# 763:	learn: 0.3040247	total: 1.09s	remaining: 337ms
# 764:	learn: 0.3040087	total: 1.09s	remaining: 335ms
# 765:	learn: 0.3040021	total: 1.09s	remaining: 334ms
# 766:	learn: 0.3039912	total: 1.09s	remaining: 332ms
# 767:	learn: 0.3039760	total: 1.09s	remaining: 331ms
# 768:	learn: 0.3039590	total: 1.1s	remaining: 329ms
# 769:	learn: 0.3039467	total: 1.1s	remaining: 328ms
# 770:	learn: 0.3039264	total: 1.1s	remaining: 326ms
# 771:	learn: 0.3039149	total: 1.1s	remaining: 325ms
# 772:	learn: 0.3038904	total: 1.1s	remaining: 323ms
# 773:	learn: 0.3038741	total: 1.1s	remaining: 322ms
# 774:	learn: 0.3038567	total: 1.1s	remaining: 320ms
# 775:	learn: 0.3038365	total: 1.1s	remaining: 318ms
# 776:	learn: 0.3038194	total: 1.1s	remaining: 317ms
# 777:	learn: 0.3038180	total: 1.1s	remaining: 315ms
# 778:	learn: 0.3038069	total: 1.11s	remaining: 314ms
# 779:	learn: 0.3037967	total: 1.11s	remaining: 313ms
# 780:	learn: 0.3037881	total: 1.11s	remaining: 311ms
# 781:	learn: 0.3037783	total: 1.11s	remaining: 310ms
# 782:	learn: 0.3037625	total: 1.11s	remaining: 308ms
# 783:	learn: 0.3037542	total: 1.11s	remaining: 307ms
# 784:	learn: 0.3037427	total: 1.11s	remaining: 306ms
# 785:	learn: 0.3037329	total: 1.12s	remaining: 304ms
# 786:	learn: 0.3037154	total: 1.12s	remaining: 303ms
# 787:	learn: 0.3036992	total: 1.12s	remaining: 301ms
# 788:	learn: 0.3036890	total: 1.12s	remaining: 299ms
# 789:	learn: 0.3036754	total: 1.12s	remaining: 298ms
# 790:	learn: 0.3036741	total: 1.12s	remaining: 297ms
# 791:	learn: 0.3036539	total: 1.12s	remaining: 295ms
# 792:	learn: 0.3036452	total: 1.12s	remaining: 293ms
# 793:	learn: 0.3036368	total: 1.13s	remaining: 292ms
# 794:	learn: 0.3036225	total: 1.13s	remaining: 290ms
# 795:	learn: 0.3036021	total: 1.13s	remaining: 289ms
# 796:	learn: 0.3035859	total: 1.13s	remaining: 288ms
# 797:	learn: 0.3035706	total: 1.13s	remaining: 286ms
# 798:	learn: 0.3035610	total: 1.13s	remaining: 285ms
# 799:	learn: 0.3035482	total: 1.13s	remaining: 283ms
# 800:	learn: 0.3035444	total: 1.13s	remaining: 282ms
# 801:	learn: 0.3035355	total: 1.13s	remaining: 280ms
# 802:	learn: 0.3035174	total: 1.14s	remaining: 278ms
# 803:	learn: 0.3035014	total: 1.14s	remaining: 277ms
# 804:	learn: 0.3034855	total: 1.14s	remaining: 276ms
# 805:	learn: 0.3034747	total: 1.14s	remaining: 274ms
# 806:	learn: 0.3034538	total: 1.14s	remaining: 273ms
# 807:	learn: 0.3034388	total: 1.14s	remaining: 271ms
# 808:	learn: 0.3034267	total: 1.14s	remaining: 270ms
# 809:	learn: 0.3034117	total: 1.14s	remaining: 268ms
# 810:	learn: 0.3033941	total: 1.14s	remaining: 267ms
# 811:	learn: 0.3033798	total: 1.15s	remaining: 265ms
# 812:	learn: 0.3033661	total: 1.15s	remaining: 264ms
# 813:	learn: 0.3033552	total: 1.15s	remaining: 262ms
# 814:	learn: 0.3033394	total: 1.15s	remaining: 261ms
# 815:	learn: 0.3033285	total: 1.15s	remaining: 259ms
# 816:	learn: 0.3033143	total: 1.15s	remaining: 258ms
# 817:	learn: 0.3033053	total: 1.15s	remaining: 256ms
# 818:	learn: 0.3032920	total: 1.15s	remaining: 255ms
# 819:	learn: 0.3032827	total: 1.15s	remaining: 253ms
# 820:	learn: 0.3032679	total: 1.16s	remaining: 252ms
# 821:	learn: 0.3032527	total: 1.16s	remaining: 250ms
# 822:	learn: 0.3032511	total: 1.16s	remaining: 249ms
# 823:	learn: 0.3032422	total: 1.16s	remaining: 247ms
# 824:	learn: 0.3032225	total: 1.16s	remaining: 246ms
# 825:	learn: 0.3032064	total: 1.16s	remaining: 244ms
# 826:	learn: 0.3031928	total: 1.16s	remaining: 243ms
# 827:	learn: 0.3031754	total: 1.16s	remaining: 241ms
# 828:	learn: 0.3031576	total: 1.16s	remaining: 240ms
# 829:	learn: 0.3031489	total: 1.16s	remaining: 238ms
# 830:	learn: 0.3031375	total: 1.16s	remaining: 237ms
# 831:	learn: 0.3031183	total: 1.17s	remaining: 235ms
# 832:	learn: 0.3031027	total: 1.17s	remaining: 234ms
# 833:	learn: 0.3030927	total: 1.17s	remaining: 232ms
# 834:	learn: 0.3030803	total: 1.17s	remaining: 231ms
# 835:	learn: 0.3030682	total: 1.17s	remaining: 229ms
# 836:	learn: 0.3030666	total: 1.17s	remaining: 228ms
# 837:	learn: 0.3030530	total: 1.17s	remaining: 227ms
# 838:	learn: 0.3030381	total: 1.17s	remaining: 225ms
# 839:	learn: 0.3030277	total: 1.17s	remaining: 224ms
# 840:	learn: 0.3030141	total: 1.17s	remaining: 222ms
# 841:	learn: 0.3029926	total: 1.18s	remaining: 221ms
# 842:	learn: 0.3029911	total: 1.18s	remaining: 219ms
# 843:	learn: 0.3029785	total: 1.18s	remaining: 218ms
# 844:	learn: 0.3029717	total: 1.18s	remaining: 216ms
# 845:	learn: 0.3029567	total: 1.18s	remaining: 214ms
# 846:	learn: 0.3029473	total: 1.18s	remaining: 213ms
# 847:	learn: 0.3029367	total: 1.18s	remaining: 212ms
# 848:	learn: 0.3029289	total: 1.18s	remaining: 210ms
# 849:	learn: 0.3029204	total: 1.18s	remaining: 209ms
# 850:	learn: 0.3029061	total: 1.18s	remaining: 207ms
# 851:	learn: 0.3028860	total: 1.19s	remaining: 206ms
# 852:	learn: 0.3028764	total: 1.19s	remaining: 204ms
# 853:	learn: 0.3028684	total: 1.19s	remaining: 203ms
# 854:	learn: 0.3028548	total: 1.19s	remaining: 202ms
# 855:	learn: 0.3028400	total: 1.19s	remaining: 200ms
# 856:	learn: 0.3028298	total: 1.19s	remaining: 199ms
# 857:	learn: 0.3028128	total: 1.19s	remaining: 198ms
# 858:	learn: 0.3028039	total: 1.19s	remaining: 196ms
# 859:	learn: 0.3027899	total: 1.2s	remaining: 195ms
# 860:	learn: 0.3027820	total: 1.2s	remaining: 193ms
# 861:	learn: 0.3027758	total: 1.2s	remaining: 192ms
# 862:	learn: 0.3027626	total: 1.2s	remaining: 191ms
# 863:	learn: 0.3027490	total: 1.2s	remaining: 189ms
# 864:	learn: 0.3027420	total: 1.2s	remaining: 188ms
# 865:	learn: 0.3027324	total: 1.2s	remaining: 186ms
# 866:	learn: 0.3027207	total: 1.2s	remaining: 185ms
# 867:	learn: 0.3027085	total: 1.21s	remaining: 183ms
# 868:	learn: 0.3026957	total: 1.21s	remaining: 182ms
# 869:	learn: 0.3026812	total: 1.21s	remaining: 180ms
# 870:	learn: 0.3026733	total: 1.21s	remaining: 179ms
# 871:	learn: 0.3026643	total: 1.21s	remaining: 178ms
# 872:	learn: 0.3026638	total: 1.21s	remaining: 176ms
# 873:	learn: 0.3026489	total: 1.21s	remaining: 175ms
# 874:	learn: 0.3026361	total: 1.21s	remaining: 173ms
# 875:	learn: 0.3026240	total: 1.21s	remaining: 172ms
# 876:	learn: 0.3026117	total: 1.21s	remaining: 170ms
# 877:	learn: 0.3025899	total: 1.21s	remaining: 169ms
# 878:	learn: 0.3025834	total: 1.22s	remaining: 167ms
# 879:	learn: 0.3025625	total: 1.22s	remaining: 166ms
# 880:	learn: 0.3025533	total: 1.22s	remaining: 164ms
# 881:	learn: 0.3025458	total: 1.22s	remaining: 163ms
# 882:	learn: 0.3025345	total: 1.22s	remaining: 162ms
# 883:	learn: 0.3025230	total: 1.22s	remaining: 160ms
# 884:	learn: 0.3025078	total: 1.22s	remaining: 159ms
# 885:	learn: 0.3024965	total: 1.22s	remaining: 157ms
# 886:	learn: 0.3024857	total: 1.22s	remaining: 156ms
# 887:	learn: 0.3024723	total: 1.22s	remaining: 154ms
# 888:	learn: 0.3024651	total: 1.22s	remaining: 153ms
# 889:	learn: 0.3024576	total: 1.22s	remaining: 151ms
# 890:	learn: 0.3024510	total: 1.22s	remaining: 150ms
# 891:	learn: 0.3024323	total: 1.23s	remaining: 148ms
# 892:	learn: 0.3024292	total: 1.23s	remaining: 147ms
# 893:	learn: 0.3024164	total: 1.23s	remaining: 146ms
# 894:	learn: 0.3024046	total: 1.23s	remaining: 144ms
# 895:	learn: 0.3023931	total: 1.23s	remaining: 143ms
# 896:	learn: 0.3023839	total: 1.23s	remaining: 141ms
# 897:	learn: 0.3023705	total: 1.23s	remaining: 140ms
# 898:	learn: 0.3023627	total: 1.23s	remaining: 138ms
# 899:	learn: 0.3023596	total: 1.23s	remaining: 137ms
# 900:	learn: 0.3023454	total: 1.24s	remaining: 136ms
# 901:	learn: 0.3023372	total: 1.24s	remaining: 135ms
# 902:	learn: 0.3023363	total: 1.24s	remaining: 133ms
# 903:	learn: 0.3023245	total: 1.24s	remaining: 132ms
# 904:	learn: 0.3023122	total: 1.24s	remaining: 130ms
# 905:	learn: 0.3023037	total: 1.24s	remaining: 129ms
# 906:	learn: 0.3022962	total: 1.24s	remaining: 128ms
# 907:	learn: 0.3022840	total: 1.24s	remaining: 126ms
# 908:	learn: 0.3022770	total: 1.25s	remaining: 125ms
# 909:	learn: 0.3022659	total: 1.25s	remaining: 123ms
# 910:	learn: 0.3022581	total: 1.25s	remaining: 122ms
# 911:	learn: 0.3022529	total: 1.25s	remaining: 121ms
# 912:	learn: 0.3022499	total: 1.25s	remaining: 119ms
# 913:	learn: 0.3022424	total: 1.25s	remaining: 118ms
# 914:	learn: 0.3022323	total: 1.25s	remaining: 116ms
# 915:	learn: 0.3022253	total: 1.25s	remaining: 115ms
# 916:	learn: 0.3022169	total: 1.25s	remaining: 114ms
# 917:	learn: 0.3022054	total: 1.26s	remaining: 112ms
# 918:	learn: 0.3021870	total: 1.26s	remaining: 111ms
# 919:	learn: 0.3021727	total: 1.26s	remaining: 110ms
# 920:	learn: 0.3021600	total: 1.26s	remaining: 108ms
# 921:	learn: 0.3021469	total: 1.26s	remaining: 107ms
# 922:	learn: 0.3021331	total: 1.26s	remaining: 105ms
# ...
# 695:	learn: 0.3035319	total: 454ms	remaining: 198ms
# 696:	learn: 0.3035092	total: 454ms	remaining: 197ms
# 697:	learn: 0.3035042	total: 455ms	remaining: 197ms
# 698:	learn: 0.3034917	total: 455ms	remaining: 196ms
# 699:	learn: 0.3034717	total: 456ms	remaining: 195ms
# 700:	learn: 0.3034524	total: 456ms	remaining: 195ms
# 701:	learn: 0.3034398	total: 457ms	remaining: 194ms
# 702:	learn: 0.3034242	total: 458ms	remaining: 193ms
# 703:	learn: 0.3034101	total: 458ms	remaining: 193ms
# 704:	learn: 0.3034054	total: 459ms	remaining: 192ms
# 705:	learn: 0.3034006	total: 459ms	remaining: 191ms
# 706:	learn: 0.3033877	total: 460ms	remaining: 191ms
# 707:	learn: 0.3033724	total: 461ms	remaining: 190ms
# 708:	learn: 0.3033537	total: 461ms	remaining: 189ms
# 709:	learn: 0.3033379	total: 462ms	remaining: 189ms
# 710:	learn: 0.3033281	total: 462ms	remaining: 188ms
# 711:	learn: 0.3033077	total: 463ms	remaining: 187ms
# 712:	learn: 0.3032875	total: 464ms	remaining: 187ms
# 713:	learn: 0.3032684	total: 464ms	remaining: 186ms
# 714:	learn: 0.3032528	total: 465ms	remaining: 185ms
# 715:	learn: 0.3032343	total: 466ms	remaining: 185ms
# 716:	learn: 0.3032149	total: 466ms	remaining: 184ms
# 717:	learn: 0.3032010	total: 467ms	remaining: 183ms
# 718:	learn: 0.3031921	total: 468ms	remaining: 183ms
# 719:	learn: 0.3031731	total: 468ms	remaining: 182ms
# 720:	learn: 0.3031586	total: 469ms	remaining: 181ms
# 721:	learn: 0.3031405	total: 469ms	remaining: 181ms
# 722:	learn: 0.3031196	total: 470ms	remaining: 180ms
# 723:	learn: 0.3031091	total: 470ms	remaining: 179ms
# 724:	learn: 0.3030957	total: 471ms	remaining: 179ms
# 725:	learn: 0.3030826	total: 472ms	remaining: 178ms
# 726:	learn: 0.3030650	total: 472ms	remaining: 177ms
# 727:	learn: 0.3030463	total: 473ms	remaining: 177ms
# 728:	learn: 0.3030388	total: 473ms	remaining: 176ms
# 729:	learn: 0.3030344	total: 474ms	remaining: 175ms
# 730:	learn: 0.3030303	total: 475ms	remaining: 175ms
# 731:	learn: 0.3030132	total: 476ms	remaining: 174ms
# 732:	learn: 0.3030027	total: 476ms	remaining: 173ms
# 733:	learn: 0.3029816	total: 477ms	remaining: 173ms
# 734:	learn: 0.3029573	total: 478ms	remaining: 172ms
# 735:	learn: 0.3029359	total: 479ms	remaining: 172ms
# 736:	learn: 0.3029201	total: 479ms	remaining: 171ms
# 737:	learn: 0.3029104	total: 480ms	remaining: 170ms
# 738:	learn: 0.3028907	total: 481ms	remaining: 170ms
# 739:	learn: 0.3028742	total: 481ms	remaining: 169ms
# 740:	learn: 0.3028581	total: 482ms	remaining: 168ms
# 741:	learn: 0.3028438	total: 482ms	remaining: 168ms
# 742:	learn: 0.3028314	total: 483ms	remaining: 167ms
# 743:	learn: 0.3028143	total: 483ms	remaining: 166ms
# 744:	learn: 0.3028010	total: 484ms	remaining: 166ms
# 745:	learn: 0.3027902	total: 485ms	remaining: 165ms
# 746:	learn: 0.3027828	total: 485ms	remaining: 164ms
# 747:	learn: 0.3027726	total: 486ms	remaining: 164ms
# 748:	learn: 0.3027622	total: 486ms	remaining: 163ms
# 749:	learn: 0.3027490	total: 487ms	remaining: 162ms
# 750:	learn: 0.3027355	total: 488ms	remaining: 162ms
# 751:	learn: 0.3027069	total: 488ms	remaining: 161ms
# 752:	learn: 0.3026894	total: 489ms	remaining: 160ms
# 753:	learn: 0.3026825	total: 489ms	remaining: 160ms
# 754:	learn: 0.3026657	total: 490ms	remaining: 159ms
# 755:	learn: 0.3026550	total: 490ms	remaining: 158ms
# 756:	learn: 0.3026506	total: 491ms	remaining: 158ms
# 757:	learn: 0.3026328	total: 492ms	remaining: 157ms
# 758:	learn: 0.3026245	total: 493ms	remaining: 156ms
# 759:	learn: 0.3026078	total: 493ms	remaining: 156ms
# 760:	learn: 0.3026003	total: 494ms	remaining: 155ms
# 761:	learn: 0.3025811	total: 495ms	remaining: 154ms
# 762:	learn: 0.3025573	total: 495ms	remaining: 154ms
# 763:	learn: 0.3025402	total: 496ms	remaining: 153ms
# 764:	learn: 0.3025361	total: 496ms	remaining: 153ms
# 765:	learn: 0.3025168	total: 497ms	remaining: 152ms
# 766:	learn: 0.3024999	total: 498ms	remaining: 151ms
# 767:	learn: 0.3024855	total: 498ms	remaining: 150ms
# 768:	learn: 0.3024697	total: 499ms	remaining: 150ms
# 769:	learn: 0.3024523	total: 499ms	remaining: 149ms
# 770:	learn: 0.3024360	total: 500ms	remaining: 149ms
# 771:	learn: 0.3024194	total: 501ms	remaining: 148ms
# 772:	learn: 0.3023932	total: 501ms	remaining: 147ms
# 773:	learn: 0.3023807	total: 502ms	remaining: 147ms
# 774:	learn: 0.3023672	total: 502ms	remaining: 146ms
# 775:	learn: 0.3023519	total: 503ms	remaining: 145ms
# 776:	learn: 0.3023350	total: 504ms	remaining: 145ms
# 777:	learn: 0.3023235	total: 504ms	remaining: 144ms
# 778:	learn: 0.3022975	total: 505ms	remaining: 143ms
# 779:	learn: 0.3022938	total: 505ms	remaining: 143ms
# 780:	learn: 0.3022734	total: 506ms	remaining: 142ms
# 781:	learn: 0.3022602	total: 507ms	remaining: 141ms
# 782:	learn: 0.3022550	total: 507ms	remaining: 141ms
# 783:	learn: 0.3022353	total: 508ms	remaining: 140ms
# 784:	learn: 0.3022175	total: 509ms	remaining: 139ms
# 785:	learn: 0.3022067	total: 509ms	remaining: 139ms
# 786:	learn: 0.3021821	total: 510ms	remaining: 138ms
# 787:	learn: 0.3021763	total: 510ms	remaining: 137ms
# 788:	learn: 0.3021669	total: 511ms	remaining: 137ms
# 789:	learn: 0.3021632	total: 511ms	remaining: 136ms
# 790:	learn: 0.3021525	total: 512ms	remaining: 135ms
# 791:	learn: 0.3021346	total: 513ms	remaining: 135ms
# 792:	learn: 0.3021206	total: 513ms	remaining: 134ms
# 793:	learn: 0.3021130	total: 514ms	remaining: 133ms
# 794:	learn: 0.3020990	total: 514ms	remaining: 133ms
# 795:	learn: 0.3020844	total: 515ms	remaining: 132ms
# 796:	learn: 0.3020691	total: 516ms	remaining: 131ms
# 797:	learn: 0.3020546	total: 516ms	remaining: 131ms
# 798:	learn: 0.3020369	total: 517ms	remaining: 130ms
# 799:	learn: 0.3020127	total: 517ms	remaining: 129ms
# 800:	learn: 0.3019964	total: 518ms	remaining: 129ms
# 801:	learn: 0.3019839	total: 518ms	remaining: 128ms
# 802:	learn: 0.3019682	total: 519ms	remaining: 127ms
# 803:	learn: 0.3019649	total: 520ms	remaining: 127ms
# 804:	learn: 0.3019605	total: 520ms	remaining: 126ms
# 805:	learn: 0.3019438	total: 521ms	remaining: 125ms
# 806:	learn: 0.3019308	total: 521ms	remaining: 125ms
# 807:	learn: 0.3019189	total: 522ms	remaining: 124ms
# 808:	learn: 0.3019065	total: 522ms	remaining: 123ms
# 809:	learn: 0.3018993	total: 523ms	remaining: 123ms
# 810:	learn: 0.3018821	total: 524ms	remaining: 122ms
# 811:	learn: 0.3018710	total: 525ms	remaining: 121ms
# 812:	learn: 0.3018565	total: 525ms	remaining: 121ms
# 813:	learn: 0.3018446	total: 526ms	remaining: 120ms
# 814:	learn: 0.3018303	total: 526ms	remaining: 119ms
# 815:	learn: 0.3018133	total: 527ms	remaining: 119ms
# 816:	learn: 0.3018041	total: 528ms	remaining: 118ms
# 817:	learn: 0.3017941	total: 528ms	remaining: 118ms
# 818:	learn: 0.3017830	total: 529ms	remaining: 117ms
# 819:	learn: 0.3017713	total: 529ms	remaining: 116ms
# 820:	learn: 0.3017565	total: 530ms	remaining: 116ms
# 821:	learn: 0.3017420	total: 530ms	remaining: 115ms
# 822:	learn: 0.3017378	total: 531ms	remaining: 114ms
# 823:	learn: 0.3017286	total: 532ms	remaining: 114ms
# 824:	learn: 0.3017197	total: 532ms	remaining: 113ms
# 825:	learn: 0.3017103	total: 533ms	remaining: 112ms
# 826:	learn: 0.3017003	total: 533ms	remaining: 112ms
# 827:	learn: 0.3016873	total: 534ms	remaining: 111ms
# 828:	learn: 0.3016793	total: 534ms	remaining: 110ms
# 829:	learn: 0.3016599	total: 535ms	remaining: 110ms
# 830:	learn: 0.3016434	total: 535ms	remaining: 109ms
# 831:	learn: 0.3016295	total: 536ms	remaining: 108ms
# 832:	learn: 0.3016104	total: 537ms	remaining: 108ms
# 833:	learn: 0.3016010	total: 537ms	remaining: 107ms
# 834:	learn: 0.3015898	total: 538ms	remaining: 106ms
# 835:	learn: 0.3015782	total: 539ms	remaining: 106ms
# 836:	learn: 0.3015622	total: 540ms	remaining: 105ms
# 837:	learn: 0.3015510	total: 540ms	remaining: 104ms
# 838:	learn: 0.3015477	total: 541ms	remaining: 104ms
# 839:	learn: 0.3015307	total: 542ms	remaining: 103ms
# 840:	learn: 0.3015224	total: 542ms	remaining: 103ms
# 841:	learn: 0.3015110	total: 543ms	remaining: 102ms
# 842:	learn: 0.3014998	total: 544ms	remaining: 101ms
# 843:	learn: 0.3014831	total: 544ms	remaining: 101ms
# 844:	learn: 0.3014727	total: 545ms	remaining: 99.9ms
# 845:	learn: 0.3014625	total: 545ms	remaining: 99.3ms
# 846:	learn: 0.3014472	total: 546ms	remaining: 98.6ms
# 847:	learn: 0.3014373	total: 546ms	remaining: 98ms
# 848:	learn: 0.3014241	total: 547ms	remaining: 97.3ms
# 849:	learn: 0.3014179	total: 548ms	remaining: 96.6ms
# 850:	learn: 0.3014045	total: 548ms	remaining: 96ms
# 851:	learn: 0.3013905	total: 549ms	remaining: 95.3ms
# 852:	learn: 0.3013750	total: 549ms	remaining: 94.6ms
# 853:	learn: 0.3013662	total: 550ms	remaining: 94ms
# 854:	learn: 0.3013512	total: 550ms	remaining: 93.3ms
# 855:	learn: 0.3013389	total: 551ms	remaining: 92.7ms
# 856:	learn: 0.3013214	total: 552ms	remaining: 92ms
# 857:	learn: 0.3013076	total: 552ms	remaining: 91.4ms
# 858:	learn: 0.3013004	total: 553ms	remaining: 90.7ms
# 859:	learn: 0.3012902	total: 553ms	remaining: 90.1ms
# 860:	learn: 0.3012841	total: 554ms	remaining: 89.4ms
# 861:	learn: 0.3012731	total: 554ms	remaining: 88.8ms
# 862:	learn: 0.3012699	total: 556ms	remaining: 88.2ms
# 863:	learn: 0.3012606	total: 556ms	remaining: 87.6ms
# 864:	learn: 0.3012465	total: 557ms	remaining: 86.9ms
# 865:	learn: 0.3012313	total: 557ms	remaining: 86.2ms
# 866:	learn: 0.3012282	total: 558ms	remaining: 85.6ms
# 867:	learn: 0.3012149	total: 559ms	remaining: 84.9ms
# 868:	learn: 0.3011990	total: 559ms	remaining: 84.3ms
# 869:	learn: 0.3011873	total: 560ms	remaining: 83.6ms
# 870:	learn: 0.3011779	total: 560ms	remaining: 83ms
# 871:	learn: 0.3011675	total: 561ms	remaining: 82.4ms
# 872:	learn: 0.3011548	total: 562ms	remaining: 81.7ms
# 873:	learn: 0.3011451	total: 562ms	remaining: 81.1ms
# 874:	learn: 0.3011296	total: 563ms	remaining: 80.4ms
# 875:	learn: 0.3011159	total: 563ms	remaining: 79.7ms
# 876:	learn: 0.3010977	total: 564ms	remaining: 79.1ms
# 877:	learn: 0.3010884	total: 564ms	remaining: 78.4ms
# 878:	learn: 0.3010800	total: 565ms	remaining: 77.8ms
# 879:	learn: 0.3010675	total: 566ms	remaining: 77.1ms
# 880:	learn: 0.3010589	total: 566ms	remaining: 76.5ms
# 881:	learn: 0.3010478	total: 567ms	remaining: 75.8ms
# 882:	learn: 0.3010450	total: 567ms	remaining: 75.1ms
# 883:	learn: 0.3010347	total: 568ms	remaining: 74.5ms
# 884:	learn: 0.3010246	total: 568ms	remaining: 73.9ms
# 885:	learn: 0.3010146	total: 569ms	remaining: 73.2ms
# 886:	learn: 0.3010027	total: 569ms	remaining: 72.5ms
# 887:	learn: 0.3009903	total: 570ms	remaining: 71.9ms
# 888:	learn: 0.3009807	total: 571ms	remaining: 71.3ms
# 889:	learn: 0.3009647	total: 572ms	remaining: 70.6ms
# 890:	learn: 0.3009565	total: 572ms	remaining: 70ms
# 891:	learn: 0.3009414	total: 573ms	remaining: 69.4ms
# 892:	learn: 0.3009336	total: 574ms	remaining: 68.7ms
# 893:	learn: 0.3009217	total: 574ms	remaining: 68.1ms
# 894:	learn: 0.3009053	total: 575ms	remaining: 67.4ms
# 895:	learn: 0.3008911	total: 575ms	remaining: 66.8ms
# 896:	learn: 0.3008844	total: 576ms	remaining: 66.1ms
# 897:	learn: 0.3008678	total: 577ms	remaining: 65.5ms
# 898:	learn: 0.3008650	total: 577ms	remaining: 64.9ms
# 899:	learn: 0.3008451	total: 578ms	remaining: 64.2ms
# 900:	learn: 0.3008426	total: 578ms	remaining: 63.5ms
# 901:	learn: 0.3008348	total: 579ms	remaining: 62.9ms
# 902:	learn: 0.3008233	total: 579ms	remaining: 62.2ms
# 903:	learn: 0.3008150	total: 580ms	remaining: 61.6ms
# 904:	learn: 0.3008024	total: 581ms	remaining: 60.9ms
# 905:	learn: 0.3007908	total: 581ms	remaining: 60.3ms
# 906:	learn: 0.3007851	total: 582ms	remaining: 59.6ms
# 907:	learn: 0.3007824	total: 582ms	remaining: 59ms
# 908:	learn: 0.3007684	total: 583ms	remaining: 58.3ms
# 909:	learn: 0.3007610	total: 583ms	remaining: 57.7ms
# 910:	learn: 0.3007501	total: 584ms	remaining: 57ms
# 911:	learn: 0.3007478	total: 584ms	remaining: 56.4ms
# 912:	learn: 0.3007381	total: 585ms	remaining: 55.7ms
# 913:	learn: 0.3007264	total: 585ms	remaining: 55.1ms
# 914:	learn: 0.3007151	total: 586ms	remaining: 54.5ms
# 915:	learn: 0.3007103	total: 587ms	remaining: 53.8ms
# 916:	learn: 0.3007016	total: 587ms	remaining: 53.2ms
# 917:	learn: 0.3006894	total: 588ms	remaining: 52.5ms
# 918:	learn: 0.3006859	total: 589ms	remaining: 51.9ms
# 919:	learn: 0.3006756	total: 589ms	remaining: 51.3ms
# 920:	learn: 0.3006697	total: 590ms	remaining: 50.6ms
# 921:	learn: 0.3006629	total: 591ms	remaining: 50ms
# 922:	learn: 0.3006564	total: 591ms	remaining: 49.3ms
# 923:	learn: 0.3006464	total: 592ms	remaining: 48.7ms
# 924:	learn: 0.3006355	total: 592ms	remaining: 48ms
# 925:	learn: 0.3006270	total: 593ms	remaining: 47.4ms
# 926:	learn: 0.3006139	total: 593ms	remaining: 46.7ms
# 927:	learn: 0.3006007	total: 594ms	remaining: 46.1ms
# 928:	learn: 0.3005784	total: 595ms	remaining: 45.5ms
# 929:	learn: 0.3005724	total: 595ms	remaining: 44.8ms
# 930:	learn: 0.3005611	total: 596ms	remaining: 44.2ms
# 931:	learn: 0.3005442	total: 597ms	remaining: 43.5ms
# 932:	learn: 0.3005406	total: 597ms	remaining: 42.9ms
# 933:	learn: 0.3005329	total: 598ms	remaining: 42.2ms
# 934:	learn: 0.3005245	total: 598ms	remaining: 41.6ms
# 935:	learn: 0.3005181	total: 599ms	remaining: 40.9ms
# 936:	learn: 0.3004957	total: 599ms	remaining: 40.3ms
# 937:	learn: 0.3004782	total: 600ms	remaining: 39.6ms
# 938:	learn: 0.3004651	total: 600ms	remaining: 39ms
# 939:	learn: 0.3004567	total: 601ms	remaining: 38.4ms
# 940:	learn: 0.3004490	total: 602ms	remaining: 37.7ms
# 941:	learn: 0.3004383	total: 602ms	remaining: 37.1ms
# 942:	learn: 0.3004276	total: 603ms	remaining: 36.4ms
# 943:	learn: 0.3004169	total: 604ms	remaining: 35.8ms
# 944:	learn: 0.3004121	total: 604ms	remaining: 35.2ms
# 945:	learn: 0.3004041	total: 605ms	remaining: 34.5ms
# 946:	learn: 0.3003964	total: 606ms	remaining: 33.9ms
# 947:	learn: 0.3003903	total: 607ms	remaining: 33.3ms
# 948:	learn: 0.3003880	total: 607ms	remaining: 32.6ms
# 949:	learn: 0.3003737	total: 608ms	remaining: 32ms
# 950:	learn: 0.3003637	total: 609ms	remaining: 31.4ms
# 951:	learn: 0.3003532	total: 609ms	remaining: 30.7ms
# 952:	learn: 0.3003408	total: 610ms	remaining: 30.1ms
# 953:	learn: 0.3003249	total: 611ms	remaining: 29.4ms
# 954:	learn: 0.3003153	total: 611ms	remaining: 28.8ms
# 955:	learn: 0.3003026	total: 612ms	remaining: 28.1ms
# 956:	learn: 0.3002930	total: 612ms	remaining: 27.5ms
# 957:	learn: 0.3002777	total: 613ms	remaining: 26.9ms
# 958:	learn: 0.3002669	total: 613ms	remaining: 26.2ms
# 959:	learn: 0.3002617	total: 614ms	remaining: 25.6ms
# 960:	learn: 0.3002513	total: 614ms	remaining: 24.9ms
# 961:	learn: 0.3002489	total: 615ms	remaining: 24.3ms
# 962:	learn: 0.3002433	total: 616ms	remaining: 23.6ms
# 963:	learn: 0.3002228	total: 616ms	remaining: 23ms
# 964:	learn: 0.3002079	total: 617ms	remaining: 22.4ms
# 965:	learn: 0.3001997	total: 617ms	remaining: 21.7ms
# 966:	learn: 0.3001977	total: 618ms	remaining: 21.1ms
# 967:	learn: 0.3001885	total: 618ms	remaining: 20.4ms
# 968:	learn: 0.3001863	total: 619ms	remaining: 19.8ms
# 969:	learn: 0.3001782	total: 620ms	remaining: 19.2ms
# 970:	learn: 0.3001696	total: 621ms	remaining: 18.5ms
# 971:	learn: 0.3001611	total: 622ms	remaining: 17.9ms
# 972:	learn: 0.3001531	total: 622ms	remaining: 17.3ms
# 973:	learn: 0.3001454	total: 623ms	remaining: 16.6ms
# 974:	learn: 0.3001359	total: 623ms	remaining: 16ms
# 975:	learn: 0.3001219	total: 624ms	remaining: 15.3ms
# 976:	learn: 0.3001098	total: 624ms	remaining: 14.7ms
# 977:	learn: 0.3000924	total: 625ms	remaining: 14.1ms
# 978:	learn: 0.3000905	total: 626ms	remaining: 13.4ms
# 979:	learn: 0.3000823	total: 626ms	remaining: 12.8ms
# 980:	learn: 0.3000726	total: 627ms	remaining: 12.1ms
# 981:	learn: 0.3000528	total: 627ms	remaining: 11.5ms
# 982:	learn: 0.3000437	total: 628ms	remaining: 10.9ms
# 983:	learn: 0.3000335	total: 628ms	remaining: 10.2ms
# 984:	learn: 0.3000265	total: 629ms	remaining: 9.58ms
# 985:	learn: 0.3000200	total: 630ms	remaining: 8.94ms
# 986:	learn: 0.3000040	total: 630ms	remaining: 8.3ms
# 987:	learn: 0.2999935	total: 631ms	remaining: 7.66ms
# 988:	learn: 0.2999878	total: 631ms	remaining: 7.02ms
# 989:	learn: 0.2999756	total: 632ms	remaining: 6.38ms
# 990:	learn: 0.2999572	total: 632ms	remaining: 5.74ms
# 991:	learn: 0.2999482	total: 633ms	remaining: 5.1ms
# 992:	learn: 0.2999422	total: 633ms	remaining: 4.46ms
# 993:	learn: 0.2999301	total: 634ms	remaining: 3.83ms
# 994:	learn: 0.2999275	total: 635ms	remaining: 3.19ms
# 995:	learn: 0.2999180	total: 636ms	remaining: 2.55ms
# 996:	learn: 0.2999110	total: 636ms	remaining: 1.91ms
# 997:	learn: 0.2999048	total: 637ms	remaining: 1.28ms
# 998:	learn: 0.2998965	total: 637ms	remaining: 638us
# 999:	learn: 0.2998827	total: 638ms	remaining: 0us

# %%
#Undoing log transformation on predictions to use actual price on stacked model

lasso_pred=np.exp(lasso_pred)-1

en_pred=np.exp(en_pred)-1

knn_pred=np.exp(knn_pred)-1
knn_pred2=np.exp(knn_pred2)-1
knn_pred3=np.exp(knn_pred3)-1
rf_pred=np.exp(rf_pred)-1
gbm_pred=np.exp(gbm_pred)-1
xgb_pred=np.exp(xgb_pred)-1
cat_pred=np.exp(cat_pred)-1

# %% [markdown]
# The correlation heatmap below demonstrates that although lasso and elastic net were very similar to each other (both being linear models), they had very different error structures compared to K-nearest neighbours and tree-based models such as gradient boosting and random forest. K-nearest neighbours on geographical features were the most dissimilar to the other models since it was trained only on geographic features, which were not as significant in other models. The greatest similarities were observed in the tree-based models, namely random forest, gradient boosting (predicting on log price), gradient boosting (predicting on non-transformed price), and XGBoost. Given that CatBoost was trained on only categorical features, it had a unique error structure compared to other models.

# %%
#Plotting correlations between model predictions
#Getting correlation matrix between models
corr_matrix=np.corrcoef([lasso_pred,en_pred,knn_pred,knn_pred2,knn_pred3,rf_pred,gbm_pred,gbm_pred2,xgb_pred,cat_pred])
corr_df= pd.DataFrame(corr_matrix,columns=['Lasso','Elastic Net','KNN(Geo)','KNN(prop)','KNN (All)','RF','GBM','GBM2','XGB','CatBoost'],
                      index=['Lasso','Elastic Net','KNN(Geo)','KNN(prop)','KNN (All)','RF','GBM','GBM2','XGB','CatBoost'])

#Plotting heatmap of correlations
fig=sns.heatmap(corr_df, annot=True)
fig.xaxis.tick_top()
fig.set_xticklabels(fig.get_xticklabels(), rotation=40)
plt.tight_layout()
plt.title("Correlation Between Base Models")
# Out:
# Text(0.5, 1.0, 'Correlation Between Base Models')

# %%
#Feature reduction using lasso regression
X_meta=np.column_stack([knn_pred2, lasso_pred,knn_pred,knn_pred3,gbm_pred,en_pred,rf_pred,xgb_pred,cat_pred])


meta_learner_lasso=Lasso()

meta_lasso=GridSearchCV(
    meta_learner_lasso,
    param_grid={'alpha':[0.1, 1, 10, 100, 1000, 10000]},
    cv=5,
    scoring='neg_root_mean_squared_error'
)


meta_lasso.fit(X_meta,y_train)

meta_lasso_best= meta_lasso.best_estimator_

#No feature reduction necessary
meta_lasso_best.coef_
# Out:
# array([-0.08912069,  0.22553171,  0.06836847, -0.18329014,  0.89600084,
#         0.01752591, -0.03944503,  0.07797557,  0.10739258])

# %%
#Selecting best models for meta-learner
#KNN (on all features), XGB, Elastic Net, RF, CatBoost, and GBM is used to train the meta-learner
X_meta_train=np.column_stack([knn_pred,xgb_pred,en_pred,rf_pred,cat_pred,gbm_pred])

# %%
#GBM meta learner
meta_learner_gbm=GradientBoostingRegressor(random_state=10001)
meta_learner_gbm.fit(X_meta_train,y_train)
# Out:
# GradientBoostingRegressor(random_state=10001)

# %%
#Linear regression meta-learner
meta_learner_linear=LinearRegression()
meta_learner_linear.fit(X_meta_train,y_train)
meta_learner_linear.coef_
# Out:
# array([ 0.08734694,  0.01650273,  0.17294531, -0.18743701,  0.06352755,
#         0.9873948 ])

# %%
from sklearn.linear_model import Ridge

#Ridge regression meta-learner
#Ridge does not automatically shrink any variables that are redundant 
#Can also handle multicollinear features 
meta_learner_ridge=Ridge(solver='sag')

#Grid search on alpha
meta_ridge=GridSearchCV(
    meta_learner_ridge,
    param_grid={'alpha':[0.1, 1, 10, 100, 1000, 10000]},
    cv=5,
    scoring='neg_root_mean_squared_error'
)

#Fitting ridge model
meta_ridge.fit(X_meta_train,y_train)

#getting best model
meta_ridge_best= meta_ridge.best_estimator_

meta_ridge_best.coef_
# Out:
# array([ 0.08730611,  0.01826276,  0.1729442 , -0.18695028,  0.06356017,
#         0.98519858])

# %%
#Defining a function for model performance metrics without undoing log transformation
def linear_metrics(model,X_test,Y_test):
    #Predict on model 
    pred=model.predict(X_test)
    
    #RMSE
    rmse=mean_squared_error(Y_test,pred)
    rmse=np.sqrt(rmse).astype(float)

    #R squared
    r2 = r2_score(Y_test, pred)

    #Put everything together in a dict 
    lr_results = {"RMSE": rmse, "Rsquare": r2}
    print("lr_results:", lr_results)

# %%
#Getting predictions on test set and undoing log transformation on predicted results 

lasso_pred_test=np.exp(lasso_best.predict(X_test))-1

rf_pred_test=np.exp(rf_best.predict(X_test))-1
knn_pred_test=np.exp(knn_best.predict(X_test))-1
knn_pred_test2=np.exp(knn_best2.predict(X_test))-1
knn_pred_test3=np.exp(knn_best3.predict(X_test))-1
gbm_pred_test=np.exp(gbm_best.predict(X_test))-1
en_pred_test=np.exp(en_best.predict(X_test))-1
xgb_pred_test=np.exp(xgb_best.predict(X_test))-1
cat_pred_test=np.exp(cat_best.predict(X_test))-1

gbm_pred2_test=gbm_best2.predict(X_test)


#Column stacks for meta learners
X_meta_test=np.column_stack([knn_pred_test,xgb_pred_test,en_pred_test,rf_pred_test,cat_pred_test,gbm_pred_test])
X_meta_test2=np.column_stack([knn_pred_test2,lasso_pred_test,knn_pred_test,knn_pred_test3,en_pred_test,gbm_pred_test,rf_pred_test,xgb_pred_test,cat_pred_test])

#Performance metrics on test set for meta-learners
linear_metrics(meta_learner_gbm,X_meta_test,y_test)
linear_metrics(meta_learner_linear,X_meta_test,y_test)
linear_metrics(meta_ridge_best,X_meta_test,y_test)
# Out:
# lr_results: {'RMSE': np.float64(235876.36437409732), 'Rsquare': 0.8291755928467349}
# lr_results: {'RMSE': np.float64(219766.68278052428), 'Rsquare': 0.8517124201077719}
# lr_results: {'RMSE': np.float64(219763.5455223753), 'Rsquare': 0.8517166538077299}

# %%
#Defining function to get performance metrics without y transformation

def scores2(model,Xtest, Ytest):
    #Get predictions
    pred=model.predict(Xtest)

    #RMSE
    rmse=mean_squared_error(Ytest,pred)
    rmse=np.sqrt(rmse)
    rmse=round(rmse,2)

    #R squared
    r2 = r2_score(Ytest, pred)
    r2=round(r2,2)

    #MAPE
    mape=mean_absolute_percentage_error(Ytest,pred)
    mape=100*round(mape,2)

    #Average Profit
    avg_profit=100*round(np.mean((pred-Ytest)/Ytest),2)
    return (rmse, r2, mape,avg_profit)

# %% [markdown]
# Based on the table below, the ridge based meta-learner performed the best with the lowest RMSE and MAPE as well as the highest R squared. There is also very little difference between training R squared and testing R squared observed in the Ridge model. Although the gradient boosting meta learner had performed the best on the training set, it had the lowest R squared and the greatest RMSE on the test set, indicating that the gradient boosting model was overfitting on the training dataset.

# %%
#Comparing meta-learner performance on test set
models=[meta_learner_gbm,meta_learner_linear,meta_ridge_best]
model_names=['GBM Meta Learner','Linear Meta Learner','Ridge']

#Mapping scores onto meta-learners
score=list(map(lambda l: scores2(l,Xtest=X_meta_test,Ytest=y_test),models))

#Displaying dataframe 
score_df= pd.DataFrame(score,columns=['RMSE','R Squared','MAPE','Average Profit'],index=model_names)
score_df
# Out:
#                           RMSE  R Squared  MAPE  Average Profit
# GBM Meta Learner     235876.36       0.83  16.0             5.0
# Linear Meta Learner  219766.68       0.85  16.0             3.0
# Ridge                219763.55       0.85  16.0             3.0

# %%
#Comparing meta-learner performance on train set to check for overfitting
score=list(map(lambda l: scores2(l,Xtest=X_meta_train,Ytest=y_train),models))

score_df= pd.DataFrame(score,columns=['RMSE','R Squared','MAPE','Average Profit'],index=model_names)
score_df
# Out:
#                           RMSE  R Squared  MAPE  Average Profit
# GBM Meta Learner     133987.02       0.93  15.0             4.0
# Linear Meta Learner  183804.46       0.87  16.0             3.0
# Ridge                183804.48       0.87  16.0             3.0

# %%
#Getting base-learner weights in Ridge meta-learner
meta_ridge_coef=meta_ridge_best.coef_
name_models=['KNN','XGB','Elastic Net','Random Forest','CatBoost','GBM']
coefs=[]

for coef in meta_ridge_coef:
    coefs.append(coef)

coefs_df=pd.DataFrame({'Base Learner':name_models,'Weight':coefs})
coefs_df.sort_values(by='Weight', ascending=False)
# Out:
#     Base Learner    Weight
# 5            GBM  0.985199
# 2    Elastic Net  0.172944
# 0            KNN  0.087306
# 4       CatBoost  0.063560
# 1            XGB  0.018263
# 3  Random Forest -0.186950

# %% [markdown]
# # Pick investments
# The stacked model was then applied to 2000 current listings to predict the actual value of each of the listings. Then, the difference between the predicted actual value of the property and the asking price of each property was calculated as a percentage then ranked. Doing so ascertained which properties were undervalued by their asking price. The top 200 listings with the greatest difference between actual value and asking price was then selected for the portfolio.

# %%
#Creating clustered columns on oos data
df4=london_house_prices_2019_out_of_sample.copy()
df3 = london_house_prices_2019_training.copy()

#Clsutering for energy features
scaler=StandardScaler()

energy_features=['total_floor_area','co2_emissions_current','co2_emissions_potential','energy_consumption_potential','energy_consumption_current']

#Scaling on training data
df3_scaled_energy=scaler.fit_transform(df3[energy_features])

#Scaling on OOS
df4_scaled_energy=scaler.transform(df4[energy_features])

#Fitting K-means on training data
km_energy=KMeans(n_clusters=3,n_init=50, random_state=1).fit(df3_scaled_energy)

#Predicting Kmeans on OOS
km_predict_energy=km_energy.predict(df4_scaled_energy)+1

#Adding labels to OOS dataframe
df4['cluster_energy']=km_predict_energy

# %%
#Clustering on geographic features
geo_features=['latitude','longitude','london_zone','distance_to_station']

#Scaling data
df3_scaled_geo=scaler.fit_transform(df3[geo_features])
df4_scaled_geo=scaler.transform(df4[geo_features])

#Fitting K-means clustering
km_geo=KMeans(n_clusters=2,n_init=50, random_state=1).fit(df3_scaled_geo)
km_predict_geo=km_geo.predict(df4_scaled_geo)+1

#Adding labels to OOS dataframe
df4['cluster_geo']=km_predict_geo

# %%
#Predicting on OOS using ridge model
#Creating stacked columns for prediction
ridge_models=[knn_best,en_best,rf_best,gbm_best,cat_best,xgb_best]
columns=[]

for model in ridge_models:
    pred=np.exp(model.predict(df4))-1
    columns.append(pred)

stack_oos=np.column_stack([col for col in columns])

# %%
#Getting predictions and generating list of investments
pred_oos=pd.DataFrame({'ID':df4['ID'],'asking price':df4['asking_price'],'price':meta_ridge_best.predict(stack_oos)})

#Calculating price difference between asking price and predicted price 
pred_oos['price_diff']=(pred_oos['price']-pred_oos['asking price'])/pred_oos['asking price']

#Selecting the top 200 most undervalued properties 
pred_oos_ranked=pred_oos.sort_values(by='price_diff', ascending=False).head(200)
pred_oos_ranked
# Out:
#          ID  asking price          price  price_diff
# 25     5977      192000.0  944563.657516    3.919602
# 881    7296      112000.0  429533.265318    2.835118
# 863    9101       83000.0  315725.154937    2.803918
# 38    15713       84000.0  284379.974546    2.385476
# 1400   8684      131000.0  376109.347261    1.871064
# ...     ...           ...            ...         ...
# 1015   4808      596000.0  785174.018509    0.317406
# 415    4494      291000.0  383305.846853    0.317202
# 8      9363      534000.0  702992.307210    0.316465
# 73    12103      453000.0  596153.194219    0.316011
# 41    12502      231000.0  303337.169749    0.313148
#
# [200 rows x 4 columns]

# %%
#Calculating Average profit %
average_profit= np.mean(pred_oos_ranked['price_diff'])*100
print(f'The average profit % is {average_profit:.2f}%')
print(f'There are {len(pred_oos_ranked)} investments in the portfolio')
# Out:
# The average profit % is 65.75%
# There are 200 investments in the portfolio

# %%
#Creating buy column for investments
df4['buy']=df4['ID'].isin(pred_oos_ranked['ID']).astype(int)
df4
# Out:
#          ID date  postcode property_type whether_old_or_new freehold_or_leasehold  address1  address2  address3 town  \
# 0     14434  NaT       NaN             D                  N                     F       NaN       NaN       NaN  NaN
# 1     12562  NaT       NaN             F                  N                     L       NaN       NaN       NaN  NaN
# 2      8866  NaT       NaN             F                  N                     L       NaN       NaN       NaN  NaN
# 3     10721  NaT       NaN             S                  N                     F       NaN       NaN       NaN  NaN
# 4      1057  NaT       NaN             T                  N                     F       NaN       NaN       NaN  NaN
# ...     ...  ...       ...           ...                ...                   ...       ...       ...       ...  ...
# 1994   3690  NaT       NaN             D                  N                     F       NaN       NaN       NaN  NaN
# 1995   9181  NaT       NaN             S                  N                     F       NaN       NaN       NaN  NaN
# 1996  11246  NaT       NaN             F                  N                     L       NaN       NaN       NaN  NaN
# 1997   1247  NaT       NaN             S                  N                     F       NaN       NaN       NaN  NaN
# 1998  15418  NaT       NaN             F                  N                     L       NaN       NaN       NaN  NaN
#
#       local_aut  county postcode_short current_energy_rating  total_floor_area  number_habitable_rooms  \
# 0           NaN     NaN            N14                     D             150.0                       6
# 1           NaN     NaN            HA0                     C              59.0                       2
# 2           NaN     NaN             E3                     D              58.0                       2
# 3           NaN     NaN            HA2                     D              74.0                       5
# 4           NaN     NaN             W4                     E              97.3                       5
# ...         ...     ...            ...                   ...               ...                     ...
# 1994        NaN     NaN            HA4                     F              79.0                       4
# 1995        NaN     NaN            HA4                     C             153.0                       7
# 1996        NaN     NaN            SE1                     C              81.0                       2
# 1997        NaN     NaN           SE21                     D              82.0                       4
# 1998        NaN     NaN            SW6                     D              45.0                       3
#
#       co2_emissions_current  co2_emissions_potential  energy_consumption_current  energy_consumption_potential  \
# 0                       7.3                      2.4                         274                            89
# 1                       1.5                      1.4                         142                           136
# 2                       2.8                      1.2                         253                           110
# 3                       3.5                      1.2                         256                            80
# 4                       6.5                      5.7                         303                           266
# ...                     ...                      ...                         ...                           ...
# 1994                    8.9                      3.2                         622                           214
# 1995                    4.3                      2.9                         158                           107
# 1996                    2.1                      2.2                         172                           177
# 1997                    3.4                      1.3                         276                           116
# 1998                    1.9                      1.2                         237                           158
#
#      windows_energy_eff          tenure   latitude  longitude  population  altitude  london_zone  nearest_station  \
# 0               Average  owner-occupied  51.624538  -0.129001        87.0        63            4      arnos grove
# 1               Average  owner-occupied  51.551654  -0.296625        79.0        38            4  wembley central
# 2               Average  owner-occupied  51.536359  -0.032838        23.0        17            2     hackney wick
# 3               Average  owner-occupied  51.559214  -0.374416        73.0        39            5    northolt park
# 4               Average  owner-occupied  51.491380  -0.257589       100.0         8            2    turnham green
# ...                 ...             ...        ...        ...         ...       ...          ...              ...
# 1994               Poor  owner-occupied  51.583597  -0.430962         8.0        54            6          ruislip
# 1995               Good  owner-occupied  51.575697  -0.389457        79.0        44            5         eastcote
# 1996               Good  owner-occupied  51.502170  -0.098875        34.0         9            1          borough
# 1997               Poor  owner-occupied  51.450050  -0.086822        62.0        30            2    north dulwich
# 1998          Very Poor  owner-occupied  51.478042  -0.206169       164.0        10            2    parsons green
#
#        water_company  average_income                district type_of_closest_station  num_tube_lines  num_rail_lines  \
# 0       Thames Water           61300                 Enfield                    tube               1               0
# 1     Affinity Water           48900                   Brent                    tube               2               1
# 2       Thames Water           46200           Tower Hamlets              light_rail               0               0
# 3     Affinity Water           52200                  Harrow                    rail               0               1
# 4       Thames Water           60700                Hounslow                    tube               2               0
# ...              ...             ...                     ...                     ...             ...             ...
# 1994  Affinity Water           60400              Hillingdon                    tube               2               0
# 1995  Affinity Water           64600              Hillingdon                    tube               2               0
# 1996    Thames Water           56600               Southwark                    tube               1               0
# 1997    Thames Water           76600               Southwark                    rail               0               1
# 1998    Thames Water           61900  Hammersmith and Fulham                    tube               1               0
#
#       num_light_rail_lines  distance_to_station  asking_price  cluster_energy  cluster_geo  buy
# 0                        0             0.838890      750000.0               3            2    0
# 1                        1             0.103774      229000.0               2            1    0
# 2                        1             0.914079      152000.0               2            1    1
# 3                        0             0.765565      379000.0               2            2    0
# 4                        0             0.448651      930000.0               1            1    0
# ...                    ...                  ...           ...             ...          ...  ...
# 1994                     0             0.970005      718000.0               1            2    0
# 1995                     0             0.494013      903000.0               2            2    0
# 1996                     0             0.360412      556000.0               2            1    0
# 1997                     0             0.461700     1131000.0               2            1    0
# 1998                     0             0.495256      687000.0               2            1    0
#
# [1999 rows x 40 columns]
